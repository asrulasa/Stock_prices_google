# %% [markdown]
# ### LSTM - Google Stocks prediction

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import ParameterGrid

import yfinance as yf
import datetime
import joblib

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Load dataset

# %%
# Load Google stock data from Yahoo Finance
start_date = '2021-01-01'
end_date = '2024-11-30'
df = yf.download('GOOG', start=start_date, end=end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ### Data visualisation and exploration

# %%
# Display the first five rows
print("First five rows of the dataset:")
df.head()
# Out:
# First five rows of the dataset:
# Price       Adj Close      Close       High        Low       Open    Volume
# Ticker           GOOG       GOOG       GOOG       GOOG       GOOG      GOOG
# Date
# 2021-01-04  86.200310  86.412003  88.032501  85.392502  87.876999  38038000
# 2021-01-05  86.832756  87.045998  87.383499  85.900749  86.250000  22906000
# 2021-01-06  86.551941  86.764503  87.400002  84.949997  85.131500  52042000
# 2021-01-07  89.143578  89.362503  89.419998  86.852501  87.002998  45300000
# 2021-01-08  90.139130  90.360497  90.491997  88.676750  89.399002  41012000

# %%
# Display the first five rows
print("Last five rows of the dataset:")
df.tail()
# Out:
# Last five rows of the dataset:
# Price        Adj Close       Close        High         Low        Open  \
# Ticker            GOOG        GOOG        GOOG        GOOG        GOOG
# Date
# 2024-11-22  166.570007  166.570007  168.264999  165.710007  167.160004
# 2024-11-25  169.429993  169.429993  170.460007  167.399994  167.990005
# 2024-11-26  170.619995  170.619995  171.494995  169.429993  169.490005
# 2024-11-27  170.820007  170.820007  171.139999  169.669998  170.679993
# 2024-11-29  170.490005  170.490005  170.869995  168.750000  170.059998
#
# Price         Volume
# Ticker          GOOG
# Date
# 2024-11-22  24497000
# 2024-11-25  21395700
# 2024-11-26  14937500
# 2024-11-27  12433400
# 2024-11-29   9250700

# %%
# Statistical summary
print("\nStatistical summary of the dataset:")
df.describe()
# Out:
# Statistical summary of the dataset:
# Price    Adj Close       Close        High         Low        Open  \
# Ticker        GOOG        GOOG        GOOG        GOOG        GOOG
# count   984.000000  984.000000  984.000000  984.000000  984.000000
# mean    129.947381  130.229311  131.618411  128.826308  130.154110
# std      24.771823   24.772173   24.879915   24.700776   24.850911
# min      83.285461   83.489998   86.550003   83.449997   85.131500
# 25%     109.962452  110.232498  111.878628  108.127186  109.676502
# 50%     130.277061  130.597000  132.446747  129.608749  130.942001
# 75%     144.030533  144.384254  145.708122  143.065998  144.480495
# max     192.406723  192.660004  193.309998  190.619995  191.750000
#
# Price         Volume
# Ticker          GOOG
# count   9.840000e+02
# mean    2.486143e+07
# std     1.044442e+07
# min     7.409100e+06
# 25%     1.788328e+07
# 50%     2.252595e+07
# 75%     2.874378e+07
# max     9.779860e+07

# %%
# Dataset information
print("\nInformation about the dataset:")
print(df.info())

# Visualize Adj Close prices over time
plt.figure(figsize=(14, 7))
plt.plot(df['Close'])
plt.title('Google Stock Close Price History')
plt.xlabel('Date')
plt.ylabel('Close Price USD ($)')
plt.xticks(rotation=45)
plt.show()
# Out:
# Information about the dataset:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 984 entries, 2021-01-04 to 2024-11-29
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, GOOG)  984 non-null    float64
#  1   (Close, GOOG)      984 non-null    float64
#  2   (High, GOOG)       984 non-null    float64
#  3   (Low, GOOG)        984 non-null    float64
#  4   (Open, GOOG)       984 non-null    float64
#  5   (Volume, GOOG)     984 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 53.8 KB
# None

# %%
# Define sequence length and test days
sequence_length = 60  # Number of days to use for sequences
#test_days = sequence_length  # Use 5 days for testing

# Split into training/validation and test sets
df_train = df[:500]
df_val = df[500:632]
df_test = df[632:732]
#df_actual = df[60:65]

print(f"Training data shape: {df_train.shape}")
print(f"Validation data shape: {df_val.shape}")
print(f"Test data shape: {df_test.shape}")
#print(f"Actual data shape: {df_actual.shape}")
# Out:
# Training data shape: (500, 6)
# Validation data shape: (132, 6)
# Test data shape: (100, 6)

# %% [markdown]
# ### Data Scaling

# %%
# Initialize MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))

# Fit scaler on training data
train_data = df_train[['Close']].values
train_scaled = scaler.fit_transform(train_data)

# Transform validation and test data
val_data = df_val[['Close']].values
val_scaled = scaler.transform(val_data)

test_data = df_test[['Close']].values
test_scaled = scaler.transform(test_data)

# %% [markdown]
# ### LSTM Base Model

# %%
class StockDataset(Dataset):
    def __init__(self, data, sequence_length=5):
        self.sequence_length = sequence_length
        self.data = data

    def __len__(self):
        return len(self.data) - self.sequence_length

    def __getitem__(self, index):
        x = self.data[index:index+self.sequence_length]
        y = self.data[index+self.sequence_length]
        return torch.FloatTensor(x), torch.FloatTensor(y)

class LSTMModel(nn.Module):
    def __init__(self, input_size=1, hidden_size=50, num_layers=2, dropout=0.2):
        super(LSTMModel, self).__init__()
        self.num_layers = num_layers
        self.hidden_size = hidden_size

        self.lstm = nn.LSTM(input_size, hidden_size, num_layers,
                            batch_first=True, dropout=dropout)
        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0),
                         self.hidden_size).to(device)
        c0 = torch.zeros(self.num_layers, x.size(0),
                         self.hidden_size).to(device)

        out, _ = self.lstm(x, (h0, c0))
        out = self.fc(out[:, -1, :])
        return out

# %% [markdown]
# ### Training function

# %%
def train_model(model, train_loader, val_loader, num_epochs=20, learning_rate=0.001,
                criterion=nn.MSELoss(), optimizer_name='Adam', early_stopping_patience=5):

    optimizer = getattr(torch.optim, optimizer_name)(model.parameters(), lr=learning_rate)
    model.to(device)
    criterion.to(device)

    train_losses = []
    val_losses = []
    best_val_loss = np.inf
    patience = early_stopping_patience
    best_model_state = None

    for epoch in range(num_epochs):
        model.train()
        train_loss = 0.0

        for x_batch, y_batch in train_loader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)

            optimizer.zero_grad()
            outputs = model(x_batch)
            loss = criterion(outputs, y_batch)
            loss.backward()
            optimizer.step()

            train_loss += loss.item() * x_batch.size(0)

        train_loss = train_loss / len(train_loader.dataset)
        train_losses.append(train_loss)

        # Validation
        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for x_val, y_val in val_loader:
                x_val = x_val.to(device)
                y_val = y_val.to(device)

                outputs = model(x_val)
                loss = criterion(outputs, y_val)
                val_loss += loss.item() * x_val.size(0)

            val_loss = val_loss / len(val_loader.dataset)
            val_losses.append(val_loss)

            print(f'Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss:.6f}, '
                  f'Val Loss: {val_loss:.6f}')

            # Early Stopping
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                best_model_state = model.state_dict()
                patience = early_stopping_patience  # Reset patience
            else:
                patience -= 1
                if patience == 0:
                    print("Early stopping")
                    model.load_state_dict(best_model_state)
                    break

    # Load best model
    model.load_state_dict(best_model_state)

    return model, train_losses, val_losses

# %% [markdown]
# ### Visualisation function

# %%
def plot_losses(train_losses, val_losses):
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.title('Loss over epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()
    best_loss = min(val_losses)
    print(f'Best Validation Loss: {best_loss}')

# %% [markdown]
# ### Base model LSTM Training

# %%
# Device configuration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Parameters
sequence_length = 60
batch_size = 64

# Prepare datasets and dataloaders
train_dataset = StockDataset(train_scaled, sequence_length)
val_dataset = StockDataset(val_scaled, sequence_length)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# Model parameters
input_size = 1
hidden_size = 50
num_layers = 1
dropout = 0.0
learning_rate = 0.0001
num_epochs = 2000
optimizer_name = 'Adam'
early_stopping_patience = 10

# Initialize model and loss function
model = LSTMModel(input_size, hidden_size, num_layers, dropout)
criterion = nn.MSELoss()

# Train the model
model, train_losses, val_losses = train_model(model, train_loader, val_loader,
                                              num_epochs=num_epochs,
                                              learning_rate=learning_rate,
                                              criterion=criterion,
                                              optimizer_name=optimizer_name,
                                              early_stopping_patience=early_stopping_patience)
# Out:
# Epoch 1/2000, Train Loss: 0.341896, Val Loss: 0.168067
# Epoch 2/2000, Train Loss: 0.330723, Val Loss: 0.160607
# Epoch 3/2000, Train Loss: 0.320282, Val Loss: 0.153477
# Epoch 4/2000, Train Loss: 0.310213, Val Loss: 0.146614
# Epoch 5/2000, Train Loss: 0.300448, Val Loss: 0.139990
# Epoch 6/2000, Train Loss: 0.290946, Val Loss: 0.133579
# Epoch 7/2000, Train Loss: 0.281676, Val Loss: 0.127361
# Epoch 8/2000, Train Loss: 0.272607, Val Loss: 0.121313
# Epoch 9/2000, Train Loss: 0.263711, Val Loss: 0.115418
# Epoch 10/2000, Train Loss: 0.254962, Val Loss: 0.109658
# Epoch 11/2000, Train Loss: 0.246334, Val Loss: 0.104019
# Epoch 12/2000, Train Loss: 0.237806, Val Loss: 0.098486
# Epoch 13/2000, Train Loss: 0.229354, Val Loss: 0.093049
# Epoch 14/2000, Train Loss: 0.220960, Val Loss: 0.087698
# Epoch 15/2000, Train Loss: 0.212604, Val Loss: 0.082423
# Epoch 16/2000, Train Loss: 0.204268, Val Loss: 0.077218
# Epoch 17/2000, Train Loss: 0.195934, Val Loss: 0.072077
# Epoch 18/2000, Train Loss: 0.187586, Val Loss: 0.066994
# Epoch 19/2000, Train Loss: 0.179204, Val Loss: 0.061966
# Epoch 20/2000, Train Loss: 0.170772, Val Loss: 0.056994
# Epoch 21/2000, Train Loss: 0.162270, Val Loss: 0.052079
# Epoch 22/2000, Train Loss: 0.153683, Val Loss: 0.047226
# Epoch 23/2000, Train Loss: 0.144994, Val Loss: 0.042450
# Epoch 24/2000, Train Loss: 0.136192, Val Loss: 0.037769
# Epoch 25/2000, Train Loss: 0.127269, Val Loss: 0.033217
# Epoch 26/2000, Train Loss: 0.118229, Val Loss: 0.028842
# Epoch 27/2000, Train Loss: 0.109091, Val Loss: 0.024714
# Epoch 28/2000, Train Loss: 0.099898, Val Loss: 0.020932
# Epoch 29/2000, Train Loss: 0.090728, Val Loss: 0.017634
# Epoch 30/2000, Train Loss: 0.081710, Val Loss: 0.014998
# Epoch 31/2000, Train Loss: 0.073040, Val Loss: 0.013242
# Epoch 32/2000, Train Loss: 0.064994, Val Loss: 0.012594
# Epoch 33/2000, Train Loss: 0.057909, Val Loss: 0.013212
# Epoch 34/2000, Train Loss: 0.052124, Val Loss: 0.015045
# Epoch 35/2000, Train Loss: 0.047843, Val Loss: 0.017688
# Epoch 36/2000, Train Loss: 0.044985, Val Loss: 0.020391
# Epoch 37/2000, Train Loss: 0.043177, Val Loss: 0.022383
# Epoch 38/2000, Train Loss: 0.041960, Val Loss: 0.023309
# Epoch 39/2000, Train Loss: 0.041024, Val Loss: 0.023330
# Epoch 40/2000, Train Loss: 0.040246, Val Loss: 0.022843
# Epoch 41/2000, Train Loss: 0.039583, Val Loss: 0.022200
# Epoch 42/2000, Train Loss: 0.038997, Val Loss: 0.021594
# Early stopping

# %%
# Plot training and validation loss curves
plot_losses(train_losses, val_losses)
# Out:
# Best Validation Loss: 0.012594380467716191

# %%
# Save the trained base model and scaler
torch.save(model.state_dict(), 'lstm_base_model.pth')
joblib.dump(scaler, 'scaler.pkl')
# Out:
# ['scaler.pkl']

# %% [markdown]
# ### Optimised LSTM model training

# %%
# Define parameter grid for hyperparameter tuning
param_grid = {
    'num_layers': [1, 2, 3],
    'hidden_size': [50, 100],
    'dropout': [0.0, 0.2, 0.3],
    'learning_rate': [0.001, 0.0001],
    'batch_size': [32],
    'num_epochs':[2000],
    'optimizer_name': ['Adam'],
    'early_stopping_patience': [10]
    
}

param_list = list(ParameterGrid(param_grid))

best_model = None
best_val_loss = np.inf
best_params = None

for params in param_list:
    print(f"\nTraining with parameters: {params}")
    # Update batch_size
    batch_size = params['batch_size']

    # Create new DataLoaders with updated batch_size
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    # Initialize model with current parameters
    opt_model = LSTMModel(input_size=input_size, hidden_size=params['hidden_size'],
                      num_layers=params['num_layers'], dropout=params['dropout'])
    criterion = nn.MSELoss()

    # Train model
    opt_model, opt_train_losses, opt_val_losses = train_model(opt_model, train_loader, val_loader,
                                                  num_epochs=params['num_epochs'],
                                                  learning_rate=params['learning_rate'],
                                                  criterion=criterion,
                                                  optimizer_name='Adam',
                                                  early_stopping_patience=params['early_stopping_patience'])

    # Get final validation loss
    val_loss = opt_val_losses[-1]

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model = opt_model
        best_params = params
        best_train_losses = opt_train_losses
        best_val_losses = opt_val_losses

print(f"\nBest parameters: {best_params}")
print(f"Best Validation Loss: {best_val_loss}")
# Out:
# Training with parameters: {'batch_size': 32, 'dropout': 0.0, 'early_stopping_patience': 10, 'hidden_size': 50, 'learning_rate': 0.001, 'num_epochs': 2000, 'num_layers': 1, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.279628, Val Loss: 0.067646
# Epoch 2/2000, Train Loss: 0.137650, Val Loss: 0.015768
# Epoch 3/2000, Train Loss: 0.060800, Val Loss: 0.022627
# Epoch 4/2000, Train Loss: 0.046316, Val Loss: 0.010677
# Epoch 5/2000, Train Loss: 0.047554, Val Loss: 0.020377
# Epoch 6/2000, Train Loss: 0.033831, Val Loss: 0.016176
# Epoch 7/2000, Train Loss: 0.029894, Val Loss: 0.011895
# Epoch 8/2000, Train Loss: 0.024896, Val Loss: 0.009859
# Epoch 9/2000, Train Loss: 0.017650, Val Loss: 0.005553
# Epoch 10/2000, Train Loss: 0.010518, Val Loss: 0.004050
# Epoch 11/2000, Train Loss: 0.009267, Val Loss: 0.006024
# Epoch 12/2000, Train Loss: 0.011552, Val Loss: 0.004511
# Epoch 13/2000, Train Loss: 0.009624, Val Loss: 0.003831
# Epoch 14/2000, Train Loss: 0.007328, Val Loss: 0.004714
# Epoch 15/2000, Train Loss: 0.007900, Val Loss: 0.004545
# Epoch 16/2000, Train Loss: 0.007472, Val Loss: 0.004349
# Epoch 17/2000, Train Loss: 0.006924, Val Loss: 0.004414
# Epoch 18/2000, Train Loss: 0.006710, Val Loss: 0.004368
# Epoch 19/2000, Train Loss: 0.006423, Val Loss: 0.004339
# Epoch 20/2000, Train Loss: 0.006175, Val Loss: 0.004316
# Epoch 21/2000, Train Loss: 0.005963, Val Loss: 0.004277
# Epoch 22/2000, Train Loss: 0.005756, Val Loss: 0.004246
# Epoch 23/2000, Train Loss: 0.005572, Val Loss: 0.004214
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.0, 'early_stopping_patience': 10, 'hidden_size': 50, 'learning_rate': 0.001, 'num_epochs': 2000, 'num_layers': 2, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.383129, Val Loss: 0.025364
# Epoch 2/2000, Train Loss: 0.111282, Val Loss: 0.017980
# Epoch 3/2000, Train Loss: 0.086702, Val Loss: 0.015297
# Epoch 4/2000, Train Loss: 0.081433, Val Loss: 0.033157
# Epoch 5/2000, Train Loss: 0.049185, Val Loss: 0.023033
# Epoch 6/2000, Train Loss: 0.047743, Val Loss: 0.016189
# Epoch 7/2000, Train Loss: 0.044836, Val Loss: 0.017844
# Epoch 8/2000, Train Loss: 0.034129, Val Loss: 0.011063
# Epoch 9/2000, Train Loss: 0.023049, Val Loss: 0.004864
# Epoch 10/2000, Train Loss: 0.007783, Val Loss: 0.009394
# Epoch 11/2000, Train Loss: 0.011168, Val Loss: 0.008011
# Epoch 12/2000, Train Loss: 0.018685, Val Loss: 0.003376
# Epoch 13/2000, Train Loss: 0.006264, Val Loss: 0.004435
# Epoch 14/2000, Train Loss: 0.005538, Val Loss: 0.009253
# Epoch 15/2000, Train Loss: 0.009427, Val Loss: 0.004961
# Epoch 16/2000, Train Loss: 0.009536, Val Loss: 0.003218
# Epoch 17/2000, Train Loss: 0.004921, Val Loss: 0.006106
# Epoch 18/2000, Train Loss: 0.005794, Val Loss: 0.007000
# Epoch 19/2000, Train Loss: 0.008251, Val Loss: 0.004104
# Epoch 20/2000, Train Loss: 0.006525, Val Loss: 0.004152
# Epoch 21/2000, Train Loss: 0.004878, Val Loss: 0.006151
# Epoch 22/2000, Train Loss: 0.005898, Val Loss: 0.005622
# Epoch 23/2000, Train Loss: 0.007170, Val Loss: 0.003978
# Epoch 24/2000, Train Loss: 0.005451, Val Loss: 0.004634
# Epoch 25/2000, Train Loss: 0.004816, Val Loss: 0.005765
# Epoch 26/2000, Train Loss: 0.005922, Val Loss: 0.004817
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.0, 'early_stopping_patience': 10, 'hidden_size': 50, 'learning_rate': 0.001, 'num_epochs': 2000, 'num_layers': 3, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.386692, Val Loss: 0.022070
# Epoch 2/2000, Train Loss: 0.111192, Val Loss: 0.015300
# Epoch 3/2000, Train Loss: 0.114347, Val Loss: 0.022544
# Epoch 4/2000, Train Loss: 0.104341, Val Loss: 0.032400
# Epoch 5/2000, Train Loss: 0.068464, Val Loss: 0.034935
# Epoch 6/2000, Train Loss: 0.061630, Val Loss: 0.021156
# Epoch 7/2000, Train Loss: 0.065523, Val Loss: 0.025469
# Epoch 8/2000, Train Loss: 0.057535, Val Loss: 0.022225
# Epoch 9/2000, Train Loss: 0.049185, Val Loss: 0.015101
# Epoch 10/2000, Train Loss: 0.026003, Val Loss: 0.009253
# Epoch 11/2000, Train Loss: 0.043092, Val Loss: 0.010787
# Epoch 12/2000, Train Loss: 0.005937, Val Loss: 0.017007
# Epoch 13/2000, Train Loss: 0.017724, Val Loss: 0.008524
# Epoch 14/2000, Train Loss: 0.021739, Val Loss: 0.004261
# Epoch 15/2000, Train Loss: 0.005509, Val Loss: 0.014021
# Epoch 16/2000, Train Loss: 0.010617, Val Loss: 0.008431
# Epoch 17/2000, Train Loss: 0.014004, Val Loss: 0.004482
# Epoch 18/2000, Train Loss: 0.005833, Val Loss: 0.011356
# Epoch 19/2000, Train Loss: 0.008582, Val Loss: 0.008043
# Epoch 20/2000, Train Loss: 0.011773, Val Loss: 0.004910
# Epoch 21/2000, Train Loss: 0.005797, Val Loss: 0.010049
# Epoch 22/2000, Train Loss: 0.007606, Val Loss: 0.007750
# Epoch 23/2000, Train Loss: 0.011064, Val Loss: 0.004819
# Epoch 24/2000, Train Loss: 0.005647, Val Loss: 0.009099
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.0, 'early_stopping_patience': 10, 'hidden_size': 50, 'learning_rate': 0.0001, 'num_epochs': 2000, 'num_layers': 1, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.305593, Val Loss: 0.142895
# Epoch 2/2000, Train Loss: 0.289602, Val Loss: 0.132189
# Epoch 3/2000, Train Loss: 0.274583, Val Loss: 0.121846
# Epoch 4/2000, Train Loss: 0.259772, Val Loss: 0.111688
# Epoch 5/2000, Train Loss: 0.244927, Val Loss: 0.101590
# Epoch 6/2000, Train Loss: 0.229839, Val Loss: 0.091438
# Epoch 7/2000, Train Loss: 0.214298, Val Loss: 0.081135
# Epoch 8/2000, Train Loss: 0.198083, Val Loss: 0.070600
# Epoch 9/2000, Train Loss: 0.180965, Val Loss: 0.059785
# Epoch 10/2000, Train Loss: 0.162721, Val Loss: 0.048708
# Epoch 11/2000, Train Loss: 0.143150, Val Loss: 0.037526
# Epoch 12/2000, Train Loss: 0.122169, Val Loss: 0.026719
# Epoch 13/2000, Train Loss: 0.100048, Val Loss: 0.017471
# Epoch 14/2000, Train Loss: 0.078020, Val Loss: 0.012304
# Epoch 15/2000, Train Loss: 0.059236, Val Loss: 0.014589
# Epoch 16/2000, Train Loss: 0.047608, Val Loss: 0.021653
# Epoch 17/2000, Train Loss: 0.042022, Val Loss: 0.023279
# Epoch 18/2000, Train Loss: 0.039422, Val Loss: 0.021244
# Epoch 19/2000, Train Loss: 0.038305, Val Loss: 0.019882
# Epoch 20/2000, Train Loss: 0.037322, Val Loss: 0.019331
# Epoch 21/2000, Train Loss: 0.036131, Val Loss: 0.018960
# Epoch 22/2000, Train Loss: 0.034866, Val Loss: 0.018477
# Epoch 23/2000, Train Loss: 0.033625, Val Loss: 0.017885
# Epoch 24/2000, Train Loss: 0.032418, Val Loss: 0.017253
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.0, 'early_stopping_patience': 10, 'hidden_size': 50, 'learning_rate': 0.0001, 'num_epochs': 2000, 'num_layers': 2, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.327047, Val Loss: 0.155606
# Epoch 2/2000, Train Loss: 0.301132, Val Loss: 0.137090
# Epoch 3/2000, Train Loss: 0.276098, Val Loss: 0.118814
# Epoch 4/2000, Train Loss: 0.250677, Val Loss: 0.100397
# Epoch 5/2000, Train Loss: 0.224242, Val Loss: 0.081548
# Epoch 6/2000, Train Loss: 0.196167, Val Loss: 0.062190
# Epoch 7/2000, Train Loss: 0.166033, Val Loss: 0.042897
# Epoch 8/2000, Train Loss: 0.134248, Val Loss: 0.025789
# Epoch 9/2000, Train Loss: 0.103287, Val Loss: 0.015570
# Epoch 10/2000, Train Loss: 0.078535, Val Loss: 0.017125
# Epoch 11/2000, Train Loss: 0.064318, Val Loss: 0.025284
# Epoch 12/2000, Train Loss: 0.057977, Val Loss: 0.028689
# Epoch 13/2000, Train Loss: 0.055170, Val Loss: 0.027713
# Epoch 14/2000, Train Loss: 0.053877, Val Loss: 0.026326
# Epoch 15/2000, Train Loss: 0.053012, Val Loss: 0.025566
# Epoch 16/2000, Train Loss: 0.052112, Val Loss: 0.025211
# Epoch 17/2000, Train Loss: 0.051133, Val Loss: 0.024967
# Epoch 18/2000, Train Loss: 0.050125, Val Loss: 0.024697
# Epoch 19/2000, Train Loss: 0.049122, Val Loss: 0.024379
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.0, 'early_stopping_patience': 10, 'hidden_size': 50, 'learning_rate': 0.0001, 'num_epochs': 2000, 'num_layers': 3, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.504315, Val Loss: 0.286459
# Epoch 2/2000, Train Loss: 0.460359, Val Loss: 0.251086
# Epoch 3/2000, Train Loss: 0.414779, Val Loss: 0.213111
# Epoch 4/2000, Train Loss: 0.363918, Val Loss: 0.170324
# Epoch 5/2000, Train Loss: 0.304211, Val Loss: 0.120440
# Epoch 6/2000, Train Loss: 0.231751, Val Loss: 0.063863
# Epoch 7/2000, Train Loss: 0.148690, Val Loss: 0.018172
# Epoch 8/2000, Train Loss: 0.083582, Val Loss: 0.025048
# Epoch 9/2000, Train Loss: 0.059285, Val Loss: 0.034524
# Epoch 10/2000, Train Loss: 0.052498, Val Loss: 0.025784
# Epoch 11/2000, Train Loss: 0.052999, Val Loss: 0.022841
# Epoch 12/2000, Train Loss: 0.053268, Val Loss: 0.023208
# Epoch 13/2000, Train Loss: 0.052254, Val Loss: 0.023680
# Epoch 14/2000, Train Loss: 0.051094, Val Loss: 0.023446
# Epoch 15/2000, Train Loss: 0.050170, Val Loss: 0.022951
# Epoch 16/2000, Train Loss: 0.049364, Val Loss: 0.022526
# Epoch 17/2000, Train Loss: 0.048540, Val Loss: 0.022170
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.0, 'early_stopping_patience': 10, 'hidden_size': 100, 'learning_rate': 0.001, 'num_epochs': 2000, 'num_layers': 1, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.363307, Val Loss: 0.031346
# Epoch 2/2000, Train Loss: 0.067445, Val Loss: 0.018863
# Epoch 3/2000, Train Loss: 0.116996, Val Loss: 0.021987
# Epoch 4/2000, Train Loss: 0.085829, Val Loss: 0.024023
# Epoch 5/2000, Train Loss: 0.049261, Val Loss: 0.026521
# Epoch 6/2000, Train Loss: 0.041394, Val Loss: 0.014133
# Epoch 7/2000, Train Loss: 0.042942, Val Loss: 0.018263
# Epoch 8/2000, Train Loss: 0.035103, Val Loss: 0.014680
# Epoch 9/2000, Train Loss: 0.031650, Val Loss: 0.012084
# Epoch 10/2000, Train Loss: 0.026296, Val Loss: 0.009169
# Epoch 11/2000, Train Loss: 0.019919, Val Loss: 0.005110
# Epoch 12/2000, Train Loss: 0.011029, Val Loss: 0.003833
# Epoch 13/2000, Train Loss: 0.008761, Val Loss: 0.006508
# Epoch 14/2000, Train Loss: 0.011603, Val Loss: 0.003807
# Epoch 15/2000, Train Loss: 0.010623, Val Loss: 0.002486
# Epoch 16/2000, Train Loss: 0.004871, Val Loss: 0.004335
# Epoch 17/2000, Train Loss: 0.004971, Val Loss: 0.006020
# Epoch 18/2000, Train Loss: 0.007448, Val Loss: 0.003838
# Epoch 19/2000, Train Loss: 0.007956, Val Loss: 0.002537
# Epoch 20/2000, Train Loss: 0.004421, Val Loss: 0.003964
# Epoch 21/2000, Train Loss: 0.004347, Val Loss: 0.005250
# Epoch 22/2000, Train Loss: 0.006060, Val Loss: 0.003722
# Epoch 23/2000, Train Loss: 0.006624, Val Loss: 0.002640
# Epoch 24/2000, Train Loss: 0.004230, Val Loss: 0.003669
# Epoch 25/2000, Train Loss: 0.004023, Val Loss: 0.004628
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.0, 'early_stopping_patience': 10, 'hidden_size': 100, 'learning_rate': 0.001, 'num_epochs': 2000, 'num_layers': 2, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.233163, Val Loss: 0.024790
# Epoch 2/2000, Train Loss: 0.078758, Val Loss: 0.024944
# Epoch 3/2000, Train Loss: 0.064848, Val Loss: 0.022943
# Epoch 4/2000, Train Loss: 0.056230, Val Loss: 0.019816
# Epoch 5/2000, Train Loss: 0.044721, Val Loss: 0.013016
# Epoch 6/2000, Train Loss: 0.024229, Val Loss: 0.006005
# Epoch 7/2000, Train Loss: 0.027272, Val Loss: 0.004113
# Epoch 8/2000, Train Loss: 0.005373, Val Loss: 0.007635
# Epoch 9/2000, Train Loss: 0.008154, Val Loss: 0.008450
# Epoch 10/2000, Train Loss: 0.021418, Val Loss: 0.003536
# Epoch 11/2000, Train Loss: 0.005518, Val Loss: 0.004737
# Epoch 12/2000, Train Loss: 0.006569, Val Loss: 0.007917
# Epoch 13/2000, Train Loss: 0.012037, Val Loss: 0.002976
# Epoch 14/2000, Train Loss: 0.010750, Val Loss: 0.002960
# Epoch 15/2000, Train Loss: 0.005969, Val Loss: 0.005132
# Epoch 16/2000, Train Loss: 0.006296, Val Loss: 0.004867
# Epoch 17/2000, Train Loss: 0.019060, Val Loss: 0.004791
# Epoch 18/2000, Train Loss: 0.004253, Val Loss: 0.005351
# Epoch 19/2000, Train Loss: 0.004829, Val Loss: 0.006868
# Epoch 20/2000, Train Loss: 0.014863, Val Loss: 0.002787
# Epoch 21/2000, Train Loss: 0.003860, Val Loss: 0.003793
# Epoch 22/2000, Train Loss: 0.004317, Val Loss: 0.006582
# Epoch 23/2000, Train Loss: 0.009472, Val Loss: 0.002111
# Epoch 24/2000, Train Loss: 0.005254, Val Loss: 0.002751
# Epoch 25/2000, Train Loss: 0.003897, Val Loss: 0.005315
# Epoch 26/2000, Train Loss: 0.005888, Val Loss: 0.002844
# Epoch 27/2000, Train Loss: 0.007810, Val Loss: 0.002258
# Epoch 28/2000, Train Loss: 0.003675, Val Loss: 0.004065
# Epoch 29/2000, Train Loss: 0.003978, Val Loss: 0.004028
# Epoch 30/2000, Train Loss: 0.010135, Val Loss: 0.002120
# Epoch 31/2000, Train Loss: 0.003507, Val Loss: 0.003349
# Epoch 32/2000, Train Loss: 0.003568, Val Loss: 0.004866
# Epoch 33/2000, Train Loss: 0.009586, Val Loss: 0.001863
# Epoch 34/2000, Train Loss: 0.003815, Val Loss: 0.002766
# Epoch 35/2000, Train Loss: 0.003606, Val Loss: 0.004677
# Epoch 36/2000, Train Loss: 0.006736, Val Loss: 0.001951
# Epoch 37/2000, Train Loss: 0.005320, Val Loss: 0.002245
# Epoch 38/2000, Train Loss: 0.003492, Val Loss: 0.003705
# Epoch 39/2000, Train Loss: 0.004148, Val Loss: 0.002795
# Epoch 40/2000, Train Loss: 0.007679, Val Loss: 0.001974
# Epoch 41/2000, Train Loss: 0.003284, Val Loss: 0.002931
# Epoch 42/2000, Train Loss: 0.003190, Val Loss: 0.003802
# Epoch 43/2000, Train Loss: 0.008644, Val Loss: 0.001768
# Epoch 44/2000, Train Loss: 0.003269, Val Loss: 0.002540
# Epoch 45/2000, Train Loss: 0.003329, Val Loss: 0.004076
# Epoch 46/2000, Train Loss: 0.006773, Val Loss: 0.001652
# Epoch 47/2000, Train Loss: 0.004232, Val Loss: 0.002154
# Epoch 48/2000, Train Loss: 0.003351, Val Loss: 0.003407
# Epoch 49/2000, Train Loss: 0.004182, Val Loss: 0.002210
# Epoch 50/2000, Train Loss: 0.006218, Val Loss: 0.001881
# Epoch 51/2000, Train Loss: 0.003102, Val Loss: 0.002637
# Epoch 52/2000, Train Loss: 0.002942, Val Loss: 0.003140
# Epoch 53/2000, Train Loss: 0.007499, Val Loss: 0.001668
# Epoch 54/2000, Train Loss: 0.002940, Val Loss: 0.002287
# Epoch 55/2000, Train Loss: 0.003032, Val Loss: 0.003539
# Epoch 56/2000, Train Loss: 0.006281, Val Loss: 0.001502
# Epoch 57/2000, Train Loss: 0.003627, Val Loss: 0.002011
# Epoch 58/2000, Train Loss: 0.003152, Val Loss: 0.003054
# Epoch 59/2000, Train Loss: 0.003955, Val Loss: 0.001908
# Epoch 60/2000, Train Loss: 0.005310, Val Loss: 0.001770
# Epoch 61/2000, Train Loss: 0.002906, Val Loss: 0.002361
# Epoch 62/2000, Train Loss: 0.002706, Val Loss: 0.002729
# Epoch 63/2000, Train Loss: 0.006558, Val Loss: 0.001549
# Epoch 64/2000, Train Loss: 0.002692, Val Loss: 0.002053
# Epoch 65/2000, Train Loss: 0.002783, Val Loss: 0.003112
# Epoch 66/2000, Train Loss: 0.005598, Val Loss: 0.001391
# Epoch 67/2000, Train Loss: 0.003300, Val Loss: 0.001852
# Epoch 68/2000, Train Loss: 0.002923, Val Loss: 0.002650
# Epoch 69/2000, Train Loss: 0.003493, Val Loss: 0.001772
# Epoch 70/2000, Train Loss: 0.004802, Val Loss: 0.001632
# Epoch 71/2000, Train Loss: 0.002670, Val Loss: 0.002043
# Epoch 72/2000, Train Loss: 0.002437, Val Loss: 0.002527
# Epoch 73/2000, Train Loss: 0.005901, Val Loss: 0.001397
# Epoch 74/2000, Train Loss: 0.002496, Val Loss: 0.001845
# Epoch 75/2000, Train Loss: 0.002633, Val Loss: 0.002776
# Epoch 76/2000, Train Loss: 0.004769, Val Loss: 0.001310
# Epoch 77/2000, Train Loss: 0.003226, Val Loss: 0.001700
# Epoch 78/2000, Train Loss: 0.002743, Val Loss: 0.002258
# Epoch 79/2000, Train Loss: 0.002898, Val Loss: 0.001772
# Epoch 80/2000, Train Loss: 0.004729, Val Loss: 0.001498
# Epoch 81/2000, Train Loss: 0.002445, Val Loss: 0.001774
# Epoch 82/2000, Train Loss: 0.002227, Val Loss: 0.002455
# Epoch 83/2000, Train Loss: 0.005468, Val Loss: 0.001264
# Epoch 84/2000, Train Loss: 0.002341, Val Loss: 0.001686
# Epoch 85/2000, Train Loss: 0.002567, Val Loss: 0.002532
# Epoch 86/2000, Train Loss: 0.004077, Val Loss: 0.001258
# Epoch 87/2000, Train Loss: 0.003251, Val Loss: 0.001568
# Epoch 88/2000, Train Loss: 0.002573, Val Loss: 0.001946
# Epoch 89/2000, Train Loss: 0.002376, Val Loss: 0.001839
# Epoch 90/2000, Train Loss: 0.004749, Val Loss: 0.001355
# Epoch 91/2000, Train Loss: 0.002189, Val Loss: 0.001589
# Epoch 92/2000, Train Loss: 0.002124, Val Loss: 0.002414
# Epoch 93/2000, Train Loss: 0.004901, Val Loss: 0.001129
# Epoch 94/2000, Train Loss: 0.002287, Val Loss: 0.001556
# Epoch 95/2000, Train Loss: 0.002495, Val Loss: 0.002217
# Epoch 96/2000, Train Loss: 0.003161, Val Loss: 0.001316
# Epoch 97/2000, Train Loss: 0.003509, Val Loss: 0.001421
# Epoch 98/2000, Train Loss: 0.002300, Val Loss: 0.001637
# Epoch 99/2000, Train Loss: 0.001945, Val Loss: 0.002002
# Epoch 100/2000, Train Loss: 0.004715, Val Loss: 0.001184
# Epoch 101/2000, Train Loss: 0.001955, Val Loss: 0.001468
# Epoch 102/2000, Train Loss: 0.002155, Val Loss: 0.002290
# Epoch 103/2000, Train Loss: 0.004002, Val Loss: 0.001068
# Epoch 104/2000, Train Loss: 0.002490, Val Loss: 0.001442
# Epoch 105/2000, Train Loss: 0.002361, Val Loss: 0.001821
# Epoch 106/2000, Train Loss: 0.002256, Val Loss: 0.001522
# Epoch 107/2000, Train Loss: 0.003919, Val Loss: 0.001262
# Epoch 108/2000, Train Loss: 0.001966, Val Loss: 0.001403
# Epoch 109/2000, Train Loss: 0.001809, Val Loss: 0.002132
# Epoch 110/2000, Train Loss: 0.004357, Val Loss: 0.001028
# Epoch 111/2000, Train Loss: 0.001912, Val Loss: 0.001399
# Epoch 112/2000, Train Loss: 0.002221, Val Loss: 0.001994
# Epoch 113/2000, Train Loss: 0.002875, Val Loss: 0.001165
# Epoch 114/2000, Train Loss: 0.002979, Val Loss: 0.001306
# Epoch 115/2000, Train Loss: 0.002079, Val Loss: 0.001441
# Epoch 116/2000, Train Loss: 0.001705, Val Loss: 0.001798
# Epoch 117/2000, Train Loss: 0.004134, Val Loss: 0.001074
# Epoch 118/2000, Train Loss: 0.001720, Val Loss: 0.001312
# Epoch 119/2000, Train Loss: 0.001956, Val Loss: 0.002037
# Epoch 120/2000, Train Loss: 0.003446, Val Loss: 0.000982
# Epoch 121/2000, Train Loss: 0.002270, Val Loss: 0.001317
# Epoch 122/2000, Train Loss: 0.002141, Val Loss: 0.001546
# Epoch 123/2000, Train Loss: 0.001884, Val Loss: 0.001463
# Epoch 124/2000, Train Loss: 0.003620, Val Loss: 0.001124
# Epoch 125/2000, Train Loss: 0.001733, Val Loss: 0.001239
# Epoch 126/2000, Train Loss: 0.001705, Val Loss: 0.001953
# Epoch 127/2000, Train Loss: 0.003732, Val Loss: 0.000921
# Epoch 128/2000, Train Loss: 0.001861, Val Loss: 0.001294
# Epoch 129/2000, Train Loss: 0.002100, Val Loss: 0.001639
# Epoch 130/2000, Train Loss: 0.002198, Val Loss: 0.001219
# Epoch 131/2000, Train Loss: 0.003080, Val Loss: 0.001160
# Epoch 132/2000, Train Loss: 0.001810, Val Loss: 0.001202
# Epoch 133/2000, Train Loss: 0.001556, Val Loss: 0.001792
# Epoch 134/2000, Train Loss: 0.003771, Val Loss: 0.000920
# Epoch 135/2000, Train Loss: 0.001655, Val Loss: 0.001249
# Epoch 136/2000, Train Loss: 0.002013, Val Loss: 0.001699
# Epoch 137/2000, Train Loss: 0.002523, Val Loss: 0.001054
# Epoch 138/2000, Train Loss: 0.002658, Val Loss: 0.001186
# Epoch 139/2000, Train Loss: 0.001898, Val Loss: 0.001213
# Epoch 140/2000, Train Loss: 0.001521, Val Loss: 0.001641
# Epoch 141/2000, Train Loss: 0.003680, Val Loss: 0.000939
# Epoch 142/2000, Train Loss: 0.001583, Val Loss: 0.001203
# Epoch 143/2000, Train Loss: 0.001906, Val Loss: 0.001719
# Epoch 144/2000, Train Loss: 0.002790, Val Loss: 0.000956
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.0, 'early_stopping_patience': 10, 'hidden_size': 100, 'learning_rate': 0.001, 'num_epochs': 2000, 'num_layers': 3, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.256072, Val Loss: 0.015128
# Epoch 2/2000, Train Loss: 0.120000, Val Loss: 0.015688
# Epoch 3/2000, Train Loss: 0.102718, Val Loss: 0.040054
# Epoch 4/2000, Train Loss: 0.066197, Val Loss: 0.018250
# Epoch 5/2000, Train Loss: 0.070465, Val Loss: 0.026728
# Epoch 6/2000, Train Loss: 0.052165, Val Loss: 0.014149
# Epoch 7/2000, Train Loss: 0.036248, Val Loss: 0.021049
# Epoch 8/2000, Train Loss: 0.085459, Val Loss: 0.016686
# Epoch 9/2000, Train Loss: 0.042420, Val Loss: 0.017030
# Epoch 10/2000, Train Loss: 0.029258, Val Loss: 0.005361
# Epoch 11/2000, Train Loss: 0.010019, Val Loss: 0.005703
# Epoch 12/2000, Train Loss: 0.006737, Val Loss: 0.008347
# Epoch 13/2000, Train Loss: 0.008326, Val Loss: 0.006069
# Epoch 14/2000, Train Loss: 0.017630, Val Loss: 0.003783
# Epoch 15/2000, Train Loss: 0.005433, Val Loss: 0.008421
# Epoch 16/2000, Train Loss: 0.006978, Val Loss: 0.007245
# Epoch 17/2000, Train Loss: 0.017354, Val Loss: 0.003672
# Epoch 18/2000, Train Loss: 0.004970, Val Loss: 0.007772
# Epoch 19/2000, Train Loss: 0.006107, Val Loss: 0.007620
# Epoch 20/2000, Train Loss: 0.014905, Val Loss: 0.003176
# Epoch 21/2000, Train Loss: 0.004758, Val Loss: 0.006813
# Epoch 22/2000, Train Loss: 0.005485, Val Loss: 0.007624
# Epoch 23/2000, Train Loss: 0.013067, Val Loss: 0.002904
# Epoch 24/2000, Train Loss: 0.004761, Val Loss: 0.005939
# Epoch 25/2000, Train Loss: 0.005014, Val Loss: 0.007556
# Epoch 26/2000, Train Loss: 0.011751, Val Loss: 0.002777
# Epoch 27/2000, Train Loss: 0.004951, Val Loss: 0.005171
# Epoch 28/2000, Train Loss: 0.004659, Val Loss: 0.007438
# Epoch 29/2000, Train Loss: 0.010590, Val Loss: 0.002756
# Epoch 30/2000, Train Loss: 0.005403, Val Loss: 0.004477
# Epoch 31/2000, Train Loss: 0.004424, Val Loss: 0.007181
# Epoch 32/2000, Train Loss: 0.009289, Val Loss: 0.002903
# Epoch 33/2000, Train Loss: 0.006320, Val Loss: 0.003824
# Epoch 34/2000, Train Loss: 0.004330, Val Loss: 0.006655
# Epoch 35/2000, Train Loss: 0.007692, Val Loss: 0.003358
# Epoch 36/2000, Train Loss: 0.008021, Val Loss: 0.003223
# Epoch 37/2000, Train Loss: 0.004377, Val Loss: 0.005820
# Epoch 38/2000, Train Loss: 0.005958, Val Loss: 0.004266
# Epoch 39/2000, Train Loss: 0.010599, Val Loss: 0.002779
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.0, 'early_stopping_patience': 10, 'hidden_size': 100, 'learning_rate': 0.0001, 'num_epochs': 2000, 'num_layers': 1, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.570939, Val Loss: 0.336796
# Epoch 2/2000, Train Loss: 0.527519, Val Loss: 0.305448
# Epoch 3/2000, Train Loss: 0.487437, Val Loss: 0.275477
# Epoch 4/2000, Train Loss: 0.448039, Val Loss: 0.245593
# Epoch 5/2000, Train Loss: 0.407605, Val Loss: 0.214583
# Epoch 6/2000, Train Loss: 0.364297, Val Loss: 0.181079
# Epoch 7/2000, Train Loss: 0.315777, Val Loss: 0.143347
# Epoch 8/2000, Train Loss: 0.258683, Val Loss: 0.099129
# Epoch 9/2000, Train Loss: 0.188064, Val Loss: 0.047089
# Epoch 10/2000, Train Loss: 0.102328, Val Loss: 0.008568
# Epoch 11/2000, Train Loss: 0.043163, Val Loss: 0.017132
# Epoch 12/2000, Train Loss: 0.028639, Val Loss: 0.009294
# Epoch 13/2000, Train Loss: 0.031312, Val Loss: 0.012603
# Epoch 14/2000, Train Loss: 0.025719, Val Loss: 0.011334
# Epoch 15/2000, Train Loss: 0.024272, Val Loss: 0.009840
# Epoch 16/2000, Train Loss: 0.023283, Val Loss: 0.009511
# Epoch 17/2000, Train Loss: 0.021398, Val Loss: 0.008661
# Epoch 18/2000, Train Loss: 0.020130, Val Loss: 0.007942
# Epoch 19/2000, Train Loss: 0.018842, Val Loss: 0.007320
# Epoch 20/2000, Train Loss: 0.017605, Val Loss: 0.006728
# Epoch 21/2000, Train Loss: 0.016522, Val Loss: 0.006234
# Epoch 22/2000, Train Loss: 0.015515, Val Loss: 0.005825
# Epoch 23/2000, Train Loss: 0.014644, Val Loss: 0.005517
# Epoch 24/2000, Train Loss: 0.013879, Val Loss: 0.005306
# Epoch 25/2000, Train Loss: 0.013242, Val Loss: 0.005188
# Epoch 26/2000, Train Loss: 0.012708, Val Loss: 0.005151
# Epoch 27/2000, Train Loss: 0.012285, Val Loss: 0.005179
# Epoch 28/2000, Train Loss: 0.011939, Val Loss: 0.005257
# Epoch 29/2000, Train Loss: 0.011677, Val Loss: 0.005362
# Epoch 30/2000, Train Loss: 0.011458, Val Loss: 0.005489
# Epoch 31/2000, Train Loss: 0.011301, Val Loss: 0.005611
# Epoch 32/2000, Train Loss: 0.011149, Val Loss: 0.005743
# Epoch 33/2000, Train Loss: 0.011056, Val Loss: 0.005843
# Epoch 34/2000, Train Loss: 0.010929, Val Loss: 0.005963
# Epoch 35/2000, Train Loss: 0.010883, Val Loss: 0.006020
# Epoch 36/2000, Train Loss: 0.010742, Val Loss: 0.006136
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.0, 'early_stopping_patience': 10, 'hidden_size': 100, 'learning_rate': 0.0001, 'num_epochs': 2000, 'num_layers': 2, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.389845, Val Loss: 0.189305
# Epoch 2/2000, Train Loss: 0.338473, Val Loss: 0.151629
# Epoch 3/2000, Train Loss: 0.287682, Val Loss: 0.112033
# Epoch 4/2000, Train Loss: 0.230976, Val Loss: 0.068005
# Epoch 5/2000, Train Loss: 0.165110, Val Loss: 0.025472
# Epoch 6/2000, Train Loss: 0.103076, Val Loss: 0.021876
# Epoch 7/2000, Train Loss: 0.071080, Val Loss: 0.038193
# Epoch 8/2000, Train Loss: 0.057895, Val Loss: 0.026556
# Epoch 9/2000, Train Loss: 0.057879, Val Loss: 0.023840
# Epoch 10/2000, Train Loss: 0.056893, Val Loss: 0.024669
# Epoch 11/2000, Train Loss: 0.054394, Val Loss: 0.024827
# Epoch 12/2000, Train Loss: 0.052021, Val Loss: 0.023957
# Epoch 13/2000, Train Loss: 0.050027, Val Loss: 0.023026
# Epoch 14/2000, Train Loss: 0.048058, Val Loss: 0.022254
# Epoch 15/2000, Train Loss: 0.045949, Val Loss: 0.021449
# Epoch 16/2000, Train Loss: 0.043716, Val Loss: 0.020525
# Epoch 17/2000, Train Loss: 0.041387, Val Loss: 0.019492
# Epoch 18/2000, Train Loss: 0.038925, Val Loss: 0.018354
# Epoch 19/2000, Train Loss: 0.036298, Val Loss: 0.017099
# Epoch 20/2000, Train Loss: 0.033481, Val Loss: 0.015688
# Epoch 21/2000, Train Loss: 0.030469, Val Loss: 0.014115
# Epoch 22/2000, Train Loss: 0.027254, Val Loss: 0.012368
# Epoch 23/2000, Train Loss: 0.023864, Val Loss: 0.010468
# Epoch 24/2000, Train Loss: 0.020395, Val Loss: 0.008520
# Epoch 25/2000, Train Loss: 0.017072, Val Loss: 0.006786
# Epoch 26/2000, Train Loss: 0.014301, Val Loss: 0.005681
# Epoch 27/2000, Train Loss: 0.012553, Val Loss: 0.005447
# Epoch 28/2000, Train Loss: 0.011872, Val Loss: 0.005709
# Epoch 29/2000, Train Loss: 0.011688, Val Loss: 0.005980
# Epoch 30/2000, Train Loss: 0.011575, Val Loss: 0.006091
# Epoch 31/2000, Train Loss: 0.011361, Val Loss: 0.006139
# Epoch 32/2000, Train Loss: 0.011194, Val Loss: 0.006097
# Epoch 33/2000, Train Loss: 0.010902, Val Loss: 0.006157
# Epoch 34/2000, Train Loss: 0.010848, Val Loss: 0.006022
# Epoch 35/2000, Train Loss: 0.010428, Val Loss: 0.006237
# Epoch 36/2000, Train Loss: 0.010670, Val Loss: 0.005860
# Epoch 37/2000, Train Loss: 0.009873, Val Loss: 0.006497
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.0, 'early_stopping_patience': 10, 'hidden_size': 100, 'learning_rate': 0.0001, 'num_epochs': 2000, 'num_layers': 3, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.479785, Val Loss: 0.253751
# Epoch 2/2000, Train Loss: 0.411581, Val Loss: 0.200066
# Epoch 3/2000, Train Loss: 0.339243, Val Loss: 0.137259
# Epoch 4/2000, Train Loss: 0.247596, Val Loss: 0.058713
# Epoch 5/2000, Train Loss: 0.137406, Val Loss: 0.017027
# Epoch 6/2000, Train Loss: 0.076271, Val Loss: 0.045515
# Epoch 7/2000, Train Loss: 0.052669, Val Loss: 0.020816
# Epoch 8/2000, Train Loss: 0.058640, Val Loss: 0.021857
# Epoch 9/2000, Train Loss: 0.056505, Val Loss: 0.025157
# Epoch 10/2000, Train Loss: 0.052836, Val Loss: 0.023825
# Epoch 11/2000, Train Loss: 0.051167, Val Loss: 0.022318
# Epoch 12/2000, Train Loss: 0.049730, Val Loss: 0.021799
# Epoch 13/2000, Train Loss: 0.047675, Val Loss: 0.021095
# Epoch 14/2000, Train Loss: 0.045463, Val Loss: 0.020050
# Epoch 15/2000, Train Loss: 0.043163, Val Loss: 0.018926
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.2, 'early_stopping_patience': 10, 'hidden_size': 50, 'learning_rate': 0.001, 'num_epochs': 2000, 'num_layers': 1, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.352326, Val Loss: 0.079835
# Epoch 2/2000, Train Loss: 0.133664, Val Loss: 0.038807
# Epoch 3/2000, Train Loss: 0.039068, Val Loss: 0.014452
# Epoch 4/2000, Train Loss: 0.041914, Val Loss: 0.014709
# Epoch 5/2000, Train Loss: 0.036388, Val Loss: 0.014806
# Epoch 6/2000, Train Loss: 0.031265, Val Loss: 0.011503
# Epoch 7/2000, Train Loss: 0.027626, Val Loss: 0.010127
# Epoch 8/2000, Train Loss: 0.022524, Val Loss: 0.007554
# Epoch 9/2000, Train Loss: 0.017801, Val Loss: 0.005230
# Epoch 10/2000, Train Loss: 0.012831, Val Loss: 0.003343
# Epoch 11/2000, Train Loss: 0.008878, Val Loss: 0.003498
# Epoch 12/2000, Train Loss: 0.007702, Val Loss: 0.005263
# Epoch 13/2000, Train Loss: 0.008763, Val Loss: 0.005079
# Epoch 14/2000, Train Loss: 0.008946, Val Loss: 0.003891
# Epoch 15/2000, Train Loss: 0.007298, Val Loss: 0.003925
# Epoch 16/2000, Train Loss: 0.006616, Val Loss: 0.004364
# Epoch 17/2000, Train Loss: 0.006731, Val Loss: 0.004319
# Epoch 18/2000, Train Loss: 0.006595, Val Loss: 0.004114
# Epoch 19/2000, Train Loss: 0.006259, Val Loss: 0.004063
# Epoch 20/2000, Train Loss: 0.006032, Val Loss: 0.004056
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.2, 'early_stopping_patience': 10, 'hidden_size': 50, 'learning_rate': 0.001, 'num_epochs': 2000, 'num_layers': 2, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.296563, Val Loss: 0.022690
# Epoch 2/2000, Train Loss: 0.113387, Val Loss: 0.033921
# Epoch 3/2000, Train Loss: 0.060256, Val Loss: 0.012125
# Epoch 4/2000, Train Loss: 0.065748, Val Loss: 0.025690
# Epoch 5/2000, Train Loss: 0.043126, Val Loss: 0.020575
# Epoch 6/2000, Train Loss: 0.035845, Val Loss: 0.013251
# Epoch 7/2000, Train Loss: 0.021863, Val Loss: 0.005651
# Epoch 8/2000, Train Loss: 0.014830, Val Loss: 0.005772
# Epoch 9/2000, Train Loss: 0.013855, Val Loss: 0.005374
# Epoch 10/2000, Train Loss: 0.012335, Val Loss: 0.004030
# Epoch 11/2000, Train Loss: 0.008901, Val Loss: 0.005084
# Epoch 12/2000, Train Loss: 0.009308, Val Loss: 0.004834
# Epoch 13/2000, Train Loss: 0.008971, Val Loss: 0.004562
# Epoch 14/2000, Train Loss: 0.008015, Val Loss: 0.005015
# Epoch 15/2000, Train Loss: 0.007982, Val Loss: 0.004555
# Epoch 16/2000, Train Loss: 0.007546, Val Loss: 0.005075
# Epoch 17/2000, Train Loss: 0.008015, Val Loss: 0.004244
# Epoch 18/2000, Train Loss: 0.007299, Val Loss: 0.004530
# Epoch 19/2000, Train Loss: 0.006625, Val Loss: 0.004384
# Epoch 20/2000, Train Loss: 0.006416, Val Loss: 0.005063
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.2, 'early_stopping_patience': 10, 'hidden_size': 50, 'learning_rate': 0.001, 'num_epochs': 2000, 'num_layers': 3, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.341753, Val Loss: 0.025319
# Epoch 2/2000, Train Loss: 0.120398, Val Loss: 0.019165
# Epoch 3/2000, Train Loss: 0.093681, Val Loss: 0.018735
# Epoch 4/2000, Train Loss: 0.093687, Val Loss: 0.024852
# Epoch 5/2000, Train Loss: 0.067920, Val Loss: 0.035650
# Epoch 6/2000, Train Loss: 0.056667, Val Loss: 0.020350
# Epoch 7/2000, Train Loss: 0.057279, Val Loss: 0.020813
# Epoch 8/2000, Train Loss: 0.043535, Val Loss: 0.011671
# Epoch 9/2000, Train Loss: 0.018956, Val Loss: 0.013360
# Epoch 10/2000, Train Loss: 0.039264, Val Loss: 0.007308
# Epoch 11/2000, Train Loss: 0.006760, Val Loss: 0.021326
# Epoch 12/2000, Train Loss: 0.023118, Val Loss: 0.004423
# Epoch 13/2000, Train Loss: 0.007972, Val Loss: 0.010721
# Epoch 14/2000, Train Loss: 0.010551, Val Loss: 0.010189
# Epoch 15/2000, Train Loss: 0.012038, Val Loss: 0.006678
# Epoch 16/2000, Train Loss: 0.007705, Val Loss: 0.010926
# Epoch 17/2000, Train Loss: 0.010058, Val Loss: 0.007560
# Epoch 18/2000, Train Loss: 0.008976, Val Loss: 0.008738
# Epoch 19/2000, Train Loss: 0.007782, Val Loss: 0.009120
# Epoch 20/2000, Train Loss: 0.009490, Val Loss: 0.006649
# Epoch 21/2000, Train Loss: 0.007184, Val Loss: 0.008981
# Epoch 22/2000, Train Loss: 0.007847, Val Loss: 0.007784
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.2, 'early_stopping_patience': 10, 'hidden_size': 50, 'learning_rate': 0.0001, 'num_epochs': 2000, 'num_layers': 1, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.451988, Val Loss: 0.244190
# Epoch 2/2000, Train Loss: 0.426477, Val Loss: 0.225791
# Epoch 3/2000, Train Loss: 0.401805, Val Loss: 0.207494
# Epoch 4/2000, Train Loss: 0.376919, Val Loss: 0.188896
# Epoch 5/2000, Train Loss: 0.351258, Val Loss: 0.169652
# Epoch 6/2000, Train Loss: 0.324301, Val Loss: 0.149477
# Epoch 7/2000, Train Loss: 0.295535, Val Loss: 0.128132
# Epoch 8/2000, Train Loss: 0.264429, Val Loss: 0.105471
# Epoch 9/2000, Train Loss: 0.230486, Val Loss: 0.081562
# Epoch 10/2000, Train Loss: 0.193368, Val Loss: 0.056982
# Epoch 11/2000, Train Loss: 0.153317, Val Loss: 0.033641
# Epoch 12/2000, Train Loss: 0.112459, Val Loss: 0.016646
# Epoch 13/2000, Train Loss: 0.077462, Val Loss: 0.014808
# Epoch 14/2000, Train Loss: 0.057364, Val Loss: 0.024913
# Epoch 15/2000, Train Loss: 0.049411, Val Loss: 0.026909
# Epoch 16/2000, Train Loss: 0.046437, Val Loss: 0.023863
# Epoch 17/2000, Train Loss: 0.045544, Val Loss: 0.022101
# Epoch 18/2000, Train Loss: 0.044785, Val Loss: 0.021561
# Epoch 19/2000, Train Loss: 0.043724, Val Loss: 0.021322
# Epoch 20/2000, Train Loss: 0.042569, Val Loss: 0.020974
# Epoch 21/2000, Train Loss: 0.041459, Val Loss: 0.020506
# Epoch 22/2000, Train Loss: 0.040410, Val Loss: 0.020000
# Epoch 23/2000, Train Loss: 0.039393, Val Loss: 0.019500
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.2, 'early_stopping_patience': 10, 'hidden_size': 50, 'learning_rate': 0.0001, 'num_epochs': 2000, 'num_layers': 2, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.264719, Val Loss: 0.109901
# Epoch 2/2000, Train Loss: 0.240277, Val Loss: 0.094175
# Epoch 3/2000, Train Loss: 0.217984, Val Loss: 0.079163
# Epoch 4/2000, Train Loss: 0.195997, Val Loss: 0.064505
# Epoch 5/2000, Train Loss: 0.172742, Val Loss: 0.050075
# Epoch 6/2000, Train Loss: 0.149181, Val Loss: 0.036252
# Epoch 7/2000, Train Loss: 0.124329, Val Loss: 0.024141
# Epoch 8/2000, Train Loss: 0.100694, Val Loss: 0.016036
# Epoch 9/2000, Train Loss: 0.079860, Val Loss: 0.014814
# Epoch 10/2000, Train Loss: 0.064861, Val Loss: 0.020324
# Epoch 11/2000, Train Loss: 0.056852, Val Loss: 0.026228
# Epoch 12/2000, Train Loss: 0.053725, Val Loss: 0.027965
# Epoch 13/2000, Train Loss: 0.051450, Val Loss: 0.027222
# Epoch 14/2000, Train Loss: 0.051658, Val Loss: 0.026276
# Epoch 15/2000, Train Loss: 0.049660, Val Loss: 0.025617
# Epoch 16/2000, Train Loss: 0.049013, Val Loss: 0.025259
# Epoch 17/2000, Train Loss: 0.048488, Val Loss: 0.025043
# Epoch 18/2000, Train Loss: 0.047662, Val Loss: 0.024716
# Epoch 19/2000, Train Loss: 0.046778, Val Loss: 0.024346
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.2, 'early_stopping_patience': 10, 'hidden_size': 50, 'learning_rate': 0.0001, 'num_epochs': 2000, 'num_layers': 3, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.297795, Val Loss: 0.133021
# Epoch 2/2000, Train Loss: 0.270590, Val Loss: 0.114256
# Epoch 3/2000, Train Loss: 0.244525, Val Loss: 0.095482
# Epoch 4/2000, Train Loss: 0.217098, Val Loss: 0.076000
# Epoch 5/2000, Train Loss: 0.187949, Val Loss: 0.055703
# Epoch 6/2000, Train Loss: 0.155296, Val Loss: 0.035620
# Epoch 7/2000, Train Loss: 0.121640, Val Loss: 0.019587
# Epoch 8/2000, Train Loss: 0.090760, Val Loss: 0.015123
# Epoch 9/2000, Train Loss: 0.069757, Val Loss: 0.023767
# Epoch 10/2000, Train Loss: 0.060348, Val Loss: 0.030023
# Epoch 11/2000, Train Loss: 0.056460, Val Loss: 0.028628
# Epoch 12/2000, Train Loss: 0.054176, Val Loss: 0.026610
# Epoch 13/2000, Train Loss: 0.052445, Val Loss: 0.025635
# Epoch 14/2000, Train Loss: 0.052361, Val Loss: 0.025278
# Epoch 15/2000, Train Loss: 0.051884, Val Loss: 0.024866
# Epoch 16/2000, Train Loss: 0.049694, Val Loss: 0.024292
# Epoch 17/2000, Train Loss: 0.048518, Val Loss: 0.023693
# Epoch 18/2000, Train Loss: 0.046110, Val Loss: 0.022904
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.2, 'early_stopping_patience': 10, 'hidden_size': 100, 'learning_rate': 0.001, 'num_epochs': 2000, 'num_layers': 1, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.217659, Val Loss: 0.011904
# Epoch 2/2000, Train Loss: 0.061208, Val Loss: 0.011461
# Epoch 3/2000, Train Loss: 0.068975, Val Loss: 0.011978
# Epoch 4/2000, Train Loss: 0.061721, Val Loss: 0.019771
# Epoch 5/2000, Train Loss: 0.041350, Val Loss: 0.023473
# Epoch 6/2000, Train Loss: 0.034030, Val Loss: 0.013808
# Epoch 7/2000, Train Loss: 0.033162, Val Loss: 0.014785
# Epoch 8/2000, Train Loss: 0.024984, Val Loss: 0.009367
# Epoch 9/2000, Train Loss: 0.018206, Val Loss: 0.004265
# Epoch 10/2000, Train Loss: 0.007857, Val Loss: 0.007082
# Epoch 11/2000, Train Loss: 0.011387, Val Loss: 0.005634
# Epoch 12/2000, Train Loss: 0.015923, Val Loss: 0.002904
# Epoch 13/2000, Train Loss: 0.005113, Val Loss: 0.004003
# Epoch 14/2000, Train Loss: 0.004933, Val Loss: 0.006953
# Epoch 15/2000, Train Loss: 0.008233, Val Loss: 0.003655
# Epoch 16/2000, Train Loss: 0.008984, Val Loss: 0.002394
# Epoch 17/2000, Train Loss: 0.003725, Val Loss: 0.005478
# Epoch 18/2000, Train Loss: 0.004651, Val Loss: 0.005343
# Epoch 19/2000, Train Loss: 0.009345, Val Loss: 0.002208
# Epoch 20/2000, Train Loss: 0.004242, Val Loss: 0.003972
# Epoch 21/2000, Train Loss: 0.003728, Val Loss: 0.005424
# Epoch 22/2000, Train Loss: 0.007109, Val Loss: 0.002458
# Epoch 23/2000, Train Loss: 0.005699, Val Loss: 0.002810
# Epoch 24/2000, Train Loss: 0.003475, Val Loss: 0.004692
# Epoch 25/2000, Train Loss: 0.004992, Val Loss: 0.003085
# Epoch 26/2000, Train Loss: 0.008068, Val Loss: 0.002148
# Epoch 27/2000, Train Loss: 0.003409, Val Loss: 0.003964
# Epoch 28/2000, Train Loss: 0.003771, Val Loss: 0.003973
# Epoch 29/2000, Train Loss: 0.009626, Val Loss: 0.002250
# Epoch 30/2000, Train Loss: 0.003206, Val Loss: 0.003470
# Epoch 31/2000, Train Loss: 0.003370, Val Loss: 0.004445
# Epoch 32/2000, Train Loss: 0.007388, Val Loss: 0.001843
# Epoch 33/2000, Train Loss: 0.003648, Val Loss: 0.002650
# Epoch 34/2000, Train Loss: 0.003138, Val Loss: 0.004023
# Epoch 35/2000, Train Loss: 0.005025, Val Loss: 0.002115
# Epoch 36/2000, Train Loss: 0.004760, Val Loss: 0.002070
# Epoch 37/2000, Train Loss: 0.003017, Val Loss: 0.003369
# Epoch 38/2000, Train Loss: 0.003635, Val Loss: 0.002755
# Epoch 39/2000, Train Loss: 0.005760, Val Loss: 0.001818
# Epoch 40/2000, Train Loss: 0.003006, Val Loss: 0.002833
# Epoch 41/2000, Train Loss: 0.003059, Val Loss: 0.003215
# Epoch 42/2000, Train Loss: 0.005620, Val Loss: 0.001720
# Epoch 43/2000, Train Loss: 0.003241, Val Loss: 0.002365
# Epoch 44/2000, Train Loss: 0.002875, Val Loss: 0.003187
# Epoch 45/2000, Train Loss: 0.004503, Val Loss: 0.001852
# Epoch 46/2000, Train Loss: 0.003908, Val Loss: 0.001963
# Epoch 47/2000, Train Loss: 0.002815, Val Loss: 0.002809
# Epoch 48/2000, Train Loss: 0.003404, Val Loss: 0.002293
# Epoch 49/2000, Train Loss: 0.004711, Val Loss: 0.001720
# Epoch 50/2000, Train Loss: 0.002843, Val Loss: 0.002412
# Epoch 51/2000, Train Loss: 0.002845, Val Loss: 0.002708
# Epoch 52/2000, Train Loss: 0.004798, Val Loss: 0.001629
# Epoch 53/2000, Train Loss: 0.003090, Val Loss: 0.002077
# Epoch 54/2000, Train Loss: 0.002695, Val Loss: 0.002727
# Epoch 55/2000, Train Loss: 0.003950, Val Loss: 0.001768
# Epoch 56/2000, Train Loss: 0.003736, Val Loss: 0.001783
# Epoch 57/2000, Train Loss: 0.002673, Val Loss: 0.002414
# Epoch 58/2000, Train Loss: 0.003026, Val Loss: 0.002192
# Epoch 59/2000, Train Loss: 0.004435, Val Loss: 0.001599
# Epoch 60/2000, Train Loss: 0.002745, Val Loss: 0.002100
# Epoch 61/2000, Train Loss: 0.002629, Val Loss: 0.002523
# Epoch 62/2000, Train Loss: 0.004287, Val Loss: 0.001557
# Epoch 63/2000, Train Loss: 0.003108, Val Loss: 0.001835
# Epoch 64/2000, Train Loss: 0.002568, Val Loss: 0.002420
# Epoch 65/2000, Train Loss: 0.003353, Val Loss: 0.001802
# Epoch 66/2000, Train Loss: 0.003858, Val Loss: 0.001610
# Epoch 67/2000, Train Loss: 0.002575, Val Loss: 0.002104
# Epoch 68/2000, Train Loss: 0.002648, Val Loss: 0.002246
# Epoch 69/2000, Train Loss: 0.004298, Val Loss: 0.001489
# Epoch 70/2000, Train Loss: 0.002737, Val Loss: 0.001855
# Epoch 71/2000, Train Loss: 0.002483, Val Loss: 0.002388
# Epoch 72/2000, Train Loss: 0.003686, Val Loss: 0.001557
# Epoch 73/2000, Train Loss: 0.003317, Val Loss: 0.001630
# Epoch 74/2000, Train Loss: 0.002476, Val Loss: 0.002126
# Epoch 75/2000, Train Loss: 0.002768, Val Loss: 0.001954
# Epoch 76/2000, Train Loss: 0.004049, Val Loss: 0.001471
# Epoch 77/2000, Train Loss: 0.002521, Val Loss: 0.001855
# Epoch 78/2000, Train Loss: 0.002417, Val Loss: 0.002288
# Epoch 79/2000, Train Loss: 0.003902, Val Loss: 0.001429
# Epoch 80/2000, Train Loss: 0.002892, Val Loss: 0.001643
# Epoch 81/2000, Train Loss: 0.002400, Val Loss: 0.002154
# Epoch 82/2000, Train Loss: 0.002961, Val Loss: 0.001695
# Epoch 83/2000, Train Loss: 0.003661, Val Loss: 0.001467
# Epoch 84/2000, Train Loss: 0.002395, Val Loss: 0.001854
# Epoch 85/2000, Train Loss: 0.002387, Val Loss: 0.002125
# Epoch 86/2000, Train Loss: 0.003938, Val Loss: 0.001371
# Epoch 87/2000, Train Loss: 0.002591, Val Loss: 0.001644
# Epoch 88/2000, Train Loss: 0.002325, Val Loss: 0.002156
# Epoch 89/2000, Train Loss: 0.003163, Val Loss: 0.001501
# Epoch 90/2000, Train Loss: 0.003252, Val Loss: 0.001464
# Epoch 91/2000, Train Loss: 0.002312, Val Loss: 0.001860
# Epoch 92/2000, Train Loss: 0.002403, Val Loss: 0.001929
# Epoch 93/2000, Train Loss: 0.003804, Val Loss: 0.001346
# Epoch 94/2000, Train Loss: 0.002390, Val Loss: 0.001635
# Epoch 95/2000, Train Loss: 0.002249, Val Loss: 0.002113
# Epoch 96/2000, Train Loss: 0.003309, Val Loss: 0.001375
# Epoch 97/2000, Train Loss: 0.002898, Val Loss: 0.001458
# Epoch 98/2000, Train Loss: 0.002245, Val Loss: 0.001866
# Epoch 99/2000, Train Loss: 0.002455, Val Loss: 0.001739
# Epoch 100/2000, Train Loss: 0.003570, Val Loss: 0.001329
# Epoch 101/2000, Train Loss: 0.002258, Val Loss: 0.001618
# Epoch 102/2000, Train Loss: 0.002181, Val Loss: 0.002031
# Epoch 103/2000, Train Loss: 0.003369, Val Loss: 0.001299
# Epoch 104/2000, Train Loss: 0.002624, Val Loss: 0.001447
# Epoch 105/2000, Train Loss: 0.002182, Val Loss: 0.001862
# Epoch 106/2000, Train Loss: 0.002517, Val Loss: 0.001580
# Epoch 107/2000, Train Loss: 0.003314, Val Loss: 0.001313
# Epoch 108/2000, Train Loss: 0.002166, Val Loss: 0.001599
# Epoch 109/2000, Train Loss: 0.002125, Val Loss: 0.001931
# Epoch 110/2000, Train Loss: 0.003354, Val Loss: 0.001251
# Epoch 111/2000, Train Loss: 0.002424, Val Loss: 0.001430
# Epoch 112/2000, Train Loss: 0.002119, Val Loss: 0.001844
# Epoch 113/2000, Train Loss: 0.002565, Val Loss: 0.001461
# Epoch 114/2000, Train Loss: 0.003085, Val Loss: 0.001295
# Epoch 115/2000, Train Loss: 0.002096, Val Loss: 0.001575
# Epoch 116/2000, Train Loss: 0.002080, Val Loss: 0.001834
# Epoch 117/2000, Train Loss: 0.003294, Val Loss: 0.001217
# Epoch 118/2000, Train Loss: 0.002280, Val Loss: 0.001406
# Epoch 119/2000, Train Loss: 0.002059, Val Loss: 0.001814
# Epoch 120/2000, Train Loss: 0.002584, Val Loss: 0.001375
# Epoch 121/2000, Train Loss: 0.002904, Val Loss: 0.001274
# Epoch 122/2000, Train Loss: 0.002037, Val Loss: 0.001546
# Epoch 123/2000, Train Loss: 0.002038, Val Loss: 0.001753
# Epoch 124/2000, Train Loss: 0.003216, Val Loss: 0.001188
# Epoch 125/2000, Train Loss: 0.002176, Val Loss: 0.001378
# Epoch 126/2000, Train Loss: 0.002004, Val Loss: 0.001776
# Epoch 127/2000, Train Loss: 0.002569, Val Loss: 0.001316
# Epoch 128/2000, Train Loss: 0.002772, Val Loss: 0.001250
# Epoch 129/2000, Train Loss: 0.001985, Val Loss: 0.001512
# Epoch 130/2000, Train Loss: 0.001993, Val Loss: 0.001693
# Epoch 131/2000, Train Loss: 0.003137, Val Loss: 0.001161
# Epoch 132/2000, Train Loss: 0.002100, Val Loss: 0.001345
# Epoch 133/2000, Train Loss: 0.001955, Val Loss: 0.001735
# Epoch 134/2000, Train Loss: 0.002520, Val Loss: 0.001278
# Epoch 135/2000, Train Loss: 0.002686, Val Loss: 0.001223
# Epoch 136/2000, Train Loss: 0.001936, Val Loss: 0.001470
# Epoch 137/2000, Train Loss: 0.001939, Val Loss: 0.001655
# Epoch 138/2000, Train Loss: 0.003060, Val Loss: 0.001134
# Epoch 139/2000, Train Loss: 0.002046, Val Loss: 0.001309
# Epoch 140/2000, Train Loss: 0.001911, Val Loss: 0.001688
# Epoch 141/2000, Train Loss: 0.002434, Val Loss: 0.001258
# Epoch 142/2000, Train Loss: 0.002643, Val Loss: 0.001192
# Epoch 143/2000, Train Loss: 0.001888, Val Loss: 0.001422
# Epoch 144/2000, Train Loss: 0.001879, Val Loss: 0.001635
# Epoch 145/2000, Train Loss: 0.002979, Val Loss: 0.001108
# Epoch 146/2000, Train Loss: 0.002015, Val Loss: 0.001270
# Epoch 147/2000, Train Loss: 0.001871, Val Loss: 0.001633
# Epoch 148/2000, Train Loss: 0.002311, Val Loss: 0.001258
# Epoch 149/2000, Train Loss: 0.002636, Val Loss: 0.001159
# Epoch 150/2000, Train Loss: 0.001839, Val Loss: 0.001367
# Epoch 151/2000, Train Loss: 0.001817, Val Loss: 0.001628
# Epoch 152/2000, Train Loss: 0.002879, Val Loss: 0.001085
# Epoch 153/2000, Train Loss: 0.002010, Val Loss: 0.001229
# Epoch 154/2000, Train Loss: 0.001833, Val Loss: 0.001565
# Epoch 155/2000, Train Loss: 0.002153, Val Loss: 0.001282
# Epoch 156/2000, Train Loss: 0.002656, Val Loss: 0.001123
# Epoch 157/2000, Train Loss: 0.001792, Val Loss: 0.001309
# Epoch 158/2000, Train Loss: 0.001763, Val Loss: 0.001622
# Epoch 159/2000, Train Loss: 0.002738, Val Loss: 0.001069
# Epoch 160/2000, Train Loss: 0.002040, Val Loss: 0.001186
# Epoch 161/2000, Train Loss: 0.001793, Val Loss: 0.001480
# Epoch 162/2000, Train Loss: 0.001976, Val Loss: 0.001331
# Epoch 163/2000, Train Loss: 0.002687, Val Loss: 0.001085
# Epoch 164/2000, Train Loss: 0.001753, Val Loss: 0.001251
# Epoch 165/2000, Train Loss: 0.001723, Val Loss: 0.001601
# Epoch 166/2000, Train Loss: 0.002537, Val Loss: 0.001072
# Epoch 167/2000, Train Loss: 0.002118, Val Loss: 0.001142
# Epoch 168/2000, Train Loss: 0.001744, Val Loss: 0.001384
# Epoch 169/2000, Train Loss: 0.001806, Val Loss: 0.001400
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.2, 'early_stopping_patience': 10, 'hidden_size': 100, 'learning_rate': 0.001, 'num_epochs': 2000, 'num_layers': 2, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.237300, Val Loss: 0.024001
# Epoch 2/2000, Train Loss: 0.077412, Val Loss: 0.022186
# Epoch 3/2000, Train Loss: 0.063454, Val Loss: 0.022718
# Epoch 4/2000, Train Loss: 0.051838, Val Loss: 0.016260
# Epoch 5/2000, Train Loss: 0.033834, Val Loss: 0.005953
# Epoch 6/2000, Train Loss: 0.017671, Val Loss: 0.008671
# Epoch 7/2000, Train Loss: 0.019600, Val Loss: 0.003604
# Epoch 8/2000, Train Loss: 0.007730, Val Loss: 0.005202
# Epoch 9/2000, Train Loss: 0.005983, Val Loss: 0.007267
# Epoch 10/2000, Train Loss: 0.009919, Val Loss: 0.004649
# Epoch 11/2000, Train Loss: 0.010737, Val Loss: 0.003537
# Epoch 12/2000, Train Loss: 0.004869, Val Loss: 0.005712
# Epoch 13/2000, Train Loss: 0.005858, Val Loss: 0.005582
# Epoch 14/2000, Train Loss: 0.015509, Val Loss: 0.002581
# Epoch 15/2000, Train Loss: 0.005232, Val Loss: 0.004410
# Epoch 16/2000, Train Loss: 0.005337, Val Loss: 0.006470
# Epoch 17/2000, Train Loss: 0.019976, Val Loss: 0.003128
# Epoch 18/2000, Train Loss: 0.005050, Val Loss: 0.004620
# Epoch 19/2000, Train Loss: 0.006219, Val Loss: 0.007643
# Epoch 20/2000, Train Loss: 0.015623, Val Loss: 0.002538
# Epoch 21/2000, Train Loss: 0.006042, Val Loss: 0.003558
# Epoch 22/2000, Train Loss: 0.005699, Val Loss: 0.006762
# Epoch 23/2000, Train Loss: 0.009822, Val Loss: 0.002422
# Epoch 24/2000, Train Loss: 0.009228, Val Loss: 0.003028
# Epoch 25/2000, Train Loss: 0.005519, Val Loss: 0.005130
# Epoch 26/2000, Train Loss: 0.005669, Val Loss: 0.003404
# Epoch 27/2000, Train Loss: 0.012791, Val Loss: 0.002970
# Epoch 28/2000, Train Loss: 0.004112, Val Loss: 0.004336
# Epoch 29/2000, Train Loss: 0.004170, Val Loss: 0.005005
# Epoch 30/2000, Train Loss: 0.012297, Val Loss: 0.002431
# Epoch 31/2000, Train Loss: 0.003817, Val Loss: 0.003384
# Epoch 32/2000, Train Loss: 0.003824, Val Loss: 0.005130
# Epoch 33/2000, Train Loss: 0.007949, Val Loss: 0.001873
# Epoch 34/2000, Train Loss: 0.004304, Val Loss: 0.002550
# Epoch 35/2000, Train Loss: 0.003494, Val Loss: 0.003886
# Epoch 36/2000, Train Loss: 0.005292, Val Loss: 0.002169
# Epoch 37/2000, Train Loss: 0.005149, Val Loss: 0.002188
# Epoch 38/2000, Train Loss: 0.003307, Val Loss: 0.003331
# Epoch 39/2000, Train Loss: 0.003972, Val Loss: 0.002730
# Epoch 40/2000, Train Loss: 0.006297, Val Loss: 0.001923
# Epoch 41/2000, Train Loss: 0.003457, Val Loss: 0.002840
# Epoch 42/2000, Train Loss: 0.003530, Val Loss: 0.003105
# Epoch 43/2000, Train Loss: 0.006521, Val Loss: 0.001781
# Epoch 44/2000, Train Loss: 0.003717, Val Loss: 0.002467
# Epoch 45/2000, Train Loss: 0.003180, Val Loss: 0.003330
# Epoch 46/2000, Train Loss: 0.005501, Val Loss: 0.001870
# Epoch 47/2000, Train Loss: 0.004794, Val Loss: 0.002170
# Epoch 48/2000, Train Loss: 0.003234, Val Loss: 0.002770
# Epoch 49/2000, Train Loss: 0.003917, Val Loss: 0.002412
# Epoch 50/2000, Train Loss: 0.006000, Val Loss: 0.001832
# Epoch 51/2000, Train Loss: 0.003185, Val Loss: 0.002574
# Epoch 52/2000, Train Loss: 0.003280, Val Loss: 0.002762
# Epoch 53/2000, Train Loss: 0.005815, Val Loss: 0.001739
# Epoch 54/2000, Train Loss: 0.003680, Val Loss: 0.002310
# Epoch 55/2000, Train Loss: 0.003056, Val Loss: 0.002719
# Epoch 56/2000, Train Loss: 0.004686, Val Loss: 0.001852
# Epoch 57/2000, Train Loss: 0.004503, Val Loss: 0.002019
# Epoch 58/2000, Train Loss: 0.003031, Val Loss: 0.002196
# Epoch 59/2000, Train Loss: 0.003293, Val Loss: 0.002485
# Epoch 60/2000, Train Loss: 0.005839, Val Loss: 0.001678
# Epoch 61/2000, Train Loss: 0.003203, Val Loss: 0.002175
# ...
# Epoch 2/2000, Train Loss: 0.079913, Val Loss: 0.019858
# Epoch 3/2000, Train Loss: 0.060931, Val Loss: 0.015381
# Epoch 4/2000, Train Loss: 0.034083, Val Loss: 0.006410
# Epoch 5/2000, Train Loss: 0.035774, Val Loss: 0.006072
# Epoch 6/2000, Train Loss: 0.006562, Val Loss: 0.008051
# Epoch 7/2000, Train Loss: 0.008741, Val Loss: 0.007193
# Epoch 8/2000, Train Loss: 0.019418, Val Loss: 0.003436
# Epoch 9/2000, Train Loss: 0.014610, Val Loss: 0.002969
# Epoch 10/2000, Train Loss: 0.005871, Val Loss: 0.006535
# Epoch 11/2000, Train Loss: 0.005949, Val Loss: 0.007538
# Epoch 12/2000, Train Loss: 0.020622, Val Loss: 0.002689
# Epoch 13/2000, Train Loss: 0.006577, Val Loss: 0.004454
# Epoch 14/2000, Train Loss: 0.006331, Val Loss: 0.007918
# Epoch 15/2000, Train Loss: 0.010606, Val Loss: 0.003891
# Epoch 16/2000, Train Loss: 0.014856, Val Loss: 0.003024
# Epoch 17/2000, Train Loss: 0.005118, Val Loss: 0.005080
# Epoch 18/2000, Train Loss: 0.004718, Val Loss: 0.006235
# Epoch 19/2000, Train Loss: 0.015963, Val Loss: 0.002365
# Epoch 20/2000, Train Loss: 0.005459, Val Loss: 0.003715
# Epoch 21/2000, Train Loss: 0.005329, Val Loss: 0.006940
# Epoch 22/2000, Train Loss: 0.009847, Val Loss: 0.002696
# Epoch 23/2000, Train Loss: 0.010147, Val Loss: 0.002605
# Epoch 24/2000, Train Loss: 0.004415, Val Loss: 0.004785
# Epoch 25/2000, Train Loss: 0.004329, Val Loss: 0.004794
# Epoch 26/2000, Train Loss: 0.012237, Val Loss: 0.002107
# Epoch 27/2000, Train Loss: 0.004178, Val Loss: 0.003269
# Epoch 28/2000, Train Loss: 0.004131, Val Loss: 0.005374
# Epoch 29/2000, Train Loss: 0.007382, Val Loss: 0.002293
# Epoch 30/2000, Train Loss: 0.007141, Val Loss: 0.002292
# Epoch 31/2000, Train Loss: 0.003943, Val Loss: 0.004084
# Epoch 32/2000, Train Loss: 0.004472, Val Loss: 0.004131
# Epoch 33/2000, Train Loss: 0.010143, Val Loss: 0.001873
# Epoch 34/2000, Train Loss: 0.004184, Val Loss: 0.002981
# Epoch 35/2000, Train Loss: 0.003905, Val Loss: 0.004362
# Epoch 36/2000, Train Loss: 0.006897, Val Loss: 0.002456
# Epoch 37/2000, Train Loss: 0.007409, Val Loss: 0.002208
# Epoch 38/2000, Train Loss: 0.003928, Val Loss: 0.003274
# Epoch 39/2000, Train Loss: 0.003741, Val Loss: 0.004187
# Epoch 40/2000, Train Loss: 0.009751, Val Loss: 0.001787
# Epoch 41/2000, Train Loss: 0.004033, Val Loss: 0.002568
# Epoch 42/2000, Train Loss: 0.003782, Val Loss: 0.003797
# Epoch 43/2000, Train Loss: 0.006033, Val Loss: 0.002224
# Epoch 44/2000, Train Loss: 0.006487, Val Loss: 0.002088
# Epoch 45/2000, Train Loss: 0.003628, Val Loss: 0.002968
# Epoch 46/2000, Train Loss: 0.003517, Val Loss: 0.003205
# Epoch 47/2000, Train Loss: 0.008275, Val Loss: 0.001699
# Epoch 48/2000, Train Loss: 0.003841, Val Loss: 0.002523
# Epoch 49/2000, Train Loss: 0.003541, Val Loss: 0.003098
# Epoch 50/2000, Train Loss: 0.005234, Val Loss: 0.002346
# Epoch 51/2000, Train Loss: 0.006691, Val Loss: 0.001908
# Epoch 52/2000, Train Loss: 0.003587, Val Loss: 0.002723
# Epoch 53/2000, Train Loss: 0.003481, Val Loss: 0.003236
# Epoch 54/2000, Train Loss: 0.007797, Val Loss: 0.001588
# Epoch 55/2000, Train Loss: 0.004103, Val Loss: 0.002269
# Epoch 56/2000, Train Loss: 0.003409, Val Loss: 0.003142
# Epoch 57/2000, Train Loss: 0.004524, Val Loss: 0.002179
# Epoch 58/2000, Train Loss: 0.006515, Val Loss: 0.001775
# Epoch 59/2000, Train Loss: 0.003302, Val Loss: 0.002409
# Epoch 60/2000, Train Loss: 0.003534, Val Loss: 0.003231
# Epoch 61/2000, Train Loss: 0.006950, Val Loss: 0.001535
# Epoch 62/2000, Train Loss: 0.004156, Val Loss: 0.002139
# Epoch 63/2000, Train Loss: 0.003415, Val Loss: 0.002880
# Epoch 64/2000, Train Loss: 0.004378, Val Loss: 0.002108
# Epoch 65/2000, Train Loss: 0.006653, Val Loss: 0.001766
# Epoch 66/2000, Train Loss: 0.003217, Val Loss: 0.002203
# Epoch 67/2000, Train Loss: 0.003172, Val Loss: 0.003430
# Epoch 68/2000, Train Loss: 0.007406, Val Loss: 0.001465
# Epoch 69/2000, Train Loss: 0.003883, Val Loss: 0.002023
# Epoch 70/2000, Train Loss: 0.003210, Val Loss: 0.002605
# Epoch 71/2000, Train Loss: 0.003955, Val Loss: 0.002402
# Epoch 72/2000, Train Loss: 0.006204, Val Loss: 0.001742
# Epoch 73/2000, Train Loss: 0.002895, Val Loss: 0.002283
# Epoch 74/2000, Train Loss: 0.003104, Val Loss: 0.002808
# Epoch 75/2000, Train Loss: 0.005979, Val Loss: 0.001422
# Epoch 76/2000, Train Loss: 0.003332, Val Loss: 0.001853
# Epoch 77/2000, Train Loss: 0.003013, Val Loss: 0.002512
# Epoch 78/2000, Train Loss: 0.003811, Val Loss: 0.001905
# Epoch 79/2000, Train Loss: 0.005726, Val Loss: 0.001538
# Epoch 80/2000, Train Loss: 0.002893, Val Loss: 0.001916
# Epoch 81/2000, Train Loss: 0.002925, Val Loss: 0.002593
# Epoch 82/2000, Train Loss: 0.005599, Val Loss: 0.001426
# Epoch 83/2000, Train Loss: 0.003768, Val Loss: 0.001845
# Epoch 84/2000, Train Loss: 0.003182, Val Loss: 0.002563
# Epoch 85/2000, Train Loss: 0.003875, Val Loss: 0.002049
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.3, 'early_stopping_patience': 10, 'hidden_size': 100, 'learning_rate': 0.001, 'num_epochs': 2000, 'num_layers': 3, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.266426, Val Loss: 0.015302
# Epoch 2/2000, Train Loss: 0.106738, Val Loss: 0.014720
# Epoch 3/2000, Train Loss: 0.088141, Val Loss: 0.030924
# Epoch 4/2000, Train Loss: 0.064491, Val Loss: 0.014598
# Epoch 5/2000, Train Loss: 0.047524, Val Loss: 0.009004
# Epoch 6/2000, Train Loss: 0.054797, Val Loss: 0.013964
# Epoch 7/2000, Train Loss: 0.006708, Val Loss: 0.016733
# Epoch 8/2000, Train Loss: 0.016288, Val Loss: 0.008822
# Epoch 9/2000, Train Loss: 0.030262, Val Loss: 0.004056
# Epoch 10/2000, Train Loss: 0.009498, Val Loss: 0.005124
# Epoch 11/2000, Train Loss: 0.010202, Val Loss: 0.007221
# Epoch 12/2000, Train Loss: 0.040017, Val Loss: 0.010309
# Epoch 13/2000, Train Loss: 0.006031, Val Loss: 0.011914
# Epoch 14/2000, Train Loss: 0.007359, Val Loss: 0.008205
# Epoch 15/2000, Train Loss: 0.021825, Val Loss: 0.003093
# Epoch 16/2000, Train Loss: 0.006375, Val Loss: 0.007742
# Epoch 17/2000, Train Loss: 0.005766, Val Loss: 0.008720
# Epoch 18/2000, Train Loss: 0.017759, Val Loss: 0.002822
# Epoch 19/2000, Train Loss: 0.006943, Val Loss: 0.006467
# Epoch 20/2000, Train Loss: 0.005560, Val Loss: 0.008047
# Epoch 21/2000, Train Loss: 0.015739, Val Loss: 0.002689
# Epoch 22/2000, Train Loss: 0.006536, Val Loss: 0.005806
# Epoch 23/2000, Train Loss: 0.005300, Val Loss: 0.007403
# Epoch 24/2000, Train Loss: 0.015646, Val Loss: 0.002601
# Epoch 25/2000, Train Loss: 0.006627, Val Loss: 0.005465
# Epoch 26/2000, Train Loss: 0.005295, Val Loss: 0.007107
# Epoch 27/2000, Train Loss: 0.016389, Val Loss: 0.002548
# Epoch 28/2000, Train Loss: 0.006424, Val Loss: 0.005430
# Epoch 29/2000, Train Loss: 0.005578, Val Loss: 0.006608
# Epoch 30/2000, Train Loss: 0.017575, Val Loss: 0.002941
# Epoch 31/2000, Train Loss: 0.006060, Val Loss: 0.005418
# Epoch 32/2000, Train Loss: 0.005588, Val Loss: 0.006331
# Epoch 33/2000, Train Loss: 0.018915, Val Loss: 0.003982
# Epoch 34/2000, Train Loss: 0.005654, Val Loss: 0.005626
# Epoch 35/2000, Train Loss: 0.005403, Val Loss: 0.006175
# Epoch 36/2000, Train Loss: 0.018303, Val Loss: 0.003362
# Epoch 37/2000, Train Loss: 0.005425, Val Loss: 0.005280
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.3, 'early_stopping_patience': 10, 'hidden_size': 100, 'learning_rate': 0.0001, 'num_epochs': 2000, 'num_layers': 1, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.413266, Val Loss: 0.219476
# Epoch 2/2000, Train Loss: 0.377987, Val Loss: 0.193929
# Epoch 3/2000, Train Loss: 0.343432, Val Loss: 0.168046
# Epoch 4/2000, Train Loss: 0.307153, Val Loss: 0.140569
# Epoch 5/2000, Train Loss: 0.267056, Val Loss: 0.110076
# Epoch 6/2000, Train Loss: 0.220412, Val Loss: 0.075050
# Epoch 7/2000, Train Loss: 0.163847, Val Loss: 0.035647
# Epoch 8/2000, Train Loss: 0.098496, Val Loss: 0.010794
# Epoch 9/2000, Train Loss: 0.056228, Val Loss: 0.027600
# Epoch 10/2000, Train Loss: 0.036276, Val Loss: 0.014005
# Epoch 11/2000, Train Loss: 0.039551, Val Loss: 0.015134
# Epoch 12/2000, Train Loss: 0.036717, Val Loss: 0.016225
# Epoch 13/2000, Train Loss: 0.033742, Val Loss: 0.014630
# Epoch 14/2000, Train Loss: 0.032383, Val Loss: 0.013659
# Epoch 15/2000, Train Loss: 0.030853, Val Loss: 0.013064
# Epoch 16/2000, Train Loss: 0.029069, Val Loss: 0.012224
# Epoch 17/2000, Train Loss: 0.027442, Val Loss: 0.011355
# Epoch 18/2000, Train Loss: 0.025858, Val Loss: 0.010531
# Epoch 19/2000, Train Loss: 0.024254, Val Loss: 0.009694
# Epoch 20/2000, Train Loss: 0.022691, Val Loss: 0.008873
# Epoch 21/2000, Train Loss: 0.021174, Val Loss: 0.008093
# Epoch 22/2000, Train Loss: 0.019714, Val Loss: 0.007373
# Epoch 23/2000, Train Loss: 0.018343, Val Loss: 0.006743
# Epoch 24/2000, Train Loss: 0.017087, Val Loss: 0.006228
# Epoch 25/2000, Train Loss: 0.015973, Val Loss: 0.005851
# Epoch 26/2000, Train Loss: 0.015023, Val Loss: 0.005618
# Epoch 27/2000, Train Loss: 0.014246, Val Loss: 0.005523
# Epoch 28/2000, Train Loss: 0.013636, Val Loss: 0.005542
# Epoch 29/2000, Train Loss: 0.013174, Val Loss: 0.005642
# Epoch 30/2000, Train Loss: 0.012829, Val Loss: 0.005789
# Epoch 31/2000, Train Loss: 0.012572, Val Loss: 0.005953
# Epoch 32/2000, Train Loss: 0.012375, Val Loss: 0.006114
# Epoch 33/2000, Train Loss: 0.012218, Val Loss: 0.006259
# Epoch 34/2000, Train Loss: 0.012084, Val Loss: 0.006383
# Epoch 35/2000, Train Loss: 0.011964, Val Loss: 0.006484
# Epoch 36/2000, Train Loss: 0.011852, Val Loss: 0.006565
# Epoch 37/2000, Train Loss: 0.011747, Val Loss: 0.006625
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.3, 'early_stopping_patience': 10, 'hidden_size': 100, 'learning_rate': 0.0001, 'num_epochs': 2000, 'num_layers': 2, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.514633, Val Loss: 0.285172
# Epoch 2/2000, Train Loss: 0.454713, Val Loss: 0.240108
# Epoch 3/2000, Train Loss: 0.395796, Val Loss: 0.193428
# Epoch 4/2000, Train Loss: 0.330076, Val Loss: 0.139335
# Epoch 5/2000, Train Loss: 0.249485, Val Loss: 0.072935
# Epoch 6/2000, Train Loss: 0.147455, Val Loss: 0.012822
# Epoch 7/2000, Train Loss: 0.070146, Val Loss: 0.038644
# Epoch 8/2000, Train Loss: 0.038435, Val Loss: 0.017287
# Epoch 9/2000, Train Loss: 0.042509, Val Loss: 0.016243
# Epoch 10/2000, Train Loss: 0.042047, Val Loss: 0.018638
# Epoch 11/2000, Train Loss: 0.037189, Val Loss: 0.017166
# Epoch 12/2000, Train Loss: 0.036082, Val Loss: 0.016039
# Epoch 13/2000, Train Loss: 0.033591, Val Loss: 0.015116
# Epoch 14/2000, Train Loss: 0.032981, Val Loss: 0.014545
# Epoch 15/2000, Train Loss: 0.030513, Val Loss: 0.013314
# Epoch 16/2000, Train Loss: 0.028460, Val Loss: 0.012024
# Epoch 17/2000, Train Loss: 0.027675, Val Loss: 0.011408
# Epoch 18/2000, Train Loss: 0.024987, Val Loss: 0.010325
# Epoch 19/2000, Train Loss: 0.023996, Val Loss: 0.009413
# Epoch 20/2000, Train Loss: 0.020557, Val Loss: 0.008395
# Epoch 21/2000, Train Loss: 0.019381, Val Loss: 0.007278
# Epoch 22/2000, Train Loss: 0.018445, Val Loss: 0.006408
# Epoch 23/2000, Train Loss: 0.016824, Val Loss: 0.005929
# Epoch 24/2000, Train Loss: 0.014189, Val Loss: 0.005250
# Epoch 25/2000, Train Loss: 0.014150, Val Loss: 0.005060
# Epoch 26/2000, Train Loss: 0.013001, Val Loss: 0.005069
# Epoch 27/2000, Train Loss: 0.012544, Val Loss: 0.005143
# Epoch 28/2000, Train Loss: 0.011672, Val Loss: 0.005466
# Epoch 29/2000, Train Loss: 0.011414, Val Loss: 0.005702
# Epoch 30/2000, Train Loss: 0.012089, Val Loss: 0.005840
# Epoch 31/2000, Train Loss: 0.011663, Val Loss: 0.005903
# Epoch 32/2000, Train Loss: 0.011165, Val Loss: 0.006463
# Epoch 33/2000, Train Loss: 0.011949, Val Loss: 0.005494
# Epoch 34/2000, Train Loss: 0.009971, Val Loss: 0.007615
# Epoch 35/2000, Train Loss: 0.013595, Val Loss: 0.004925
# Epoch 36/2000, Train Loss: 0.008796, Val Loss: 0.009653
# Epoch 37/2000, Train Loss: 0.016119, Val Loss: 0.004524
# Epoch 38/2000, Train Loss: 0.008368, Val Loss: 0.012609
# Epoch 39/2000, Train Loss: 0.022513, Val Loss: 0.005144
# Epoch 40/2000, Train Loss: 0.009426, Val Loss: 0.014317
# Epoch 41/2000, Train Loss: 0.027615, Val Loss: 0.005040
# Epoch 42/2000, Train Loss: 0.010070, Val Loss: 0.010497
# Epoch 43/2000, Train Loss: 0.024046, Val Loss: 0.004626
# Epoch 44/2000, Train Loss: 0.009934, Val Loss: 0.006856
# Epoch 45/2000, Train Loss: 0.017047, Val Loss: 0.004397
# Epoch 46/2000, Train Loss: 0.009218, Val Loss: 0.006131
# Epoch 47/2000, Train Loss: 0.013549, Val Loss: 0.004284
# Epoch 48/2000, Train Loss: 0.008518, Val Loss: 0.006248
# Epoch 49/2000, Train Loss: 0.011990, Val Loss: 0.004303
# Epoch 50/2000, Train Loss: 0.007901, Val Loss: 0.006583
# Epoch 51/2000, Train Loss: 0.011836, Val Loss: 0.004405
# Epoch 52/2000, Train Loss: 0.007805, Val Loss: 0.007057
# Epoch 53/2000, Train Loss: 0.011750, Val Loss: 0.004323
# Epoch 54/2000, Train Loss: 0.007798, Val Loss: 0.007739
# Epoch 55/2000, Train Loss: 0.012013, Val Loss: 0.004364
# Epoch 56/2000, Train Loss: 0.007829, Val Loss: 0.007970
# Epoch 57/2000, Train Loss: 0.012132, Val Loss: 0.004326
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.3, 'early_stopping_patience': 10, 'hidden_size': 100, 'learning_rate': 0.0001, 'num_epochs': 2000, 'num_layers': 3, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.397202, Val Loss: 0.191436
# Epoch 2/2000, Train Loss: 0.334150, Val Loss: 0.142023
# Epoch 3/2000, Train Loss: 0.265677, Val Loss: 0.086031
# Epoch 4/2000, Train Loss: 0.183268, Val Loss: 0.028518
# Epoch 5/2000, Train Loss: 0.104082, Val Loss: 0.025846
# Epoch 6/2000, Train Loss: 0.066568, Val Loss: 0.039714
# Epoch 7/2000, Train Loss: 0.055102, Val Loss: 0.023894
# Epoch 8/2000, Train Loss: 0.056546, Val Loss: 0.023284
# Epoch 9/2000, Train Loss: 0.056030, Val Loss: 0.025630
# Epoch 10/2000, Train Loss: 0.052759, Val Loss: 0.024777
# Epoch 11/2000, Train Loss: 0.050112, Val Loss: 0.023290
# Epoch 12/2000, Train Loss: 0.048333, Val Loss: 0.022260
# Epoch 13/2000, Train Loss: 0.044784, Val Loss: 0.020668
# Epoch 14/2000, Train Loss: 0.043393, Val Loss: 0.020000
# Epoch 15/2000, Train Loss: 0.039105, Val Loss: 0.017899
# Epoch 16/2000, Train Loss: 0.035353, Val Loss: 0.015763
# Epoch 17/2000, Train Loss: 0.030612, Val Loss: 0.013181
# Epoch 18/2000, Train Loss: 0.026265, Val Loss: 0.009893
# Epoch 19/2000, Train Loss: 0.021776, Val Loss: 0.007773
# Epoch 20/2000, Train Loss: 0.016125, Val Loss: 0.006427
# Epoch 21/2000, Train Loss: 0.015578, Val Loss: 0.006432
# Epoch 22/2000, Train Loss: 0.013593, Val Loss: 0.008500
# Epoch 23/2000, Train Loss: 0.018765, Val Loss: 0.005914
# Epoch 24/2000, Train Loss: 0.011551, Val Loss: 0.012366
# Epoch 25/2000, Train Loss: 0.027966, Val Loss: 0.006436
# Epoch 26/2000, Train Loss: 0.012024, Val Loss: 0.014154
# Epoch 27/2000, Train Loss: 0.036727, Val Loss: 0.006027
# Epoch 28/2000, Train Loss: 0.014615, Val Loss: 0.007137
# Epoch 29/2000, Train Loss: 0.021469, Val Loss: 0.005647
# Epoch 30/2000, Train Loss: 0.012455, Val Loss: 0.006924
# Epoch 31/2000, Train Loss: 0.016375, Val Loss: 0.005454
# Epoch 32/2000, Train Loss: 0.010679, Val Loss: 0.008076
# Epoch 33/2000, Train Loss: 0.015593, Val Loss: 0.005464
# Epoch 34/2000, Train Loss: 0.010094, Val Loss: 0.010169
# Epoch 35/2000, Train Loss: 0.017459, Val Loss: 0.005280
# Epoch 36/2000, Train Loss: 0.010393, Val Loss: 0.012126
# Epoch 37/2000, Train Loss: 0.021326, Val Loss: 0.005164
# Epoch 38/2000, Train Loss: 0.010967, Val Loss: 0.011042
# Epoch 39/2000, Train Loss: 0.019959, Val Loss: 0.005105
# Epoch 40/2000, Train Loss: 0.010817, Val Loss: 0.010139
# Epoch 41/2000, Train Loss: 0.018538, Val Loss: 0.005073
# Epoch 42/2000, Train Loss: 0.010433, Val Loss: 0.009451
# Epoch 43/2000, Train Loss: 0.016402, Val Loss: 0.005191
# Epoch 44/2000, Train Loss: 0.010179, Val Loss: 0.008936
# Epoch 45/2000, Train Loss: 0.014934, Val Loss: 0.005376
# Epoch 46/2000, Train Loss: 0.009764, Val Loss: 0.009369
# Epoch 47/2000, Train Loss: 0.013621, Val Loss: 0.005533
# Epoch 48/2000, Train Loss: 0.009377, Val Loss: 0.009330
# Epoch 49/2000, Train Loss: 0.013583, Val Loss: 0.005667
# Epoch 50/2000, Train Loss: 0.009337, Val Loss: 0.009529
# Epoch 51/2000, Train Loss: 0.012427, Val Loss: 0.005961
# Early stopping
#
# Best parameters: {'batch_size': 32, 'dropout': 0.0, 'early_stopping_patience': 10, 'hidden_size': 100, 'learning_rate': 0.001, 'num_epochs': 2000, 'num_layers': 2, 'optimizer_name': 'Adam'}
# Best Validation Loss: 0.0009562552117535637

# %%
# Plot training and validation loss curves for the best model
plot_losses(best_train_losses, best_val_losses)
# Out:
# Best Validation Loss: 0.0009198995410568184

# %%
# Save the optimized model
torch.save(best_model.state_dict(), 'lstm_best_model.pth')

# %% [markdown]
# ### Model Evaluation

# %%
# Prepare test dataset and dataloader
sequence_length = 60
test_dataset = StockDataset(test_scaled, sequence_length)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)
#actual_dataset = StockDataset(df_actual, sequence_length)
#actual_loader = DataLoader(actual_dataset, batch_size=1, shuffle=False)

# Load the best model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
best_model.load_state_dict(torch.load('lstm_best_model.pth'))
best_model.to(device)
best_model.eval()

# Evaluate the model on the test set
predictions = []
actuals = []

with torch.no_grad():
    for x_test, y_test in test_loader:
        x_test = x_test.to(device)
        y_test = y_test.to(device)

        output = best_model(x_test)
        predictions.append(output.item())
        actuals.append(y_test.item())

# %%
# Convert lists to numpy arrays and reshape
predictions = np.array(predictions).reshape(-1, 1)
actuals = np.array(actuals).reshape(-1, 1)

# Inverse transform to get actual prices
predictions_inv = scaler.inverse_transform(predictions)
actuals_inv = scaler.inverse_transform(actuals)

# Compute RMSE
mse = mean_squared_error(actuals_inv, predictions_inv)
rmse = np.sqrt(mse)
print(f'\nTest MSE: {mse}')
print(f'\nTest RMSE: {rmse}')
# Out:
# Test MSE: 11.175747817958644
#
# Test RMSE: 3.3430147797996113

# %%
# Prepare dates for plotting
test_dates = df_test.index[sequence_length:]

# Create a DataFrame for comparison
result_df = pd.DataFrame({'Date': test_dates,
                          'Actual': actuals_inv.flatten(),
                          'Predicted': predictions_inv.flatten()})

# Plot actual vs predicted prices
plt.figure(figsize=(14, 7))
plt.plot(result_df['Date'], result_df['Actual'], label='Actual Price')
plt.plot(result_df['Date'], result_df['Predicted'], label='Predicted Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Actual vs Predicted Close Price')
plt.legend()
plt.show()

# Display the comparison table
print("\nComparison of Actual and Predicted Prices:")
print(result_df)
# Out:
# Comparison of Actual and Predicted Prices:
#          Date      Actual   Predicted
# 0  2023-10-04  136.270005  131.782312
# 1  2023-10-05  135.990007  133.878042
# 2  2023-10-06  138.729996  134.089753
# 3  2023-10-09  139.500002  136.175975
# 4  2023-10-10  139.199998  137.067428
# 5  2023-10-11  141.699998  136.489096
# 6  2023-10-12  140.289992  138.935112
# 7  2023-10-13  138.580002  137.770764
# 8  2023-10-16  140.490004  135.816486
# 9  2023-10-17  140.990007  138.151532
# 10 2023-10-18  139.279997  138.790111
# 11 2023-10-19  138.979994  136.633669
# 12 2023-10-20  136.740004  136.597811
# 13 2023-10-23  137.899992  134.909472
# 14 2023-10-24  140.119994  135.839472
# 15 2023-10-25  126.670000  138.147293
# 16 2023-10-26  123.440004  125.313177
# 17 2023-10-27  123.400002  122.665631
# 18 2023-10-30  125.750001  124.184596
# 19 2023-10-31  125.300003  125.642621
# 20 2023-11-01  127.569999  124.880119
# 21 2023-11-02  128.580001  126.530267
# 22 2023-11-03  130.369994  127.602824
# 23 2023-11-06  131.449996  128.803540
# 24 2023-11-07  132.399992  129.708939
# 25 2023-11-08  133.259994  130.472622
# 26 2023-11-09  131.690001  131.233337
# 27 2023-11-10  134.059996  129.830647
# 28 2023-11-13  133.640000  131.934818
# 29 2023-11-14  135.429993  131.938649
# 30 2023-11-15  136.380006  133.157466
# 31 2023-11-16  138.699995  134.262921
# 32 2023-11-17  136.940003  136.237188
# 33 2023-11-20  137.919997  134.564880
# 34 2023-11-21  138.619996  135.334521
# 35 2023-11-22  140.020006  136.461151
# 36 2023-11-24  138.220001  137.514336
# 37 2023-11-27  138.050002  135.746303
# 38 2023-11-28  138.619996  135.625770
# 39 2023-11-29  136.399994  136.565289

# %% [markdown]
# ### Combine all dataset prediction

# %% [markdown]
# Predicting training, validation, and test set. For combining dataset, the number of data reduce by number or sequence length.
# This is the reason there is gap between dataset prediction.

# %%
def predict_and_visualize(model, train_dataset, val_dataset, test_dataset, scaler, df_train, df_val, df_test, sequence_length):
    model.eval()
    predictions_train, actuals_train = [], []
    predictions_val, actuals_val = [], []
    predictions_test, actuals_test = [], []
    
    # Helper function to generate predictions
    def generate_predictions(dataset, loader):
        predictions, actuals = [], []
        with torch.no_grad():
            for x_batch, y_batch in loader:
                x_batch = x_batch.to(device)
                y_batch = y_batch.to(device)
                outputs = model(x_batch)
                predictions.append(outputs.item())
                actuals.append(y_batch.item())
        return predictions, actuals

    # Generate predictions for training dataset
    train_loader = DataLoader(train_dataset, batch_size=1, shuffle=False)
    predictions_train, actuals_train = generate_predictions(train_dataset, train_loader)

    # Generate predictions for validation dataset
    val_loader = DataLoader(val_dataset, batch_size=1, shuffle=False)
    predictions_val, actuals_val = generate_predictions(val_dataset, val_loader)

    # Generate predictions for test dataset
    test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)
    predictions_test, actuals_test = generate_predictions(test_dataset, test_loader)

    # Inverse transform the predictions and actuals
    predictions_train_inv = scaler.inverse_transform(np.array(predictions_train).reshape(-1, 1))
    actuals_train_inv = scaler.inverse_transform(np.array(actuals_train).reshape(-1, 1))

    predictions_val_inv = scaler.inverse_transform(np.array(predictions_val).reshape(-1, 1))
    actuals_val_inv = scaler.inverse_transform(np.array(actuals_val).reshape(-1, 1))

    predictions_test_inv = scaler.inverse_transform(np.array(predictions_test).reshape(-1, 1))
    actuals_test_inv = scaler.inverse_transform(np.array(actuals_test).reshape(-1, 1))

    # Combine results into a DataFrame for visualization
    train_dates = df_train.index[sequence_length:]
    val_dates = df_val.index[sequence_length:]
    test_dates = df_test.index[sequence_length:]

    combined_df = pd.DataFrame({
        'Date': np.concatenate([train_dates, val_dates, test_dates]),
        'Actual': np.concatenate([actuals_train_inv.flatten(), actuals_val_inv.flatten(), actuals_test_inv.flatten()]),
        'Train Predictions': np.concatenate([predictions_train_inv.flatten(), [None] * (len(val_dates) + len(test_dates))]),
        'Validation Predictions': np.concatenate([[None] * len(train_dates), predictions_val_inv.flatten(), [None] * len(test_dates)]),
        'Test Predictions': np.concatenate([[None] * (len(train_dates) + len(val_dates)), predictions_test_inv.flatten()]),
    })

    # Plot the results
    plt.figure(figsize=(14, 7))
    plt.plot(combined_df['Date'], combined_df['Actual'], label='Actual Prices', linewidth=2)
    plt.plot(combined_df['Date'], combined_df['Train Predictions'], label='Train Predictions', linestyle='dotted')
    plt.plot(combined_df['Date'], combined_df['Validation Predictions'], label='Validation Predictions', linestyle='dashed')
    plt.plot(combined_df['Date'], combined_df['Test Predictions'], label='Test Predictions', linestyle='dashdot')
    plt.title('Actual vs Predicted Prices (Train, Validation, Test)')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

    return combined_df

# Predict and visualize
combined_results = predict_and_visualize(
    best_model,
    train_dataset,
    val_dataset,
    test_dataset,
    scaler,
    df_train,
    df_val,
    df_test,
    sequence_length
)

# Display the combined DataFrame
print("\nCombined Results (First 10 Rows):")
print(combined_results.head(10))
# Out:
# Combined Results (First 10 Rows):
#         Date      Actual Train Predictions Validation Predictions  \
# 0 2021-03-31  103.431504        103.559221                   None
# 1 2021-04-01  106.887496         103.97587                   None
# 2 2021-04-05  111.277495        106.523919                   None
# 3 2021-04-06  111.237504        110.412057                   None
# 4 2021-04-07  112.484000        111.052735                   None
# 5 2021-04-08  113.272003        111.631139                   None
# 6 2021-04-09  114.293998        112.506627                   None
# 7 2021-04-12  112.739503        113.519733                   None
# 8 2021-04-13  113.363503        112.494357                   None
# 9 2021-04-14  112.741997        112.783888                   None
#
#   Test Predictions
# 0             None
# 1             None
# 2             None
# 3             None
# 4             None
# 5             None
# 6             None
# 7             None
# 8             None
# 9             None

# %% [markdown]
# #### Predicting whole dataset

# %%
def generate_predictions(model, dataset, scaler, device, sequence_length):
    """
    Generate predictions for a given dataset using the trained model.
    """
    loader = DataLoader(dataset, batch_size=1, shuffle=False)
    predictions, actuals = [], []
    model.eval()

    with torch.no_grad():
        for x_batch, y_batch in loader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)
            outputs = model(x_batch)
            predictions.append(outputs.item())
            actuals.append(y_batch.item())

    # Inverse transform predictions and actuals to original scale
    predictions_inv = scaler.inverse_transform(np.array(predictions).reshape(-1, 1))
    actuals_inv = scaler.inverse_transform(np.array(actuals).reshape(-1, 1))

    return predictions_inv, actuals_inv

# %%
def visualize_predictions_with_actual(df_train, df_val, df_test, predictions_train, actuals_train,
                                      predictions_val, actuals_val, predictions_test, actuals_test,
                                      sequence_length):
    # Combine all dates into a single array
    combined_dates = np.concatenate([
        df_train.index[sequence_length:], 
        df_val.index[sequence_length:], 
        df_test.index[sequence_length:]
    ])
    
    # Combine all actual data into a single array
    combined_actuals = np.concatenate([
        actuals_train.flatten(), 
        actuals_val.flatten(), 
        actuals_test.flatten()
    ])
    
    # Create combined predictions with gaps (None) where predictions for a dataset end
    combined_predictions = np.concatenate([
        predictions_train.flatten(),
        [None] * (len(actuals_val) - len(predictions_val)),
        predictions_val.flatten(),
        [None] * (len(actuals_test) - len(predictions_test)),
        predictions_test.flatten()
    ])
    
    # Plot the results
    plt.figure(figsize=(14, 7))
    plt.plot(combined_dates, combined_actuals, label='Actual Prices', color='blue', linewidth=2)
    plt.plot(combined_dates, combined_predictions, label='Predicted Prices', color='orange', linestyle='--')
    plt.title('Actual vs Predicted Prices (Training, Validation, and Test)')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.show()
    
    # Create a combined DataFrame for comparison
    combined_df = pd.DataFrame({
        'Date': combined_dates,
        'Actual': combined_actuals,
        'Predicted': combined_predictions
    })
    
    return combined_df

# %%
# Generate predictions for training, validation, and test datasets
predictions_train, actuals_train = generate_predictions(
    model=best_model,
    dataset=train_dataset,
    scaler=scaler,
    device=device,
    sequence_length=sequence_length
)

predictions_val, actuals_val = generate_predictions(
    model=best_model,
    dataset=val_dataset,
    scaler=scaler,
    device=device,
    sequence_length=sequence_length
)

predictions_test, actuals_test = generate_predictions(
    model=best_model,
    dataset=test_dataset,
    scaler=scaler,
    device=device,
    sequence_length=sequence_length
)

# Visualize predictions and actual data
combined_results = visualize_predictions_with_actual(
    df_train=df_train,
    df_val=df_val,
    df_test=df_test,
    predictions_train=predictions_train,
    actuals_train=actuals_train,
    predictions_val=predictions_val,
    actuals_val=actuals_val,
    predictions_test=predictions_test,
    actuals_test=actuals_test,
    sequence_length=sequence_length
)

# Step 3: Save the combined results to a CSV file
combined_results.to_csv('combined_results_with_actual.csv', index=False)
print("Combined results saved to 'combined_results_with_actual.csv'")
# Out:
# Combined results saved to 'combined_results_with_actual.csv'

# %% [markdown]
# Reference :
# OpenAI. (2024). ChatGPT (December 06 version) [Large language model]. https://chat.openai.com/chat
