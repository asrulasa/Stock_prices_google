# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import ParameterGrid

import yfinance as yf
import datetime
import joblib

import warnings
warnings.filterwarnings('ignore')

# %%
# Load Google stock data from Yahoo Finance
start_date = '2021-01-01'
end_date = '2024-11-30'
df = yf.download('GOOG', start=start_date, end=end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Display the first five rows
print("First five rows of the dataset:")
df.head()
# Out:
# First five rows of the dataset:
# Price       Adj Close      Close       High        Low       Open    Volume
# Ticker           GOOG       GOOG       GOOG       GOOG       GOOG      GOOG
# Date
# 2021-01-04  86.200310  86.412003  88.032501  85.392502  87.876999  38038000
# 2021-01-05  86.832756  87.045998  87.383499  85.900749  86.250000  22906000
# 2021-01-06  86.551941  86.764503  87.400002  84.949997  85.131500  52042000
# 2021-01-07  89.143578  89.362503  89.419998  86.852501  87.002998  45300000
# 2021-01-08  90.139130  90.360497  90.491997  88.676750  89.399002  41012000

# %%
# Display the first five rows
print("Last five rows of the dataset:")
df.tail()
# Out:
# Last five rows of the dataset:
# Price        Adj Close       Close        High         Low        Open  \
# Ticker            GOOG        GOOG        GOOG        GOOG        GOOG
# Date
# 2024-11-22  166.570007  166.570007  168.264999  165.710007  167.160004
# 2024-11-25  169.429993  169.429993  170.460007  167.399994  167.990005
# 2024-11-26  170.619995  170.619995  171.494995  169.429993  169.490005
# 2024-11-27  170.820007  170.820007  171.139999  169.669998  170.679993
# 2024-11-29  170.490005  170.490005  170.869995  168.750000  170.059998
#
# Price         Volume
# Ticker          GOOG
# Date
# 2024-11-22  24497000
# 2024-11-25  21395700
# 2024-11-26  14937500
# 2024-11-27  12433400
# 2024-11-29   9250700

# %%
# Statistical summary
print("\nStatistical summary of the dataset:")
df.describe()
# Out:
# Statistical summary of the dataset:
# Price    Adj Close       Close        High         Low        Open  \
# Ticker        GOOG        GOOG        GOOG        GOOG        GOOG
# count   984.000000  984.000000  984.000000  984.000000  984.000000
# mean    129.947381  130.229311  131.618411  128.826308  130.154110
# std      24.771823   24.772173   24.879915   24.700776   24.850911
# min      83.285461   83.489998   86.550003   83.449997   85.131500
# 25%     109.962452  110.232498  111.878628  108.127186  109.676502
# 50%     130.277061  130.597000  132.446747  129.608749  130.942001
# 75%     144.030533  144.384254  145.708122  143.065998  144.480495
# max     192.406723  192.660004  193.309998  190.619995  191.750000
#
# Price         Volume
# Ticker          GOOG
# count   9.840000e+02
# mean    2.486143e+07
# std     1.044442e+07
# min     7.409100e+06
# 25%     1.788328e+07
# 50%     2.252595e+07
# 75%     2.874378e+07
# max     9.779860e+07

# %%
# Dataset information
print("\nInformation about the dataset:")
print(df.info())

# Visualize Adj Close prices over time
plt.figure(figsize=(14, 7))
plt.plot(df['Adj Close'])
plt.title('Google Stock Adj Close Price History')
plt.xlabel('Date')
plt.ylabel('Adj Close Price USD ($)')
plt.xticks(rotation=45)
plt.show()
# Out:
# Information about the dataset:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 984 entries, 2021-01-04 to 2024-11-29
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, GOOG)  984 non-null    float64
#  1   (Close, GOOG)      984 non-null    float64
#  2   (High, GOOG)       984 non-null    float64
#  3   (Low, GOOG)        984 non-null    float64
#  4   (Open, GOOG)       984 non-null    float64
#  5   (Volume, GOOG)     984 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 53.8 KB
# None

# %%
# Define sequence length and test days
sequence_length = 5  # Number of days to use for sequences
#test_days = sequence_length  # Use 5 days for testing

# Split into training/validation and test sets
df_train = df[:500]
df_val = df[500:632]
df_test = df[632:732]
#df_actual = df[60:65]

print(f"Training data shape: {df_train.shape}")
print(f"Validation data shape: {df_val.shape}")
print(f"Test data shape: {df_test.shape}")
#print(f"Actual data shape: {df_actual.shape}")
# Out:
# Training data shape: (500, 6)
# Validation data shape: (132, 6)
# Test data shape: (100, 6)

# %%
# Initialize MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))

# Fit scaler on training data
train_data = df_train[['Close']].values
train_scaled = scaler.fit_transform(train_data)

# Transform validation and test data
val_data = df_val[['Close']].values
val_scaled = scaler.transform(val_data)

test_data = df_test[['Close']].values
test_scaled = scaler.transform(test_data)

# %%
class StockDataset(Dataset):
    def __init__(self, data, sequence_length=5):
        self.sequence_length = sequence_length
        self.data = data

    def __len__(self):
        return len(self.data) - self.sequence_length

    def __getitem__(self, index):
        x = self.data[index:index+self.sequence_length]
        y = self.data[index+self.sequence_length]
        return torch.FloatTensor(x), torch.FloatTensor(y)

class LSTMModel(nn.Module):
    def __init__(self, input_size=1, hidden_size=50, num_layers=2, dropout=0.2):
        super(LSTMModel, self).__init__()
        self.num_layers = num_layers
        self.hidden_size = hidden_size

        self.lstm = nn.LSTM(input_size, hidden_size, num_layers,
                            batch_first=True, dropout=dropout)
        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0),
                         self.hidden_size).to(device)
        c0 = torch.zeros(self.num_layers, x.size(0),
                         self.hidden_size).to(device)

        out, _ = self.lstm(x, (h0, c0))
        out = self.fc(out[:, -1, :])
        return out

# %%
def train_model(model, train_loader, val_loader, num_epochs=20, learning_rate=0.001,
                criterion=nn.MSELoss(), optimizer_name='Adam', early_stopping_patience=5):

    optimizer = getattr(torch.optim, optimizer_name)(model.parameters(), lr=learning_rate)
    model.to(device)
    criterion.to(device)

    train_losses = []
    val_losses = []
    best_val_loss = np.inf
    patience = early_stopping_patience
    best_model_state = None

    for epoch in range(num_epochs):
        model.train()
        train_loss = 0.0

        for x_batch, y_batch in train_loader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)

            optimizer.zero_grad()
            outputs = model(x_batch)
            loss = criterion(outputs, y_batch)
            loss.backward()
            optimizer.step()

            train_loss += loss.item() * x_batch.size(0)

        train_loss = train_loss / len(train_loader.dataset)
        train_losses.append(train_loss)

        # Validation
        model.eval()
        val_loss = 0.0
        with torch.no_grad():
            for x_val, y_val in val_loader:
                x_val = x_val.to(device)
                y_val = y_val.to(device)

                outputs = model(x_val)
                loss = criterion(outputs, y_val)
                val_loss += loss.item() * x_val.size(0)

            val_loss = val_loss / len(val_loader.dataset)
            val_losses.append(val_loss)

            print(f'Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss:.6f}, '
                  f'Val Loss: {val_loss:.6f}')

            # Early Stopping
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                best_model_state = model.state_dict()
                patience = early_stopping_patience  # Reset patience
            else:
                patience -= 1
                if patience == 0:
                    print("Early stopping")
                    model.load_state_dict(best_model_state)
                    break

    # Load best model
    model.load_state_dict(best_model_state)

    return model, train_losses, val_losses

# %%
def plot_losses(train_losses, val_losses):
    plt.figure(figsize=(10, 5))
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.title('Loss over epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()
    best_loss = min(val_losses)
    print(f'Best Validation Loss: {best_loss}')

# %%
# Device configuration
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Parameters
sequence_length = 60
batch_size = 64

# Prepare datasets and dataloaders
train_dataset = StockDataset(train_scaled, sequence_length)
val_dataset = StockDataset(val_scaled, sequence_length)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# Model parameters
input_size = 1
hidden_size = 50
num_layers = 1
dropout = 0.0
learning_rate = 0.0001
num_epochs = 2000
optimizer_name = 'Adam'
early_stopping_patience = 10

# Initialize model and loss function
model = LSTMModel(input_size, hidden_size, num_layers, dropout)
criterion = nn.MSELoss()

# Train the model
model, train_losses, val_losses = train_model(model, train_loader, val_loader,
                                              num_epochs=num_epochs,
                                              learning_rate=learning_rate,
                                              criterion=criterion,
                                              optimizer_name=optimizer_name,
                                              early_stopping_patience=early_stopping_patience)
# Out:
# Epoch 1/2000, Train Loss: 0.402605, Val Loss: 0.219149
# Epoch 2/2000, Train Loss: 0.390505, Val Loss: 0.210439
# Epoch 3/2000, Train Loss: 0.378884, Val Loss: 0.201914
# Epoch 4/2000, Train Loss: 0.367429, Val Loss: 0.193516
# Epoch 5/2000, Train Loss: 0.356073, Val Loss: 0.185212
# Epoch 6/2000, Train Loss: 0.344766, Val Loss: 0.176969
# Epoch 7/2000, Train Loss: 0.333457, Val Loss: 0.168756
# Epoch 8/2000, Train Loss: 0.322099, Val Loss: 0.160543
# Epoch 9/2000, Train Loss: 0.310642, Val Loss: 0.152301
# Epoch 10/2000, Train Loss: 0.299039, Val Loss: 0.144004
# Epoch 11/2000, Train Loss: 0.287245, Val Loss: 0.135629
# Epoch 12/2000, Train Loss: 0.275217, Val Loss: 0.127153
# Epoch 13/2000, Train Loss: 0.262910, Val Loss: 0.118558
# Epoch 14/2000, Train Loss: 0.250279, Val Loss: 0.109826
# Epoch 15/2000, Train Loss: 0.237279, Val Loss: 0.100944
# Epoch 16/2000, Train Loss: 0.223863, Val Loss: 0.091905
# Epoch 17/2000, Train Loss: 0.209988, Val Loss: 0.082712
# Epoch 18/2000, Train Loss: 0.195611, Val Loss: 0.073380
# Epoch 19/2000, Train Loss: 0.180698, Val Loss: 0.063948
# Epoch 20/2000, Train Loss: 0.165232, Val Loss: 0.054483
# Epoch 21/2000, Train Loss: 0.149220, Val Loss: 0.045105
# Epoch 22/2000, Train Loss: 0.132717, Val Loss: 0.036006
# Epoch 23/2000, Train Loss: 0.115860, Val Loss: 0.027494
# Epoch 24/2000, Train Loss: 0.098923, Val Loss: 0.020045
# Epoch 25/2000, Train Loss: 0.082406, Val Loss: 0.014362
# Epoch 26/2000, Train Loss: 0.067144, Val Loss: 0.011358
# Epoch 27/2000, Train Loss: 0.054352, Val Loss: 0.011858
# Epoch 28/2000, Train Loss: 0.045303, Val Loss: 0.015657
# Epoch 29/2000, Train Loss: 0.040328, Val Loss: 0.020437
# Epoch 30/2000, Train Loss: 0.038017, Val Loss: 0.023005
# Epoch 31/2000, Train Loss: 0.036542, Val Loss: 0.022637
# Epoch 32/2000, Train Loss: 0.035367, Val Loss: 0.020953
# Epoch 33/2000, Train Loss: 0.034597, Val Loss: 0.019356
# Epoch 34/2000, Train Loss: 0.034104, Val Loss: 0.018292
# Epoch 35/2000, Train Loss: 0.033659, Val Loss: 0.017711
# Epoch 36/2000, Train Loss: 0.033145, Val Loss: 0.017430
# Early stopping

# %%
# Plot training and validation loss curves
plot_losses(train_losses, val_losses)
# Out:
# Best Validation Loss: 0.011358345444831584

# %%
# Save the trained base model and scaler
torch.save(model.state_dict(), 'lstm_base_model.pth')
joblib.dump(scaler, 'scaler.pkl')
# Out:
# ['scaler.pkl']

# %%
# Define parameter grid for hyperparameter tuning
param_grid = {
    'num_layers': [1, 2, 3],
    'hidden_size': [50, 100],
    'dropout': [0.0, 0.2, 0.3],
    'learning_rate': [0.001, 0.0001],
    'batch_size': [32],
    'num_epochs':[2000],
    'optimizer_name': ['Adam'],
    'early_stopping_patience': [10]
    
}

param_list = list(ParameterGrid(param_grid))

best_model = None
best_val_loss = np.inf
best_params = None

for params in param_list:
    print(f"\nTraining with parameters: {params}")
    # Update batch_size
    batch_size = params['batch_size']

    # Create new DataLoaders with updated batch_size
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    # Initialize model with current parameters
    opt_model = LSTMModel(input_size=input_size, hidden_size=params['hidden_size'],
                      num_layers=params['num_layers'], dropout=params['dropout'])
    criterion = nn.MSELoss()

    # Train model
    opt_model, opt_train_losses, opt_val_losses = train_model(opt_model, train_loader, val_loader,
                                                  num_epochs=params['num_epochs'],
                                                  learning_rate=params['learning_rate'],
                                                  criterion=criterion,
                                                  optimizer_name='Adam',
                                                  early_stopping_patience=params['early_stopping_patience'])

    # Get final validation loss
    val_loss = opt_val_losses[-1]

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model = opt_model
        best_params = params
        best_train_losses = opt_train_losses
        best_val_losses = opt_val_losses

print(f"\nBest parameters: {best_params}")
print(f"Best Validation Loss: {best_val_loss}")
# Out:
# Training with parameters: {'batch_size': 32, 'dropout': 0.0, 'early_stopping_patience': 10, 'hidden_size': 50, 'learning_rate': 0.001, 'num_epochs': 2000, 'num_layers': 1, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.519990, Val Loss: 0.214728
# Epoch 2/2000, Train Loss: 0.290153, Val Loss: 0.013163
# Epoch 3/2000, Train Loss: 0.090628, Val Loss: 0.012382
# Epoch 4/2000, Train Loss: 0.096578, Val Loss: 0.017629
# Epoch 5/2000, Train Loss: 0.079835, Val Loss: 0.028555
# Epoch 6/2000, Train Loss: 0.046220, Val Loss: 0.022467
# Epoch 7/2000, Train Loss: 0.042897, Val Loss: 0.014125
# Epoch 8/2000, Train Loss: 0.043544, Val Loss: 0.017113
# Epoch 9/2000, Train Loss: 0.036999, Val Loss: 0.014042
# Epoch 10/2000, Train Loss: 0.034014, Val Loss: 0.011956
# Epoch 11/2000, Train Loss: 0.029549, Val Loss: 0.009802
# Epoch 12/2000, Train Loss: 0.024042, Val Loss: 0.006662
# Epoch 13/2000, Train Loss: 0.016960, Val Loss: 0.003701
# Epoch 14/2000, Train Loss: 0.010038, Val Loss: 0.005700
# Epoch 15/2000, Train Loss: 0.009947, Val Loss: 0.007711
# Epoch 16/2000, Train Loss: 0.012629, Val Loss: 0.004294
# Epoch 17/2000, Train Loss: 0.008868, Val Loss: 0.004304
# Epoch 18/2000, Train Loss: 0.007007, Val Loss: 0.005983
# Epoch 19/2000, Train Loss: 0.008039, Val Loss: 0.005632
# Epoch 20/2000, Train Loss: 0.007986, Val Loss: 0.004915
# Epoch 21/2000, Train Loss: 0.007108, Val Loss: 0.005113
# Epoch 22/2000, Train Loss: 0.006900, Val Loss: 0.005281
# Epoch 23/2000, Train Loss: 0.006884, Val Loss: 0.005134
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.0, 'early_stopping_patience': 10, 'hidden_size': 50, 'learning_rate': 0.001, 'num_epochs': 2000, 'num_layers': 2, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.205492, Val Loss: 0.016083
# Epoch 2/2000, Train Loss: 0.095860, Val Loss: 0.032687
# Epoch 3/2000, Train Loss: 0.054484, Val Loss: 0.012831
# Epoch 4/2000, Train Loss: 0.058676, Val Loss: 0.024576
# Epoch 5/2000, Train Loss: 0.039350, Val Loss: 0.018268
# Epoch 6/2000, Train Loss: 0.030290, Val Loss: 0.010714
# Epoch 7/2000, Train Loss: 0.010233, Val Loss: 0.007007
# Epoch 8/2000, Train Loss: 0.015184, Val Loss: 0.006034
# Epoch 9/2000, Train Loss: 0.014305, Val Loss: 0.003519
# Epoch 10/2000, Train Loss: 0.006240, Val Loss: 0.006272
# Epoch 11/2000, Train Loss: 0.008327, Val Loss: 0.005885
# Epoch 12/2000, Train Loss: 0.008900, Val Loss: 0.003959
# Epoch 13/2000, Train Loss: 0.006088, Val Loss: 0.005319
# Epoch 14/2000, Train Loss: 0.006290, Val Loss: 0.005591
# Epoch 15/2000, Train Loss: 0.006858, Val Loss: 0.004389
# Epoch 16/2000, Train Loss: 0.005652, Val Loss: 0.004925
# Epoch 17/2000, Train Loss: 0.005310, Val Loss: 0.005365
# Epoch 18/2000, Train Loss: 0.005948, Val Loss: 0.004407
# Epoch 19/2000, Train Loss: 0.005341, Val Loss: 0.004632
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.0, 'early_stopping_patience': 10, 'hidden_size': 50, 'learning_rate': 0.001, 'num_epochs': 2000, 'num_layers': 3, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.379032, Val Loss: 0.018404
# Epoch 2/2000, Train Loss: 0.096897, Val Loss: 0.014557
# Epoch 3/2000, Train Loss: 0.123302, Val Loss: 0.023148
# Epoch 4/2000, Train Loss: 0.105140, Val Loss: 0.034774
# Epoch 5/2000, Train Loss: 0.067388, Val Loss: 0.033882
# Epoch 6/2000, Train Loss: 0.062107, Val Loss: 0.021003
# Epoch 7/2000, Train Loss: 0.065948, Val Loss: 0.026091
# Epoch 8/2000, Train Loss: 0.058282, Val Loss: 0.023121
# Epoch 9/2000, Train Loss: 0.052352, Val Loss: 0.018445
# Epoch 10/2000, Train Loss: 0.038553, Val Loss: 0.008649
# Epoch 11/2000, Train Loss: 0.019213, Val Loss: 0.011918
# Epoch 12/2000, Train Loss: 0.040212, Val Loss: 0.008814
# Epoch 13/2000, Train Loss: 0.005877, Val Loss: 0.012824
# Epoch 14/2000, Train Loss: 0.013925, Val Loss: 0.010362
# Epoch 15/2000, Train Loss: 0.021230, Val Loss: 0.003961
# Epoch 16/2000, Train Loss: 0.005790, Val Loss: 0.009908
# Epoch 17/2000, Train Loss: 0.008948, Val Loss: 0.009672
# Epoch 18/2000, Train Loss: 0.012783, Val Loss: 0.004544
# Epoch 19/2000, Train Loss: 0.006946, Val Loss: 0.007643
# Epoch 20/2000, Train Loss: 0.007107, Val Loss: 0.008905
# Epoch 21/2000, Train Loss: 0.009956, Val Loss: 0.005458
# Epoch 22/2000, Train Loss: 0.007462, Val Loss: 0.006721
# Epoch 23/2000, Train Loss: 0.006352, Val Loss: 0.008322
# Epoch 24/2000, Train Loss: 0.008619, Val Loss: 0.005830
# Epoch 25/2000, Train Loss: 0.007857, Val Loss: 0.006060
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.0, 'early_stopping_patience': 10, 'hidden_size': 50, 'learning_rate': 0.0001, 'num_epochs': 2000, 'num_layers': 1, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.464743, Val Loss: 0.267441
# Epoch 2/2000, Train Loss: 0.442301, Val Loss: 0.250471
# Epoch 3/2000, Train Loss: 0.420008, Val Loss: 0.233155
# Epoch 4/2000, Train Loss: 0.396916, Val Loss: 0.215158
# Epoch 5/2000, Train Loss: 0.372548, Val Loss: 0.196156
# Epoch 6/2000, Train Loss: 0.346375, Val Loss: 0.175789
# Epoch 7/2000, Train Loss: 0.317778, Val Loss: 0.153667
# Epoch 8/2000, Train Loss: 0.286025, Val Loss: 0.129373
# Epoch 9/2000, Train Loss: 0.250229, Val Loss: 0.102517
# Epoch 10/2000, Train Loss: 0.209371, Val Loss: 0.072987
# Epoch 11/2000, Train Loss: 0.162630, Val Loss: 0.041983
# Epoch 12/2000, Train Loss: 0.111299, Val Loss: 0.015998
# Epoch 13/2000, Train Loss: 0.065892, Val Loss: 0.013446
# Epoch 14/2000, Train Loss: 0.044262, Val Loss: 0.024485
# Epoch 15/2000, Train Loss: 0.036755, Val Loss: 0.019047
# Epoch 16/2000, Train Loss: 0.036013, Val Loss: 0.016122
# Epoch 17/2000, Train Loss: 0.035950, Val Loss: 0.016015
# Epoch 18/2000, Train Loss: 0.034831, Val Loss: 0.016150
# Epoch 19/2000, Train Loss: 0.033548, Val Loss: 0.015764
# Epoch 20/2000, Train Loss: 0.032473, Val Loss: 0.015185
# Epoch 21/2000, Train Loss: 0.031514, Val Loss: 0.014671
# Epoch 22/2000, Train Loss: 0.030554, Val Loss: 0.014209
# Epoch 23/2000, Train Loss: 0.029575, Val Loss: 0.013740
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.0, 'early_stopping_patience': 10, 'hidden_size': 50, 'learning_rate': 0.0001, 'num_epochs': 2000, 'num_layers': 2, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.417542, Val Loss: 0.223894
# Epoch 2/2000, Train Loss: 0.388967, Val Loss: 0.202403
# Epoch 3/2000, Train Loss: 0.361571, Val Loss: 0.181107
# Epoch 4/2000, Train Loss: 0.333676, Val Loss: 0.159217
# Epoch 5/2000, Train Loss: 0.304200, Val Loss: 0.136044
# Epoch 6/2000, Train Loss: 0.272056, Val Loss: 0.110981
# Epoch 7/2000, Train Loss: 0.236110, Val Loss: 0.083621
# Epoch 8/2000, Train Loss: 0.195315, Val Loss: 0.054464
# Epoch 9/2000, Train Loss: 0.149931, Val Loss: 0.027514
# Epoch 10/2000, Train Loss: 0.105446, Val Loss: 0.014882
# Epoch 11/2000, Train Loss: 0.075028, Val Loss: 0.024780
# Epoch 12/2000, Train Loss: 0.061795, Val Loss: 0.031545
# Epoch 13/2000, Train Loss: 0.056799, Val Loss: 0.028465
# Epoch 14/2000, Train Loss: 0.055356, Val Loss: 0.025832
# Epoch 15/2000, Train Loss: 0.054602, Val Loss: 0.024973
# Epoch 16/2000, Train Loss: 0.053513, Val Loss: 0.024776
# Epoch 17/2000, Train Loss: 0.052222, Val Loss: 0.024554
# Epoch 18/2000, Train Loss: 0.050932, Val Loss: 0.024165
# Epoch 19/2000, Train Loss: 0.049695, Val Loss: 0.023685
# Epoch 20/2000, Train Loss: 0.048488, Val Loss: 0.023184
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.0, 'early_stopping_patience': 10, 'hidden_size': 50, 'learning_rate': 0.0001, 'num_epochs': 2000, 'num_layers': 3, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.508109, Val Loss: 0.287227
# Epoch 2/2000, Train Loss: 0.460109, Val Loss: 0.249360
# Epoch 3/2000, Train Loss: 0.411607, Val Loss: 0.209599
# Epoch 4/2000, Train Loss: 0.358549, Val Loss: 0.165707
# Epoch 5/2000, Train Loss: 0.297667, Val Loss: 0.116169
# Epoch 6/2000, Train Loss: 0.226551, Val Loss: 0.062855
# Epoch 7/2000, Train Loss: 0.148811, Val Loss: 0.020390
# Epoch 8/2000, Train Loss: 0.086266, Val Loss: 0.019191
# Epoch 9/2000, Train Loss: 0.060378, Val Loss: 0.033352
# Epoch 10/2000, Train Loss: 0.052384, Val Loss: 0.027653
# Epoch 11/2000, Train Loss: 0.051356, Val Loss: 0.023375
# Epoch 12/2000, Train Loss: 0.051681, Val Loss: 0.022793
# Epoch 13/2000, Train Loss: 0.050948, Val Loss: 0.023126
# Epoch 14/2000, Train Loss: 0.049774, Val Loss: 0.023058
# Epoch 15/2000, Train Loss: 0.048680, Val Loss: 0.022608
# Epoch 16/2000, Train Loss: 0.047708, Val Loss: 0.022098
# Epoch 17/2000, Train Loss: 0.046746, Val Loss: 0.021635
# Epoch 18/2000, Train Loss: 0.045737, Val Loss: 0.021183
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.0, 'early_stopping_patience': 10, 'hidden_size': 100, 'learning_rate': 0.001, 'num_epochs': 2000, 'num_layers': 1, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.344853, Val Loss: 0.025471
# Epoch 2/2000, Train Loss: 0.039200, Val Loss: 0.020684
# Epoch 3/2000, Train Loss: 0.109318, Val Loss: 0.013349
# Epoch 4/2000, Train Loss: 0.074557, Val Loss: 0.034964
# Epoch 5/2000, Train Loss: 0.041007, Val Loss: 0.015679
# Epoch 6/2000, Train Loss: 0.043575, Val Loss: 0.016620
# Epoch 7/2000, Train Loss: 0.037143, Val Loss: 0.014859
# Epoch 8/2000, Train Loss: 0.032310, Val Loss: 0.011441
# Epoch 9/2000, Train Loss: 0.026135, Val Loss: 0.007619
# Epoch 10/2000, Train Loss: 0.018234, Val Loss: 0.003444
# Epoch 11/2000, Train Loss: 0.009570, Val Loss: 0.006713
# Epoch 12/2000, Train Loss: 0.013330, Val Loss: 0.004974
# Epoch 13/2000, Train Loss: 0.014980, Val Loss: 0.002597
# Epoch 14/2000, Train Loss: 0.006105, Val Loss: 0.003265
# Epoch 15/2000, Train Loss: 0.004883, Val Loss: 0.005942
# Epoch 16/2000, Train Loss: 0.006933, Val Loss: 0.004889
# Epoch 17/2000, Train Loss: 0.009514, Val Loss: 0.002554
# Epoch 18/2000, Train Loss: 0.005714, Val Loss: 0.003021
# Epoch 19/2000, Train Loss: 0.004291, Val Loss: 0.004815
# Epoch 20/2000, Train Loss: 0.005308, Val Loss: 0.004562
# Epoch 21/2000, Train Loss: 0.007054, Val Loss: 0.002862
# Epoch 22/2000, Train Loss: 0.005455, Val Loss: 0.002888
# Epoch 23/2000, Train Loss: 0.004074, Val Loss: 0.004021
# Epoch 24/2000, Train Loss: 0.004517, Val Loss: 0.004137
# Epoch 25/2000, Train Loss: 0.005772, Val Loss: 0.002990
# Epoch 26/2000, Train Loss: 0.005148, Val Loss: 0.002781
# Epoch 27/2000, Train Loss: 0.003942, Val Loss: 0.003506
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.0, 'early_stopping_patience': 10, 'hidden_size': 100, 'learning_rate': 0.001, 'num_epochs': 2000, 'num_layers': 2, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.285087, Val Loss: 0.020560
# Epoch 2/2000, Train Loss: 0.079471, Val Loss: 0.019688
# Epoch 3/2000, Train Loss: 0.063270, Val Loss: 0.016441
# Epoch 4/2000, Train Loss: 0.043988, Val Loss: 0.010417
# Epoch 5/2000, Train Loss: 0.041391, Val Loss: 0.010675
# Epoch 6/2000, Train Loss: 0.006798, Val Loss: 0.008943
# Epoch 7/2000, Train Loss: 0.013927, Val Loss: 0.010551
# Epoch 8/2000, Train Loss: 0.033452, Val Loss: 0.009073
# Epoch 9/2000, Train Loss: 0.009971, Val Loss: 0.002644
# Epoch 10/2000, Train Loss: 0.003957, Val Loss: 0.006316
# Epoch 11/2000, Train Loss: 0.005782, Val Loss: 0.006959
# Epoch 12/2000, Train Loss: 0.008342, Val Loss: 0.004000
# Epoch 13/2000, Train Loss: 0.007921, Val Loss: 0.002995
# Epoch 14/2000, Train Loss: 0.004600, Val Loss: 0.004565
# Epoch 15/2000, Train Loss: 0.004708, Val Loss: 0.005825
# Epoch 16/2000, Train Loss: 0.006783, Val Loss: 0.004503
# Epoch 17/2000, Train Loss: 0.008012, Val Loss: 0.003140
# Epoch 18/2000, Train Loss: 0.004913, Val Loss: 0.003881
# Epoch 19/2000, Train Loss: 0.004147, Val Loss: 0.004966
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.0, 'early_stopping_patience': 10, 'hidden_size': 100, 'learning_rate': 0.001, 'num_epochs': 2000, 'num_layers': 3, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.301129, Val Loss: 0.015122
# Epoch 2/2000, Train Loss: 0.127463, Val Loss: 0.014568
# Epoch 3/2000, Train Loss: 0.095611, Val Loss: 0.028096
# Epoch 4/2000, Train Loss: 0.076028, Val Loss: 0.013653
# Epoch 5/2000, Train Loss: 0.073457, Val Loss: 0.024650
# Epoch 6/2000, Train Loss: 0.050918, Val Loss: 0.011584
# Epoch 7/2000, Train Loss: 0.014665, Val Loss: 0.008902
# Epoch 8/2000, Train Loss: 0.026499, Val Loss: 0.004396
# Epoch 9/2000, Train Loss: 0.013083, Val Loss: 0.006352
# Epoch 10/2000, Train Loss: 0.007992, Val Loss: 0.012862
# Epoch 11/2000, Train Loss: 0.019193, Val Loss: 0.004226
# Epoch 12/2000, Train Loss: 0.016247, Val Loss: 0.004647
# Epoch 13/2000, Train Loss: 0.007975, Val Loss: 0.010148
# Epoch 14/2000, Train Loss: 0.012455, Val Loss: 0.005507
# Epoch 15/2000, Train Loss: 0.025665, Val Loss: 0.005277
# Epoch 16/2000, Train Loss: 0.006612, Val Loss: 0.010246
# Epoch 17/2000, Train Loss: 0.007561, Val Loss: 0.008019
# Epoch 18/2000, Train Loss: 0.026133, Val Loss: 0.004981
# Epoch 19/2000, Train Loss: 0.005258, Val Loss: 0.008438
# Epoch 20/2000, Train Loss: 0.005966, Val Loss: 0.009652
# Epoch 21/2000, Train Loss: 0.020157, Val Loss: 0.003105
# Epoch 22/2000, Train Loss: 0.005540, Val Loss: 0.006192
# Epoch 23/2000, Train Loss: 0.005300, Val Loss: 0.009580
# Epoch 24/2000, Train Loss: 0.015207, Val Loss: 0.002659
# Epoch 25/2000, Train Loss: 0.006770, Val Loss: 0.004802
# Epoch 26/2000, Train Loss: 0.004944, Val Loss: 0.008685
# Epoch 27/2000, Train Loss: 0.011127, Val Loss: 0.003026
# Epoch 28/2000, Train Loss: 0.008878, Val Loss: 0.003809
# Epoch 29/2000, Train Loss: 0.004815, Val Loss: 0.007399
# Epoch 30/2000, Train Loss: 0.007687, Val Loss: 0.004020
# Epoch 31/2000, Train Loss: 0.012008, Val Loss: 0.003124
# Epoch 32/2000, Train Loss: 0.004749, Val Loss: 0.006093
# Epoch 33/2000, Train Loss: 0.005257, Val Loss: 0.005437
# Epoch 34/2000, Train Loss: 0.014751, Val Loss: 0.002731
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.0, 'early_stopping_patience': 10, 'hidden_size': 100, 'learning_rate': 0.0001, 'num_epochs': 2000, 'num_layers': 1, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.366268, Val Loss: 0.184383
# Epoch 2/2000, Train Loss: 0.335365, Val Loss: 0.163118
# Epoch 3/2000, Train Loss: 0.305546, Val Loss: 0.141805
# Epoch 4/2000, Train Loss: 0.274594, Val Loss: 0.119397
# Epoch 5/2000, Train Loss: 0.240798, Val Loss: 0.094884
# Epoch 6/2000, Train Loss: 0.202232, Val Loss: 0.067387
# Epoch 7/2000, Train Loss: 0.156720, Val Loss: 0.037043
# Epoch 8/2000, Train Loss: 0.103752, Val Loss: 0.011898
# Epoch 9/2000, Train Loss: 0.059789, Val Loss: 0.024770
# Epoch 10/2000, Train Loss: 0.037113, Val Loss: 0.018598
# Epoch 11/2000, Train Loss: 0.035588, Val Loss: 0.014881
# Epoch 12/2000, Train Loss: 0.035510, Val Loss: 0.016090
# Epoch 13/2000, Train Loss: 0.032810, Val Loss: 0.015724
# Epoch 14/2000, Train Loss: 0.030884, Val Loss: 0.014518
# Epoch 15/2000, Train Loss: 0.029538, Val Loss: 0.013831
# Epoch 16/2000, Train Loss: 0.027947, Val Loss: 0.013136
# Epoch 17/2000, Train Loss: 0.026345, Val Loss: 0.012291
# Epoch 18/2000, Train Loss: 0.024843, Val Loss: 0.011458
# Epoch 19/2000, Train Loss: 0.023341, Val Loss: 0.010616
# Epoch 20/2000, Train Loss: 0.021862, Val Loss: 0.009759
# Epoch 21/2000, Train Loss: 0.020440, Val Loss: 0.008924
# Epoch 22/2000, Train Loss: 0.019084, Val Loss: 0.008131
# Epoch 23/2000, Train Loss: 0.017827, Val Loss: 0.007415
# Epoch 24/2000, Train Loss: 0.016699, Val Loss: 0.006808
# Epoch 25/2000, Train Loss: 0.015727, Val Loss: 0.006330
# Epoch 26/2000, Train Loss: 0.014925, Val Loss: 0.005991
# Epoch 27/2000, Train Loss: 0.014291, Val Loss: 0.005778
# Epoch 28/2000, Train Loss: 0.013807, Val Loss: 0.005667
# Epoch 29/2000, Train Loss: 0.013446, Val Loss: 0.005630
# Epoch 30/2000, Train Loss: 0.013173, Val Loss: 0.005637
# Epoch 31/2000, Train Loss: 0.012963, Val Loss: 0.005666
# Epoch 32/2000, Train Loss: 0.012788, Val Loss: 0.005704
# Epoch 33/2000, Train Loss: 0.012645, Val Loss: 0.005739
# Epoch 34/2000, Train Loss: 0.012501, Val Loss: 0.005775
# Epoch 35/2000, Train Loss: 0.012394, Val Loss: 0.005790
# Epoch 36/2000, Train Loss: 0.012238, Val Loss: 0.005826
# Epoch 37/2000, Train Loss: 0.012190, Val Loss: 0.005800
# Epoch 38/2000, Train Loss: 0.011947, Val Loss: 0.005878
# Epoch 39/2000, Train Loss: 0.012087, Val Loss: 0.005737
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.0, 'early_stopping_patience': 10, 'hidden_size': 100, 'learning_rate': 0.0001, 'num_epochs': 2000, 'num_layers': 2, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.442630, Val Loss: 0.230502
# Epoch 2/2000, Train Loss: 0.388001, Val Loss: 0.189564
# Epoch 3/2000, Train Loss: 0.333421, Val Loss: 0.146264
# Epoch 4/2000, Train Loss: 0.271992, Val Loss: 0.096803
# Epoch 5/2000, Train Loss: 0.197575, Val Loss: 0.041543
# Epoch 6/2000, Train Loss: 0.114633, Val Loss: 0.014046
# Epoch 7/2000, Train Loss: 0.066214, Val Loss: 0.039336
# Epoch 8/2000, Train Loss: 0.045952, Val Loss: 0.021662
# Epoch 9/2000, Train Loss: 0.048095, Val Loss: 0.019869
# Epoch 10/2000, Train Loss: 0.047034, Val Loss: 0.021810
# Epoch 11/2000, Train Loss: 0.043985, Val Loss: 0.021339
# Epoch 12/2000, Train Loss: 0.041883, Val Loss: 0.019924
# Epoch 13/2000, Train Loss: 0.040284, Val Loss: 0.019081
# Epoch 14/2000, Train Loss: 0.038420, Val Loss: 0.018337
# Epoch 15/2000, Train Loss: 0.036401, Val Loss: 0.017370
# Epoch 16/2000, Train Loss: 0.034376, Val Loss: 0.016313
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.0, 'early_stopping_patience': 10, 'hidden_size': 100, 'learning_rate': 0.0001, 'num_epochs': 2000, 'num_layers': 3, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.293411, Val Loss: 0.121297
# Epoch 2/2000, Train Loss: 0.250194, Val Loss: 0.091365
# Epoch 3/2000, Train Loss: 0.207180, Val Loss: 0.059947
# Epoch 4/2000, Train Loss: 0.158560, Val Loss: 0.027950
# Epoch 5/2000, Train Loss: 0.107955, Val Loss: 0.017231
# Epoch 6/2000, Train Loss: 0.076992, Val Loss: 0.037662
# Epoch 7/2000, Train Loss: 0.061021, Val Loss: 0.029340
# Epoch 8/2000, Train Loss: 0.060068, Val Loss: 0.025559
# Epoch 9/2000, Train Loss: 0.059970, Val Loss: 0.026084
# Epoch 10/2000, Train Loss: 0.058336, Val Loss: 0.026699
# Epoch 11/2000, Train Loss: 0.056487, Val Loss: 0.026339
# Epoch 12/2000, Train Loss: 0.054928, Val Loss: 0.025710
# Epoch 13/2000, Train Loss: 0.053445, Val Loss: 0.025193
# Epoch 14/2000, Train Loss: 0.051833, Val Loss: 0.024697
# Epoch 15/2000, Train Loss: 0.050062, Val Loss: 0.024091
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.2, 'early_stopping_patience': 10, 'hidden_size': 50, 'learning_rate': 0.001, 'num_epochs': 2000, 'num_layers': 1, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.315791, Val Loss: 0.077428
# Epoch 2/2000, Train Loss: 0.159061, Val Loss: 0.015650
# Epoch 3/2000, Train Loss: 0.076520, Val Loss: 0.032479
# Epoch 4/2000, Train Loss: 0.049639, Val Loss: 0.013078
# Epoch 5/2000, Train Loss: 0.052484, Val Loss: 0.021336
# Epoch 6/2000, Train Loss: 0.039273, Val Loss: 0.020076
# Epoch 7/2000, Train Loss: 0.032158, Val Loss: 0.013429
# Epoch 8/2000, Train Loss: 0.025862, Val Loss: 0.010082
# Epoch 9/2000, Train Loss: 0.014050, Val Loss: 0.004355
# Epoch 10/2000, Train Loss: 0.008958, Val Loss: 0.007374
# Epoch 11/2000, Train Loss: 0.014765, Val Loss: 0.003964
# Epoch 12/2000, Train Loss: 0.008713, Val Loss: 0.004172
# Epoch 13/2000, Train Loss: 0.007465, Val Loss: 0.005347
# Epoch 14/2000, Train Loss: 0.008554, Val Loss: 0.004398
# Epoch 15/2000, Train Loss: 0.007151, Val Loss: 0.004578
# Epoch 16/2000, Train Loss: 0.006877, Val Loss: 0.004610
# Epoch 17/2000, Train Loss: 0.006588, Val Loss: 0.004526
# Epoch 18/2000, Train Loss: 0.006230, Val Loss: 0.004517
# Epoch 19/2000, Train Loss: 0.005979, Val Loss: 0.004473
# Epoch 20/2000, Train Loss: 0.005733, Val Loss: 0.004437
# Epoch 21/2000, Train Loss: 0.005517, Val Loss: 0.004401
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.2, 'early_stopping_patience': 10, 'hidden_size': 50, 'learning_rate': 0.001, 'num_epochs': 2000, 'num_layers': 2, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.224636, Val Loss: 0.018471
# Epoch 2/2000, Train Loss: 0.102578, Val Loss: 0.043084
# Epoch 3/2000, Train Loss: 0.054048, Val Loss: 0.016036
# Epoch 4/2000, Train Loss: 0.058666, Val Loss: 0.023155
# Epoch 5/2000, Train Loss: 0.048544, Val Loss: 0.022566
# Epoch 6/2000, Train Loss: 0.039279, Val Loss: 0.015358
# Epoch 7/2000, Train Loss: 0.029248, Val Loss: 0.009541
# Epoch 8/2000, Train Loss: 0.012264, Val Loss: 0.005281
# Epoch 9/2000, Train Loss: 0.010149, Val Loss: 0.008868
# Epoch 10/2000, Train Loss: 0.015231, Val Loss: 0.003319
# Epoch 11/2000, Train Loss: 0.007443, Val Loss: 0.004392
# Epoch 12/2000, Train Loss: 0.006462, Val Loss: 0.007282
# Epoch 13/2000, Train Loss: 0.008637, Val Loss: 0.004349
# Epoch 14/2000, Train Loss: 0.007255, Val Loss: 0.003977
# Epoch 15/2000, Train Loss: 0.005458, Val Loss: 0.006229
# Epoch 16/2000, Train Loss: 0.006506, Val Loss: 0.005260
# Epoch 17/2000, Train Loss: 0.007569, Val Loss: 0.003778
# Epoch 18/2000, Train Loss: 0.005057, Val Loss: 0.005770
# Epoch 19/2000, Train Loss: 0.005793, Val Loss: 0.005244
# Epoch 20/2000, Train Loss: 0.007489, Val Loss: 0.003179
# Epoch 21/2000, Train Loss: 0.005057, Val Loss: 0.005615
# Epoch 22/2000, Train Loss: 0.005397, Val Loss: 0.004656
# Epoch 23/2000, Train Loss: 0.007571, Val Loss: 0.003193
# Epoch 24/2000, Train Loss: 0.004756, Val Loss: 0.005179
# Epoch 25/2000, Train Loss: 0.005161, Val Loss: 0.005199
# Epoch 26/2000, Train Loss: 0.009323, Val Loss: 0.002695
# Epoch 27/2000, Train Loss: 0.004674, Val Loss: 0.005113
# Epoch 28/2000, Train Loss: 0.004914, Val Loss: 0.005114
# Epoch 29/2000, Train Loss: 0.010591, Val Loss: 0.002439
# Epoch 30/2000, Train Loss: 0.004500, Val Loss: 0.004640
# Epoch 31/2000, Train Loss: 0.004354, Val Loss: 0.005009
# Epoch 32/2000, Train Loss: 0.010851, Val Loss: 0.002442
# Epoch 33/2000, Train Loss: 0.004076, Val Loss: 0.004397
# Epoch 34/2000, Train Loss: 0.004272, Val Loss: 0.005457
# Epoch 35/2000, Train Loss: 0.010706, Val Loss: 0.002289
# Epoch 36/2000, Train Loss: 0.004138, Val Loss: 0.004091
# Epoch 37/2000, Train Loss: 0.004149, Val Loss: 0.004859
# Epoch 38/2000, Train Loss: 0.008641, Val Loss: 0.002146
# Epoch 39/2000, Train Loss: 0.004168, Val Loss: 0.003528
# Epoch 40/2000, Train Loss: 0.003898, Val Loss: 0.004988
# Epoch 41/2000, Train Loss: 0.007707, Val Loss: 0.002092
# Epoch 42/2000, Train Loss: 0.004238, Val Loss: 0.003027
# Epoch 43/2000, Train Loss: 0.004136, Val Loss: 0.004638
# Epoch 44/2000, Train Loss: 0.006898, Val Loss: 0.002082
# Epoch 45/2000, Train Loss: 0.004839, Val Loss: 0.002783
# Epoch 46/2000, Train Loss: 0.003958, Val Loss: 0.005077
# Epoch 47/2000, Train Loss: 0.006792, Val Loss: 0.002026
# Epoch 48/2000, Train Loss: 0.004998, Val Loss: 0.002530
# Epoch 49/2000, Train Loss: 0.003601, Val Loss: 0.004385
# Epoch 50/2000, Train Loss: 0.005777, Val Loss: 0.002175
# Epoch 51/2000, Train Loss: 0.005047, Val Loss: 0.002392
# Epoch 52/2000, Train Loss: 0.003833, Val Loss: 0.004203
# Epoch 53/2000, Train Loss: 0.005212, Val Loss: 0.002297
# Epoch 54/2000, Train Loss: 0.006279, Val Loss: 0.002240
# Epoch 55/2000, Train Loss: 0.003723, Val Loss: 0.003471
# Epoch 56/2000, Train Loss: 0.004278, Val Loss: 0.003229
# Epoch 57/2000, Train Loss: 0.008406, Val Loss: 0.002382
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.2, 'early_stopping_patience': 10, 'hidden_size': 50, 'learning_rate': 0.001, 'num_epochs': 2000, 'num_layers': 3, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.221876, Val Loss: 0.019852
# Epoch 2/2000, Train Loss: 0.091840, Val Loss: 0.033619
# Epoch 3/2000, Train Loss: 0.069045, Val Loss: 0.016106
# Epoch 4/2000, Train Loss: 0.076468, Val Loss: 0.030387
# Epoch 5/2000, Train Loss: 0.061779, Val Loss: 0.024355
# Epoch 6/2000, Train Loss: 0.057067, Val Loss: 0.020628
# Epoch 7/2000, Train Loss: 0.047171, Val Loss: 0.012869
# Epoch 8/2000, Train Loss: 0.031537, Val Loss: 0.006765
# Epoch 9/2000, Train Loss: 0.023373, Val Loss: 0.006413
# Epoch 10/2000, Train Loss: 0.016643, Val Loss: 0.007180
# Epoch 11/2000, Train Loss: 0.014485, Val Loss: 0.007375
# Epoch 12/2000, Train Loss: 0.012706, Val Loss: 0.006903
# Epoch 13/2000, Train Loss: 0.010349, Val Loss: 0.007576
# Epoch 14/2000, Train Loss: 0.010128, Val Loss: 0.007885
# Epoch 15/2000, Train Loss: 0.010097, Val Loss: 0.007197
# Epoch 16/2000, Train Loss: 0.008726, Val Loss: 0.007905
# Epoch 17/2000, Train Loss: 0.009180, Val Loss: 0.007883
# Epoch 18/2000, Train Loss: 0.009617, Val Loss: 0.007314
# Epoch 19/2000, Train Loss: 0.008789, Val Loss: 0.007020
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.2, 'early_stopping_patience': 10, 'hidden_size': 50, 'learning_rate': 0.0001, 'num_epochs': 2000, 'num_layers': 1, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.566278, Val Loss: 0.345436
# Epoch 2/2000, Train Loss: 0.545231, Val Loss: 0.329215
# Epoch 3/2000, Train Loss: 0.524721, Val Loss: 0.312983
# Epoch 4/2000, Train Loss: 0.503905, Val Loss: 0.296367
# Epoch 5/2000, Train Loss: 0.482271, Val Loss: 0.278953
# Epoch 6/2000, Train Loss: 0.459226, Val Loss: 0.260270
# Epoch 7/2000, Train Loss: 0.434077, Val Loss: 0.239759
# Epoch 8/2000, Train Loss: 0.405943, Val Loss: 0.216700
# Epoch 9/2000, Train Loss: 0.373606, Val Loss: 0.190101
# Epoch 10/2000, Train Loss: 0.335279, Val Loss: 0.158515
# Epoch 11/2000, Train Loss: 0.288182, Val Loss: 0.119817
# Epoch 12/2000, Train Loss: 0.228030, Val Loss: 0.071736
# Epoch 13/2000, Train Loss: 0.150986, Val Loss: 0.020973
# Epoch 14/2000, Train Loss: 0.079357, Val Loss: 0.022987
# Epoch 15/2000, Train Loss: 0.048915, Val Loss: 0.024444
# Epoch 16/2000, Train Loss: 0.042095, Val Loss: 0.015395
# Epoch 17/2000, Train Loss: 0.043461, Val Loss: 0.014946
# Epoch 18/2000, Train Loss: 0.041753, Val Loss: 0.015614
# Epoch 19/2000, Train Loss: 0.039268, Val Loss: 0.014964
# Epoch 20/2000, Train Loss: 0.037453, Val Loss: 0.013946
# Epoch 21/2000, Train Loss: 0.035965, Val Loss: 0.013198
# Epoch 22/2000, Train Loss: 0.034403, Val Loss: 0.012551
# Epoch 23/2000, Train Loss: 0.032794, Val Loss: 0.011859
# Epoch 24/2000, Train Loss: 0.031221, Val Loss: 0.011149
# Epoch 25/2000, Train Loss: 0.029678, Val Loss: 0.010456
# Epoch 26/2000, Train Loss: 0.028145, Val Loss: 0.009778
# Epoch 27/2000, Train Loss: 0.026622, Val Loss: 0.009114
# Epoch 28/2000, Train Loss: 0.025119, Val Loss: 0.008470
# Epoch 29/2000, Train Loss: 0.023640, Val Loss: 0.007855
# Epoch 30/2000, Train Loss: 0.022194, Val Loss: 0.007277
# Epoch 31/2000, Train Loss: 0.020789, Val Loss: 0.006747
# Epoch 32/2000, Train Loss: 0.019438, Val Loss: 0.006276
# Epoch 33/2000, Train Loss: 0.018154, Val Loss: 0.005875
# Epoch 34/2000, Train Loss: 0.016952, Val Loss: 0.005556
# Epoch 35/2000, Train Loss: 0.015847, Val Loss: 0.005328
# Epoch 36/2000, Train Loss: 0.014850, Val Loss: 0.005195
# Epoch 37/2000, Train Loss: 0.013970, Val Loss: 0.005159
# Epoch 38/2000, Train Loss: 0.013214, Val Loss: 0.005214
# Epoch 39/2000, Train Loss: 0.012581, Val Loss: 0.005348
# Epoch 40/2000, Train Loss: 0.012064, Val Loss: 0.005545
# Epoch 41/2000, Train Loss: 0.011652, Val Loss: 0.005788
# Epoch 42/2000, Train Loss: 0.011331, Val Loss: 0.006055
# Epoch 43/2000, Train Loss: 0.011085, Val Loss: 0.006329
# Epoch 44/2000, Train Loss: 0.010898, Val Loss: 0.006597
# Epoch 45/2000, Train Loss: 0.010755, Val Loss: 0.006847
# Epoch 46/2000, Train Loss: 0.010645, Val Loss: 0.007074
# Epoch 47/2000, Train Loss: 0.010559, Val Loss: 0.007274
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.2, 'early_stopping_patience': 10, 'hidden_size': 50, 'learning_rate': 0.0001, 'num_epochs': 2000, 'num_layers': 2, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.551111, Val Loss: 0.324617
# Epoch 2/2000, Train Loss: 0.511433, Val Loss: 0.294738
# Epoch 3/2000, Train Loss: 0.474510, Val Loss: 0.266436
# Epoch 4/2000, Train Loss: 0.439305, Val Loss: 0.238698
# Epoch 5/2000, Train Loss: 0.403551, Val Loss: 0.210719
# Epoch 6/2000, Train Loss: 0.366759, Val Loss: 0.181661
# Epoch 7/2000, Train Loss: 0.326893, Val Loss: 0.150646
# Epoch 8/2000, Train Loss: 0.283422, Val Loss: 0.116860
# Epoch 9/2000, Train Loss: 0.234464, Val Loss: 0.080112
# Epoch 10/2000, Train Loss: 0.178394, Val Loss: 0.042843
# Epoch 11/2000, Train Loss: 0.119743, Val Loss: 0.015730
# Epoch 12/2000, Train Loss: 0.073065, Val Loss: 0.017678
# Epoch 13/2000, Train Loss: 0.052842, Val Loss: 0.028934
# Epoch 14/2000, Train Loss: 0.046164, Val Loss: 0.025137
# Epoch 15/2000, Train Loss: 0.044164, Val Loss: 0.021457
# Epoch 16/2000, Train Loss: 0.044013, Val Loss: 0.020569
# Epoch 17/2000, Train Loss: 0.043067, Val Loss: 0.020494
# Epoch 18/2000, Train Loss: 0.041908, Val Loss: 0.020261
# Epoch 19/2000, Train Loss: 0.040092, Val Loss: 0.019571
# Epoch 20/2000, Train Loss: 0.039391, Val Loss: 0.018880
# Epoch 21/2000, Train Loss: 0.038813, Val Loss: 0.018320
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.2, 'early_stopping_patience': 10, 'hidden_size': 50, 'learning_rate': 0.0001, 'num_epochs': 2000, 'num_layers': 3, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.194211, Val Loss: 0.064376
# Epoch 2/2000, Train Loss: 0.176431, Val Loss: 0.053631
# Epoch 3/2000, Train Loss: 0.158945, Val Loss: 0.043066
# Epoch 4/2000, Train Loss: 0.140789, Val Loss: 0.032770
# Epoch 5/2000, Train Loss: 0.121743, Val Loss: 0.023501
# Epoch 6/2000, Train Loss: 0.102370, Val Loss: 0.016974
# Epoch 7/2000, Train Loss: 0.084997, Val Loss: 0.015677
# Epoch 8/2000, Train Loss: 0.071863, Val Loss: 0.020365
# Epoch 9/2000, Train Loss: 0.063593, Val Loss: 0.026590
# Epoch 10/2000, Train Loss: 0.060376, Val Loss: 0.029282
# Epoch 11/2000, Train Loss: 0.057918, Val Loss: 0.029143
# Epoch 12/2000, Train Loss: 0.056712, Val Loss: 0.028460
# Epoch 13/2000, Train Loss: 0.055671, Val Loss: 0.027788
# Epoch 14/2000, Train Loss: 0.054407, Val Loss: 0.027445
# Epoch 15/2000, Train Loss: 0.054424, Val Loss: 0.027297
# Epoch 16/2000, Train Loss: 0.052444, Val Loss: 0.026824
# Epoch 17/2000, Train Loss: 0.050932, Val Loss: 0.026432
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.2, 'early_stopping_patience': 10, 'hidden_size': 100, 'learning_rate': 0.001, 'num_epochs': 2000, 'num_layers': 1, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.313017, Val Loss: 0.026044
# Epoch 2/2000, Train Loss: 0.049038, Val Loss: 0.018427
# Epoch 3/2000, Train Loss: 0.105832, Val Loss: 0.016748
# Epoch 4/2000, Train Loss: 0.075595, Val Loss: 0.026117
# Epoch 5/2000, Train Loss: 0.043497, Val Loss: 0.021802
# Epoch 6/2000, Train Loss: 0.038707, Val Loss: 0.013146
# Epoch 7/2000, Train Loss: 0.037487, Val Loss: 0.015883
# Epoch 8/2000, Train Loss: 0.028796, Val Loss: 0.010596
# Epoch 9/2000, Train Loss: 0.023316, Val Loss: 0.006798
# Epoch 10/2000, Train Loss: 0.012278, Val Loss: 0.003649
# Epoch 11/2000, Train Loss: 0.009429, Val Loss: 0.005767
# Epoch 12/2000, Train Loss: 0.011299, Val Loss: 0.003576
# Epoch 13/2000, Train Loss: 0.009229, Val Loss: 0.002751
# Epoch 14/2000, Train Loss: 0.004913, Val Loss: 0.004851
# Epoch 15/2000, Train Loss: 0.005663, Val Loss: 0.005329
# Epoch 16/2000, Train Loss: 0.008062, Val Loss: 0.003073
# Epoch 17/2000, Train Loss: 0.006135, Val Loss: 0.003075
# Epoch 18/2000, Train Loss: 0.004310, Val Loss: 0.004764
# Epoch 19/2000, Train Loss: 0.005185, Val Loss: 0.004433
# Epoch 20/2000, Train Loss: 0.006720, Val Loss: 0.002870
# Epoch 21/2000, Train Loss: 0.004902, Val Loss: 0.003332
# Epoch 22/2000, Train Loss: 0.004061, Val Loss: 0.004421
# Epoch 23/2000, Train Loss: 0.005034, Val Loss: 0.003690
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.2, 'early_stopping_patience': 10, 'hidden_size': 100, 'learning_rate': 0.001, 'num_epochs': 2000, 'num_layers': 2, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.351997, Val Loss: 0.019052
# Epoch 2/2000, Train Loss: 0.090573, Val Loss: 0.014905
# Epoch 3/2000, Train Loss: 0.083672, Val Loss: 0.012619
# Epoch 4/2000, Train Loss: 0.061817, Val Loss: 0.017985
# Epoch 5/2000, Train Loss: 0.053306, Val Loss: 0.012331
# Epoch 6/2000, Train Loss: 0.031889, Val Loss: 0.006177
# Epoch 7/2000, Train Loss: 0.033268, Val Loss: 0.005565
# Epoch 8/2000, Train Loss: 0.005812, Val Loss: 0.008479
# Epoch 9/2000, Train Loss: 0.008310, Val Loss: 0.007383
# Epoch 10/2000, Train Loss: 0.017352, Val Loss: 0.004098
# Epoch 11/2000, Train Loss: 0.019848, Val Loss: 0.003079
# Epoch 12/2000, Train Loss: 0.004682, Val Loss: 0.005717
# Epoch 13/2000, Train Loss: 0.006344, Val Loss: 0.008355
# Epoch 14/2000, Train Loss: 0.014000, Val Loss: 0.003593
# Epoch 15/2000, Train Loss: 0.014803, Val Loss: 0.002595
# Epoch 16/2000, Train Loss: 0.004591, Val Loss: 0.005325
# Epoch 17/2000, Train Loss: 0.004970, Val Loss: 0.008051
# Epoch 18/2000, Train Loss: 0.013787, Val Loss: 0.002922
# Epoch 19/2000, Train Loss: 0.011014, Val Loss: 0.002747
# Epoch 20/2000, Train Loss: 0.004769, Val Loss: 0.004654
# Epoch 21/2000, Train Loss: 0.004597, Val Loss: 0.007295
# Epoch 22/2000, Train Loss: 0.014582, Val Loss: 0.002361
# Epoch 23/2000, Train Loss: 0.008876, Val Loss: 0.002843
# Epoch 24/2000, Train Loss: 0.004629, Val Loss: 0.004865
# Epoch 25/2000, Train Loss: 0.004658, Val Loss: 0.006447
# Epoch 26/2000, Train Loss: 0.014176, Val Loss: 0.002123
# Epoch 27/2000, Train Loss: 0.006453, Val Loss: 0.002891
# Epoch 28/2000, Train Loss: 0.004401, Val Loss: 0.004674
# Epoch 29/2000, Train Loss: 0.004836, Val Loss: 0.005131
# Epoch 30/2000, Train Loss: 0.011824, Val Loss: 0.002040
# Epoch 31/2000, Train Loss: 0.005368, Val Loss: 0.002875
# Epoch 32/2000, Train Loss: 0.004207, Val Loss: 0.004754
# Epoch 33/2000, Train Loss: 0.005043, Val Loss: 0.004138
# Epoch 34/2000, Train Loss: 0.010747, Val Loss: 0.002024
# Epoch 35/2000, Train Loss: 0.005083, Val Loss: 0.003036
# Epoch 36/2000, Train Loss: 0.003840, Val Loss: 0.004123
# Epoch 37/2000, Train Loss: 0.004962, Val Loss: 0.003726
# Epoch 38/2000, Train Loss: 0.008586, Val Loss: 0.002053
# Epoch 39/2000, Train Loss: 0.004363, Val Loss: 0.002817
# Epoch 40/2000, Train Loss: 0.003537, Val Loss: 0.003841
# Epoch 41/2000, Train Loss: 0.004991, Val Loss: 0.003627
# Epoch 42/2000, Train Loss: 0.007917, Val Loss: 0.001987
# Epoch 43/2000, Train Loss: 0.003636, Val Loss: 0.002672
# Epoch 44/2000, Train Loss: 0.003533, Val Loss: 0.004271
# Epoch 45/2000, Train Loss: 0.006335, Val Loss: 0.002858
# Epoch 46/2000, Train Loss: 0.007459, Val Loss: 0.002004
# Epoch 47/2000, Train Loss: 0.003588, Val Loss: 0.003016
# Epoch 48/2000, Train Loss: 0.003468, Val Loss: 0.004168
# Epoch 49/2000, Train Loss: 0.007033, Val Loss: 0.002493
# Epoch 50/2000, Train Loss: 0.006646, Val Loss: 0.002040
# Epoch 51/2000, Train Loss: 0.003540, Val Loss: 0.002739
# Epoch 52/2000, Train Loss: 0.003329, Val Loss: 0.003732
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.2, 'early_stopping_patience': 10, 'hidden_size': 100, 'learning_rate': 0.001, 'num_epochs': 2000, 'num_layers': 3, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.273211, Val Loss: 0.017896
# Epoch 2/2000, Train Loss: 0.101547, Val Loss: 0.016650
# Epoch 3/2000, Train Loss: 0.082906, Val Loss: 0.027578
# Epoch 4/2000, Train Loss: 0.061870, Val Loss: 0.012149
# Epoch 5/2000, Train Loss: 0.018775, Val Loss: 0.012775
# Epoch 6/2000, Train Loss: 0.059887, Val Loss: 0.016363
# Epoch 7/2000, Train Loss: 0.007152, Val Loss: 0.015340
# Epoch 8/2000, Train Loss: 0.009700, Val Loss: 0.008615
# Epoch 9/2000, Train Loss: 0.025509, Val Loss: 0.004621
# Epoch 10/2000, Train Loss: 0.008680, Val Loss: 0.007866
# Epoch 11/2000, Train Loss: 0.011657, Val Loss: 0.006163
# Epoch 12/2000, Train Loss: 0.032068, Val Loss: 0.007589
# Epoch 13/2000, Train Loss: 0.007193, Val Loss: 0.014159
# Epoch 14/2000, Train Loss: 0.010261, Val Loss: 0.005588
# Epoch 15/2000, Train Loss: 0.020581, Val Loss: 0.004425
# Epoch 16/2000, Train Loss: 0.005856, Val Loss: 0.011662
# Epoch 17/2000, Train Loss: 0.008148, Val Loss: 0.005676
# Epoch 18/2000, Train Loss: 0.017236, Val Loss: 0.003704
# Epoch 19/2000, Train Loss: 0.005537, Val Loss: 0.009853
# Epoch 20/2000, Train Loss: 0.007141, Val Loss: 0.005439
# Epoch 21/2000, Train Loss: 0.015278, Val Loss: 0.003396
# Epoch 22/2000, Train Loss: 0.005016, Val Loss: 0.008466
# Epoch 23/2000, Train Loss: 0.006387, Val Loss: 0.005120
# Epoch 24/2000, Train Loss: 0.013462, Val Loss: 0.003299
# Epoch 25/2000, Train Loss: 0.005093, Val Loss: 0.007697
# Epoch 26/2000, Train Loss: 0.006320, Val Loss: 0.005129
# Epoch 27/2000, Train Loss: 0.013904, Val Loss: 0.003165
# Epoch 28/2000, Train Loss: 0.005044, Val Loss: 0.007130
# Epoch 29/2000, Train Loss: 0.005975, Val Loss: 0.004806
# Epoch 30/2000, Train Loss: 0.013286, Val Loss: 0.003207
# Epoch 31/2000, Train Loss: 0.005090, Val Loss: 0.006586
# Epoch 32/2000, Train Loss: 0.005686, Val Loss: 0.004726
# Epoch 33/2000, Train Loss: 0.013806, Val Loss: 0.003130
# Epoch 34/2000, Train Loss: 0.005078, Val Loss: 0.006257
# Epoch 35/2000, Train Loss: 0.005616, Val Loss: 0.004509
# Epoch 36/2000, Train Loss: 0.013874, Val Loss: 0.003070
# Epoch 37/2000, Train Loss: 0.004966, Val Loss: 0.005722
# Epoch 38/2000, Train Loss: 0.004998, Val Loss: 0.004543
# Epoch 39/2000, Train Loss: 0.012644, Val Loss: 0.002784
# Epoch 40/2000, Train Loss: 0.004530, Val Loss: 0.005265
# Epoch 41/2000, Train Loss: 0.004609, Val Loss: 0.004574
# Epoch 42/2000, Train Loss: 0.012155, Val Loss: 0.002571
# Epoch 43/2000, Train Loss: 0.004381, Val Loss: 0.005027
# Epoch 44/2000, Train Loss: 0.004523, Val Loss: 0.004744
# Epoch 45/2000, Train Loss: 0.012544, Val Loss: 0.002745
# Epoch 46/2000, Train Loss: 0.004430, Val Loss: 0.004600
# Epoch 47/2000, Train Loss: 0.004102, Val Loss: 0.004236
# Epoch 48/2000, Train Loss: 0.010923, Val Loss: 0.002452
# Epoch 49/2000, Train Loss: 0.004221, Val Loss: 0.004234
# Epoch 50/2000, Train Loss: 0.004123, Val Loss: 0.004437
# Epoch 51/2000, Train Loss: 0.010321, Val Loss: 0.002282
# Epoch 52/2000, Train Loss: 0.003779, Val Loss: 0.003749
# Epoch 53/2000, Train Loss: 0.003722, Val Loss: 0.003883
# Epoch 54/2000, Train Loss: 0.008782, Val Loss: 0.001994
# Epoch 55/2000, Train Loss: 0.003609, Val Loss: 0.003243
# Epoch 56/2000, Train Loss: 0.003745, Val Loss: 0.004061
# Epoch 57/2000, Train Loss: 0.008581, Val Loss: 0.001928
# Epoch 58/2000, Train Loss: 0.003832, Val Loss: 0.003103
# Epoch 59/2000, Train Loss: 0.003595, Val Loss: 0.003830
# Epoch 60/2000, Train Loss: 0.008966, Val Loss: 0.001796
# Epoch 61/2000, Train Loss: 0.004090, Val Loss: 0.003124
# Epoch 62/2000, Train Loss: 0.003448, Val Loss: 0.003990
# Epoch 63/2000, Train Loss: 0.008657, Val Loss: 0.001760
# Epoch 64/2000, Train Loss: 0.004109, Val Loss: 0.002940
# Epoch 65/2000, Train Loss: 0.003560, Val Loss: 0.003960
# Epoch 66/2000, Train Loss: 0.008687, Val Loss: 0.001778
# Epoch 67/2000, Train Loss: 0.003664, Val Loss: 0.002936
# Epoch 68/2000, Train Loss: 0.003764, Val Loss: 0.003928
# Epoch 69/2000, Train Loss: 0.009022, Val Loss: 0.001768
# Epoch 70/2000, Train Loss: 0.003677, Val Loss: 0.002935
# Epoch 71/2000, Train Loss: 0.003503, Val Loss: 0.004170
# Epoch 72/2000, Train Loss: 0.009054, Val Loss: 0.001952
# Epoch 73/2000, Train Loss: 0.003900, Val Loss: 0.002871
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.2, 'early_stopping_patience': 10, 'hidden_size': 100, 'learning_rate': 0.0001, 'num_epochs': 2000, 'num_layers': 1, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.282870, Val Loss: 0.126270
# Epoch 2/2000, Train Loss: 0.257798, Val Loss: 0.109881
# Epoch 3/2000, Train Loss: 0.234410, Val Loss: 0.094217
# Epoch 4/2000, Train Loss: 0.210984, Val Loss: 0.078644
# Epoch 5/2000, Train Loss: 0.186477, Val Loss: 0.062648
# Epoch 6/2000, Train Loss: 0.159860, Val Loss: 0.045938
# Epoch 7/2000, Train Loss: 0.130212, Val Loss: 0.028936
# Epoch 8/2000, Train Loss: 0.097426, Val Loss: 0.014542
# Epoch 9/2000, Train Loss: 0.065360, Val Loss: 0.012714
# Epoch 10/2000, Train Loss: 0.045153, Val Loss: 0.024371
# Epoch 11/2000, Train Loss: 0.035125, Val Loss: 0.019449
# Epoch 12/2000, Train Loss: 0.033311, Val Loss: 0.016416
# Epoch 13/2000, Train Loss: 0.032156, Val Loss: 0.016203
# Epoch 14/2000, Train Loss: 0.029786, Val Loss: 0.015606
# Epoch 15/2000, Train Loss: 0.027460, Val Loss: 0.014292
# Epoch 16/2000, Train Loss: 0.025459, Val Loss: 0.013033
# Epoch 17/2000, Train Loss: 0.023424, Val Loss: 0.011818
# Epoch 18/2000, Train Loss: 0.021341, Val Loss: 0.010507
# Epoch 19/2000, Train Loss: 0.019366, Val Loss: 0.009212
# Epoch 20/2000, Train Loss: 0.017531, Val Loss: 0.008024
# Epoch 21/2000, Train Loss: 0.015917, Val Loss: 0.007027
# Epoch 22/2000, Train Loss: 0.014615, Val Loss: 0.006297
# Epoch 23/2000, Train Loss: 0.013640, Val Loss: 0.005840
# Epoch 24/2000, Train Loss: 0.012985, Val Loss: 0.005607
# Epoch 25/2000, Train Loss: 0.012547, Val Loss: 0.005522
# Epoch 26/2000, Train Loss: 0.012288, Val Loss: 0.005506
# Epoch 27/2000, Train Loss: 0.012042, Val Loss: 0.005540
# Epoch 28/2000, Train Loss: 0.011968, Val Loss: 0.005522
# Epoch 29/2000, Train Loss: 0.011617, Val Loss: 0.005644
# Epoch 30/2000, Train Loss: 0.011927, Val Loss: 0.005413
# Epoch 31/2000, Train Loss: 0.010860, Val Loss: 0.006069
# Epoch 32/2000, Train Loss: 0.013205, Val Loss: 0.004946
# Epoch 33/2000, Train Loss: 0.009760, Val Loss: 0.008692
# Epoch 34/2000, Train Loss: 0.023564, Val Loss: 0.004900
# Epoch 35/2000, Train Loss: 0.010838, Val Loss: 0.007864
# Epoch 36/2000, Train Loss: 0.023797, Val Loss: 0.005159
# Epoch 37/2000, Train Loss: 0.011621, Val Loss: 0.004920
# Epoch 38/2000, Train Loss: 0.010693, Val Loss: 0.004858
# Epoch 39/2000, Train Loss: 0.010177, Val Loss: 0.004903
# Epoch 40/2000, Train Loss: 0.010324, Val Loss: 0.004819
# Epoch 41/2000, Train Loss: 0.009716, Val Loss: 0.005058
# Epoch 42/2000, Train Loss: 0.010291, Val Loss: 0.004795
# Epoch 43/2000, Train Loss: 0.009291, Val Loss: 0.005436
# Epoch 44/2000, Train Loss: 0.010876, Val Loss: 0.004628
# Epoch 45/2000, Train Loss: 0.008908, Val Loss: 0.006368
# Epoch 46/2000, Train Loss: 0.013441, Val Loss: 0.004407
# Epoch 47/2000, Train Loss: 0.009242, Val Loss: 0.007496
# Epoch 48/2000, Train Loss: 0.017950, Val Loss: 0.004524
# Epoch 49/2000, Train Loss: 0.009511, Val Loss: 0.005423
# Epoch 50/2000, Train Loss: 0.012183, Val Loss: 0.004355
# Epoch 51/2000, Train Loss: 0.008816, Val Loss: 0.005176
# Epoch 52/2000, Train Loss: 0.010969, Val Loss: 0.004312
# Epoch 53/2000, Train Loss: 0.008518, Val Loss: 0.005216
# Epoch 54/2000, Train Loss: 0.010566, Val Loss: 0.004285
# Epoch 55/2000, Train Loss: 0.008327, Val Loss: 0.005344
# Epoch 56/2000, Train Loss: 0.010487, Val Loss: 0.004254
# Epoch 57/2000, Train Loss: 0.008197, Val Loss: 0.005459
# Epoch 58/2000, Train Loss: 0.010488, Val Loss: 0.004219
# Epoch 59/2000, Train Loss: 0.008091, Val Loss: 0.005487
# Epoch 60/2000, Train Loss: 0.010362, Val Loss: 0.004188
# Epoch 61/2000, Train Loss: 0.007973, Val Loss: 0.005418
# Epoch 62/2000, Train Loss: 0.010031, Val Loss: 0.004168
# Epoch 63/2000, Train Loss: 0.007826, Val Loss: 0.005312
# Epoch 64/2000, Train Loss: 0.009596, Val Loss: 0.004159
# Epoch 65/2000, Train Loss: 0.007668, Val Loss: 0.005221
# Epoch 66/2000, Train Loss: 0.009176, Val Loss: 0.004162
# Epoch 67/2000, Train Loss: 0.007514, Val Loss: 0.005159
# Epoch 68/2000, Train Loss: 0.008820, Val Loss: 0.004172
# Epoch 69/2000, Train Loss: 0.007373, Val Loss: 0.005119
# Epoch 70/2000, Train Loss: 0.008523, Val Loss: 0.004183
# Epoch 71/2000, Train Loss: 0.007242, Val Loss: 0.005086
# Epoch 72/2000, Train Loss: 0.008267, Val Loss: 0.004195
# Epoch 73/2000, Train Loss: 0.007120, Val Loss: 0.005053
# Epoch 74/2000, Train Loss: 0.008034, Val Loss: 0.004205
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.2, 'early_stopping_patience': 10, 'hidden_size': 100, 'learning_rate': 0.0001, 'num_epochs': 2000, 'num_layers': 2, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.411490, Val Loss: 0.206512
# Epoch 2/2000, Train Loss: 0.353054, Val Loss: 0.163644
# Epoch 3/2000, Train Loss: 0.296030, Val Loss: 0.120210
# Epoch 4/2000, Train Loss: 0.234230, Val Loss: 0.073975
# Epoch 5/2000, Train Loss: 0.164455, Val Loss: 0.029085
# Epoch 6/2000, Train Loss: 0.095267, Val Loss: 0.014405
# Epoch 7/2000, Train Loss: 0.058075, Val Loss: 0.034414
# Epoch 8/2000, Train Loss: 0.042923, Val Loss: 0.022251
# Epoch 9/2000, Train Loss: 0.042190, Val Loss: 0.018481
# Epoch 10/2000, Train Loss: 0.041211, Val Loss: 0.019151
# Epoch 11/2000, Train Loss: 0.037517, Val Loss: 0.018612
# Epoch 12/2000, Train Loss: 0.034905, Val Loss: 0.016908
# Epoch 13/2000, Train Loss: 0.032190, Val Loss: 0.015528
# Epoch 14/2000, Train Loss: 0.029419, Val Loss: 0.014298
# Epoch 15/2000, Train Loss: 0.027162, Val Loss: 0.012784
# Epoch 16/2000, Train Loss: 0.023969, Val Loss: 0.011108
# Epoch 17/2000, Train Loss: 0.021551, Val Loss: 0.009458
# Epoch 18/2000, Train Loss: 0.018759, Val Loss: 0.008089
# Epoch 19/2000, Train Loss: 0.016231, Val Loss: 0.006639
# Epoch 20/2000, Train Loss: 0.013897, Val Loss: 0.005564
# Epoch 21/2000, Train Loss: 0.012409, Val Loss: 0.004978
# Epoch 22/2000, Train Loss: 0.011203, Val Loss: 0.004837
# Epoch 23/2000, Train Loss: 0.010223, Val Loss: 0.005175
# Epoch 24/2000, Train Loss: 0.010642, Val Loss: 0.004990
# Epoch 25/2000, Train Loss: 0.009580, Val Loss: 0.006034
# Epoch 26/2000, Train Loss: 0.011384, Val Loss: 0.004861
# Epoch 27/2000, Train Loss: 0.009073, Val Loss: 0.007675
# Epoch 28/2000, Train Loss: 0.014226, Val Loss: 0.004309
# Epoch 29/2000, Train Loss: 0.008379, Val Loss: 0.011061
# Epoch 30/2000, Train Loss: 0.021281, Val Loss: 0.004464
# Epoch 31/2000, Train Loss: 0.009453, Val Loss: 0.009946
# Epoch 32/2000, Train Loss: 0.022144, Val Loss: 0.004290
# Epoch 33/2000, Train Loss: 0.009285, Val Loss: 0.005823
# Epoch 34/2000, Train Loss: 0.013390, Val Loss: 0.004173
# Epoch 35/2000, Train Loss: 0.008409, Val Loss: 0.005320
# Epoch 36/2000, Train Loss: 0.010645, Val Loss: 0.004205
# Epoch 37/2000, Train Loss: 0.007921, Val Loss: 0.005591
# Epoch 38/2000, Train Loss: 0.009972, Val Loss: 0.004297
# Epoch 39/2000, Train Loss: 0.007862, Val Loss: 0.006349
# Epoch 40/2000, Train Loss: 0.010438, Val Loss: 0.004275
# Epoch 41/2000, Train Loss: 0.007431, Val Loss: 0.006827
# Epoch 42/2000, Train Loss: 0.010630, Val Loss: 0.004200
# Epoch 43/2000, Train Loss: 0.007578, Val Loss: 0.007113
# Epoch 44/2000, Train Loss: 0.010544, Val Loss: 0.004110
# Epoch 45/2000, Train Loss: 0.007753, Val Loss: 0.007542
# Epoch 46/2000, Train Loss: 0.011243, Val Loss: 0.004074
# Epoch 47/2000, Train Loss: 0.007663, Val Loss: 0.007329
# Epoch 48/2000, Train Loss: 0.010629, Val Loss: 0.004016
# Epoch 49/2000, Train Loss: 0.007391, Val Loss: 0.007188
# Epoch 50/2000, Train Loss: 0.010605, Val Loss: 0.004006
# Epoch 51/2000, Train Loss: 0.007054, Val Loss: 0.006971
# Epoch 52/2000, Train Loss: 0.010099, Val Loss: 0.004094
# Epoch 53/2000, Train Loss: 0.007161, Val Loss: 0.006735
# Epoch 54/2000, Train Loss: 0.009713, Val Loss: 0.004084
# Epoch 55/2000, Train Loss: 0.007065, Val Loss: 0.006376
# Epoch 56/2000, Train Loss: 0.009053, Val Loss: 0.004209
# Epoch 57/2000, Train Loss: 0.006961, Val Loss: 0.006627
# Epoch 58/2000, Train Loss: 0.008936, Val Loss: 0.004176
# Epoch 59/2000, Train Loss: 0.006731, Val Loss: 0.006183
# Epoch 60/2000, Train Loss: 0.008206, Val Loss: 0.004566
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.2, 'early_stopping_patience': 10, 'hidden_size': 100, 'learning_rate': 0.0001, 'num_epochs': 2000, 'num_layers': 3, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.337609, Val Loss: 0.149729
# Epoch 2/2000, Train Loss: 0.283262, Val Loss: 0.109893
# Epoch 3/2000, Train Loss: 0.226826, Val Loss: 0.066418
# Epoch 4/2000, Train Loss: 0.159810, Val Loss: 0.023402
# Epoch 5/2000, Train Loss: 0.095694, Val Loss: 0.024210
# Epoch 6/2000, Train Loss: 0.062392, Val Loss: 0.036352
# Epoch 7/2000, Train Loss: 0.051255, Val Loss: 0.023233
# Epoch 8/2000, Train Loss: 0.052553, Val Loss: 0.022280
# Epoch 9/2000, Train Loss: 0.050999, Val Loss: 0.023533
# Epoch 10/2000, Train Loss: 0.047479, Val Loss: 0.023093
# Epoch 11/2000, Train Loss: 0.045097, Val Loss: 0.021572
# Epoch 12/2000, Train Loss: 0.042442, Val Loss: 0.020223
# Epoch 13/2000, Train Loss: 0.040061, Val Loss: 0.018970
# Epoch 14/2000, Train Loss: 0.036255, Val Loss: 0.017227
# Epoch 15/2000, Train Loss: 0.032782, Val Loss: 0.015415
# Epoch 16/2000, Train Loss: 0.028962, Val Loss: 0.013282
# Epoch 17/2000, Train Loss: 0.025262, Val Loss: 0.010778
# Epoch 18/2000, Train Loss: 0.021392, Val Loss: 0.008355
# Epoch 19/2000, Train Loss: 0.017684, Val Loss: 0.006692
# Epoch 20/2000, Train Loss: 0.014375, Val Loss: 0.006102
# Epoch 21/2000, Train Loss: 0.014613, Val Loss: 0.005928
# Epoch 22/2000, Train Loss: 0.012366, Val Loss: 0.007639
# Epoch 23/2000, Train Loss: 0.016505, Val Loss: 0.005580
# Epoch 24/2000, Train Loss: 0.010624, Val Loss: 0.010763
# Epoch 25/2000, Train Loss: 0.023757, Val Loss: 0.005964
# Epoch 26/2000, Train Loss: 0.011359, Val Loss: 0.015521
# Epoch 27/2000, Train Loss: 0.038581, Val Loss: 0.005914
# ...
# Epoch 14/2000, Train Loss: 0.011171, Val Loss: 0.002642
# Epoch 15/2000, Train Loss: 0.006824, Val Loss: 0.002972
# Epoch 16/2000, Train Loss: 0.003948, Val Loss: 0.006457
# Epoch 17/2000, Train Loss: 0.005926, Val Loss: 0.004202
# Epoch 18/2000, Train Loss: 0.010083, Val Loss: 0.002267
# Epoch 19/2000, Train Loss: 0.003554, Val Loss: 0.005049
# Epoch 20/2000, Train Loss: 0.004111, Val Loss: 0.005181
# Epoch 21/2000, Train Loss: 0.010826, Val Loss: 0.002206
# Epoch 22/2000, Train Loss: 0.003614, Val Loss: 0.004078
# Epoch 23/2000, Train Loss: 0.003618, Val Loss: 0.005436
# Epoch 24/2000, Train Loss: 0.008650, Val Loss: 0.001989
# Epoch 25/2000, Train Loss: 0.004319, Val Loss: 0.003066
# Epoch 26/2000, Train Loss: 0.003381, Val Loss: 0.004923
# Epoch 27/2000, Train Loss: 0.005982, Val Loss: 0.002331
# Epoch 28/2000, Train Loss: 0.006045, Val Loss: 0.002237
# Epoch 29/2000, Train Loss: 0.003300, Val Loss: 0.004032
# Epoch 30/2000, Train Loss: 0.004057, Val Loss: 0.003251
# Epoch 31/2000, Train Loss: 0.008308, Val Loss: 0.002089
# Epoch 32/2000, Train Loss: 0.003133, Val Loss: 0.003440
# Epoch 33/2000, Train Loss: 0.003310, Val Loss: 0.004129
# Epoch 34/2000, Train Loss: 0.007883, Val Loss: 0.001871
# Epoch 35/2000, Train Loss: 0.003250, Val Loss: 0.002736
# Epoch 36/2000, Train Loss: 0.003090, Val Loss: 0.004062
# Epoch 37/2000, Train Loss: 0.005551, Val Loss: 0.001846
# Epoch 38/2000, Train Loss: 0.004169, Val Loss: 0.002104
# Epoch 39/2000, Train Loss: 0.002942, Val Loss: 0.003408
# Epoch 40/2000, Train Loss: 0.003776, Val Loss: 0.002471
# Epoch 41/2000, Train Loss: 0.005381, Val Loss: 0.001797
# Epoch 42/2000, Train Loss: 0.002881, Val Loss: 0.002787
# Epoch 43/2000, Train Loss: 0.002996, Val Loss: 0.003104
# Epoch 44/2000, Train Loss: 0.005562, Val Loss: 0.001672
# Epoch 45/2000, Train Loss: 0.003096, Val Loss: 0.002291
# Epoch 46/2000, Train Loss: 0.002800, Val Loss: 0.003164
# Epoch 47/2000, Train Loss: 0.004440, Val Loss: 0.001793
# Epoch 48/2000, Train Loss: 0.003856, Val Loss: 0.001886
# Epoch 49/2000, Train Loss: 0.002740, Val Loss: 0.002734
# Epoch 50/2000, Train Loss: 0.003231, Val Loss: 0.002321
# Epoch 51/2000, Train Loss: 0.004764, Val Loss: 0.001658
# Epoch 52/2000, Train Loss: 0.002773, Val Loss: 0.002290
# Epoch 53/2000, Train Loss: 0.002715, Val Loss: 0.002774
# Epoch 54/2000, Train Loss: 0.004652, Val Loss: 0.001595
# Epoch 55/2000, Train Loss: 0.003174, Val Loss: 0.001932
# Epoch 56/2000, Train Loss: 0.002636, Val Loss: 0.002654
# Epoch 57/2000, Train Loss: 0.003530, Val Loss: 0.001888
# Epoch 58/2000, Train Loss: 0.004085, Val Loss: 0.001659
# Epoch 59/2000, Train Loss: 0.002626, Val Loss: 0.002240
# Epoch 60/2000, Train Loss: 0.002703, Val Loss: 0.002439
# Epoch 61/2000, Train Loss: 0.004566, Val Loss: 0.001525
# Epoch 62/2000, Train Loss: 0.002841, Val Loss: 0.001915
# Epoch 63/2000, Train Loss: 0.002549, Val Loss: 0.002555
# Epoch 64/2000, Train Loss: 0.003721, Val Loss: 0.001664
# Epoch 65/2000, Train Loss: 0.003637, Val Loss: 0.001646
# Epoch 66/2000, Train Loss: 0.002537, Val Loss: 0.002186
# Epoch 67/2000, Train Loss: 0.002709, Val Loss: 0.002203
# Epoch 68/2000, Train Loss: 0.004390, Val Loss: 0.001484
# Epoch 69/2000, Train Loss: 0.002652, Val Loss: 0.001867
# Epoch 70/2000, Train Loss: 0.002473, Val Loss: 0.002457
# Epoch 71/2000, Train Loss: 0.003779, Val Loss: 0.001542
# Epoch 72/2000, Train Loss: 0.003353, Val Loss: 0.001615
# Epoch 73/2000, Train Loss: 0.002468, Val Loss: 0.002125
# Epoch 74/2000, Train Loss: 0.002685, Val Loss: 0.002051
# Epoch 75/2000, Train Loss: 0.004208, Val Loss: 0.001446
# Epoch 76/2000, Train Loss: 0.002530, Val Loss: 0.001804
# Epoch 77/2000, Train Loss: 0.002403, Val Loss: 0.002363
# Epoch 78/2000, Train Loss: 0.003720, Val Loss: 0.001471
# Epoch 79/2000, Train Loss: 0.003177, Val Loss: 0.001569
# Epoch 80/2000, Train Loss: 0.002403, Val Loss: 0.002049
# Epoch 81/2000, Train Loss: 0.002614, Val Loss: 0.001959
# Epoch 82/2000, Train Loss: 0.004038, Val Loss: 0.001405
# Epoch 83/2000, Train Loss: 0.002442, Val Loss: 0.001732
# Epoch 84/2000, Train Loss: 0.002335, Val Loss: 0.002270
# Epoch 85/2000, Train Loss: 0.003562, Val Loss: 0.001430
# Epoch 86/2000, Train Loss: 0.003078, Val Loss: 0.001513
# Epoch 87/2000, Train Loss: 0.002334, Val Loss: 0.001953
# Epoch 88/2000, Train Loss: 0.002499, Val Loss: 0.001913
# Epoch 89/2000, Train Loss: 0.003880, Val Loss: 0.001361
# Epoch 90/2000, Train Loss: 0.002378, Val Loss: 0.001653
# Epoch 91/2000, Train Loss: 0.002270, Val Loss: 0.002173
# Epoch 92/2000, Train Loss: 0.003330, Val Loss: 0.001413
# Epoch 93/2000, Train Loss: 0.003043, Val Loss: 0.001450
# Epoch 94/2000, Train Loss: 0.002259, Val Loss: 0.001840
# Epoch 95/2000, Train Loss: 0.002358, Val Loss: 0.001902
# Epoch 96/2000, Train Loss: 0.003725, Val Loss: 0.001314
# Epoch 97/2000, Train Loss: 0.002342, Val Loss: 0.001568
# Epoch 98/2000, Train Loss: 0.002207, Val Loss: 0.002062
# Epoch 99/2000, Train Loss: 0.003042, Val Loss: 0.001425
# Epoch 100/2000, Train Loss: 0.003067, Val Loss: 0.001384
# Epoch 101/2000, Train Loss: 0.002184, Val Loss: 0.001716
# Epoch 102/2000, Train Loss: 0.002214, Val Loss: 0.001912
# Epoch 103/2000, Train Loss: 0.003548, Val Loss: 0.001271
# Epoch 104/2000, Train Loss: 0.002354, Val Loss: 0.001482
# Epoch 105/2000, Train Loss: 0.002145, Val Loss: 0.001920
# Epoch 106/2000, Train Loss: 0.002706, Val Loss: 0.001478
# Epoch 107/2000, Train Loss: 0.003131, Val Loss: 0.001316
# Epoch 108/2000, Train Loss: 0.002116, Val Loss: 0.001588
# Epoch 109/2000, Train Loss: 0.002092, Val Loss: 0.001914
# Epoch 110/2000, Train Loss: 0.003318, Val Loss: 0.001244
# Epoch 111/2000, Train Loss: 0.002422, Val Loss: 0.001396
# Epoch 112/2000, Train Loss: 0.002081, Val Loss: 0.001762
# Epoch 113/2000, Train Loss: 0.002375, Val Loss: 0.001556
# Epoch 114/2000, Train Loss: 0.003179, Val Loss: 0.001249
# Epoch 115/2000, Train Loss: 0.002070, Val Loss: 0.001485
# Epoch 116/2000, Train Loss: 0.002010, Val Loss: 0.001888
# Epoch 117/2000, Train Loss: 0.002990, Val Loss: 0.001263
# Epoch 118/2000, Train Loss: 0.002619, Val Loss: 0.001306
# Epoch 119/2000, Train Loss: 0.002008, Val Loss: 0.001583
# Epoch 120/2000, Train Loss: 0.002072, Val Loss: 0.001740
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.3, 'early_stopping_patience': 10, 'hidden_size': 100, 'learning_rate': 0.001, 'num_epochs': 2000, 'num_layers': 2, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.249541, Val Loss: 0.021607
# Epoch 2/2000, Train Loss: 0.076678, Val Loss: 0.021705
# Epoch 3/2000, Train Loss: 0.055894, Val Loss: 0.017592
# Epoch 4/2000, Train Loss: 0.043937, Val Loss: 0.011879
# Epoch 5/2000, Train Loss: 0.016627, Val Loss: 0.009418
# Epoch 6/2000, Train Loss: 0.032918, Val Loss: 0.003831
# Epoch 7/2000, Train Loss: 0.008250, Val Loss: 0.005547
# Epoch 8/2000, Train Loss: 0.007700, Val Loss: 0.008824
# Epoch 9/2000, Train Loss: 0.013493, Val Loss: 0.004490
# Epoch 10/2000, Train Loss: 0.012400, Val Loss: 0.003098
# Epoch 11/2000, Train Loss: 0.005248, Val Loss: 0.007026
# Epoch 12/2000, Train Loss: 0.006348, Val Loss: 0.007670
# Epoch 13/2000, Train Loss: 0.015640, Val Loss: 0.002781
# Epoch 14/2000, Train Loss: 0.006838, Val Loss: 0.004640
# Epoch 15/2000, Train Loss: 0.005350, Val Loss: 0.007511
# Epoch 16/2000, Train Loss: 0.009764, Val Loss: 0.004127
# Epoch 17/2000, Train Loss: 0.013619, Val Loss: 0.002731
# Epoch 18/2000, Train Loss: 0.005029, Val Loss: 0.004930
# Epoch 19/2000, Train Loss: 0.005170, Val Loss: 0.007380
# Epoch 20/2000, Train Loss: 0.019264, Val Loss: 0.002903
# Epoch 21/2000, Train Loss: 0.004784, Val Loss: 0.004209
# Epoch 22/2000, Train Loss: 0.005574, Val Loss: 0.007441
# Epoch 23/2000, Train Loss: 0.010722, Val Loss: 0.002651
# Epoch 24/2000, Train Loss: 0.010026, Val Loss: 0.002795
# Epoch 25/2000, Train Loss: 0.004789, Val Loss: 0.005256
# Epoch 26/2000, Train Loss: 0.004839, Val Loss: 0.005129
# Epoch 27/2000, Train Loss: 0.014032, Val Loss: 0.002660
# Epoch 28/2000, Train Loss: 0.004050, Val Loss: 0.003789
# Epoch 29/2000, Train Loss: 0.004678, Val Loss: 0.006328
# Epoch 30/2000, Train Loss: 0.010221, Val Loss: 0.002020
# Epoch 31/2000, Train Loss: 0.005763, Val Loss: 0.002656
# Epoch 32/2000, Train Loss: 0.004145, Val Loss: 0.005073
# Epoch 33/2000, Train Loss: 0.005168, Val Loss: 0.003051
# Epoch 34/2000, Train Loss: 0.007975, Val Loss: 0.002093
# Epoch 35/2000, Train Loss: 0.003869, Val Loss: 0.003355
# Epoch 36/2000, Train Loss: 0.003763, Val Loss: 0.004609
# Epoch 37/2000, Train Loss: 0.008312, Val Loss: 0.001956
# Epoch 38/2000, Train Loss: 0.004892, Val Loss: 0.002521
# Epoch 39/2000, Train Loss: 0.004137, Val Loss: 0.004054
# Epoch 40/2000, Train Loss: 0.005058, Val Loss: 0.002774
# Epoch 41/2000, Train Loss: 0.007293, Val Loss: 0.002056
# Epoch 42/2000, Train Loss: 0.003774, Val Loss: 0.003247
# Epoch 43/2000, Train Loss: 0.003544, Val Loss: 0.003920
# Epoch 44/2000, Train Loss: 0.008183, Val Loss: 0.001787
# Epoch 45/2000, Train Loss: 0.004173, Val Loss: 0.002530
# Epoch 46/2000, Train Loss: 0.003473, Val Loss: 0.003696
# Epoch 47/2000, Train Loss: 0.005474, Val Loss: 0.002273
# Epoch 48/2000, Train Loss: 0.006110, Val Loss: 0.002071
# Epoch 49/2000, Train Loss: 0.003441, Val Loss: 0.002903
# Epoch 50/2000, Train Loss: 0.003590, Val Loss: 0.003288
# Epoch 51/2000, Train Loss: 0.007280, Val Loss: 0.001747
# Epoch 52/2000, Train Loss: 0.003919, Val Loss: 0.002495
# Epoch 53/2000, Train Loss: 0.003302, Val Loss: 0.003393
# Epoch 54/2000, Train Loss: 0.005509, Val Loss: 0.002065
# Epoch 55/2000, Train Loss: 0.005641, Val Loss: 0.002008
# Epoch 56/2000, Train Loss: 0.003508, Val Loss: 0.002588
# Epoch 57/2000, Train Loss: 0.003420, Val Loss: 0.003280
# Epoch 58/2000, Train Loss: 0.007749, Val Loss: 0.001661
# Epoch 59/2000, Train Loss: 0.003813, Val Loss: 0.002390
# Epoch 60/2000, Train Loss: 0.003368, Val Loss: 0.003215
# Epoch 61/2000, Train Loss: 0.005756, Val Loss: 0.001889
# Epoch 62/2000, Train Loss: 0.005237, Val Loss: 0.001998
# Epoch 63/2000, Train Loss: 0.003510, Val Loss: 0.002449
# Epoch 64/2000, Train Loss: 0.003415, Val Loss: 0.003129
# Epoch 65/2000, Train Loss: 0.007979, Val Loss: 0.001582
# Epoch 66/2000, Train Loss: 0.003656, Val Loss: 0.002217
# Epoch 67/2000, Train Loss: 0.003083, Val Loss: 0.003310
# Epoch 68/2000, Train Loss: 0.005859, Val Loss: 0.001787
# Epoch 69/2000, Train Loss: 0.005214, Val Loss: 0.002006
# Epoch 70/2000, Train Loss: 0.003518, Val Loss: 0.002374
# Epoch 71/2000, Train Loss: 0.003215, Val Loss: 0.002726
# Epoch 72/2000, Train Loss: 0.006859, Val Loss: 0.001604
# Epoch 73/2000, Train Loss: 0.003378, Val Loss: 0.002126
# Epoch 74/2000, Train Loss: 0.003256, Val Loss: 0.003391
# Epoch 75/2000, Train Loss: 0.005964, Val Loss: 0.001604
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.3, 'early_stopping_patience': 10, 'hidden_size': 100, 'learning_rate': 0.001, 'num_epochs': 2000, 'num_layers': 3, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.316270, Val Loss: 0.015219
# Epoch 2/2000, Train Loss: 0.116501, Val Loss: 0.019859
# Epoch 3/2000, Train Loss: 0.083797, Val Loss: 0.025311
# Epoch 4/2000, Train Loss: 0.076908, Val Loss: 0.015649
# Epoch 5/2000, Train Loss: 0.067235, Val Loss: 0.018406
# Epoch 6/2000, Train Loss: 0.057642, Val Loss: 0.014141
# Epoch 7/2000, Train Loss: 0.014772, Val Loss: 0.016732
# Epoch 8/2000, Train Loss: 0.067424, Val Loss: 0.025282
# Epoch 9/2000, Train Loss: 0.013154, Val Loss: 0.005165
# Epoch 10/2000, Train Loss: 0.008572, Val Loss: 0.013757
# Epoch 11/2000, Train Loss: 0.012866, Val Loss: 0.007097
# Epoch 12/2000, Train Loss: 0.020500, Val Loss: 0.003593
# Epoch 13/2000, Train Loss: 0.006393, Val Loss: 0.008929
# Epoch 14/2000, Train Loss: 0.007716, Val Loss: 0.008847
# Epoch 15/2000, Train Loss: 0.025282, Val Loss: 0.003616
# Epoch 16/2000, Train Loss: 0.007100, Val Loss: 0.007990
# Epoch 17/2000, Train Loss: 0.006537, Val Loss: 0.009434
# Epoch 18/2000, Train Loss: 0.024340, Val Loss: 0.003445
# Epoch 19/2000, Train Loss: 0.006919, Val Loss: 0.007672
# Epoch 20/2000, Train Loss: 0.006113, Val Loss: 0.010189
# Epoch 21/2000, Train Loss: 0.019677, Val Loss: 0.002842
# Epoch 22/2000, Train Loss: 0.007279, Val Loss: 0.005770
# Epoch 23/2000, Train Loss: 0.006491, Val Loss: 0.009385
# Epoch 24/2000, Train Loss: 0.014447, Val Loss: 0.002944
# Epoch 25/2000, Train Loss: 0.010145, Val Loss: 0.004472
# Epoch 26/2000, Train Loss: 0.005716, Val Loss: 0.007918
# Epoch 27/2000, Train Loss: 0.009366, Val Loss: 0.004230
# Epoch 28/2000, Train Loss: 0.014060, Val Loss: 0.003734
# Epoch 29/2000, Train Loss: 0.006214, Val Loss: 0.006540
# Epoch 30/2000, Train Loss: 0.007009, Val Loss: 0.005415
# Epoch 31/2000, Train Loss: 0.018079, Val Loss: 0.003543
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.3, 'early_stopping_patience': 10, 'hidden_size': 100, 'learning_rate': 0.0001, 'num_epochs': 2000, 'num_layers': 1, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.383393, Val Loss: 0.194647
# Epoch 2/2000, Train Loss: 0.349760, Val Loss: 0.170676
# Epoch 3/2000, Train Loss: 0.316896, Val Loss: 0.146374
# Epoch 4/2000, Train Loss: 0.282476, Val Loss: 0.120676
# Epoch 5/2000, Train Loss: 0.244766, Val Loss: 0.092637
# Epoch 6/2000, Train Loss: 0.201881, Val Loss: 0.061767
# Epoch 7/2000, Train Loss: 0.152269, Val Loss: 0.029999
# Epoch 8/2000, Train Loss: 0.099028, Val Loss: 0.012388
# Epoch 9/2000, Train Loss: 0.063484, Val Loss: 0.030562
# Epoch 10/2000, Train Loss: 0.045137, Val Loss: 0.022284
# Epoch 11/2000, Train Loss: 0.043948, Val Loss: 0.018844
# Epoch 12/2000, Train Loss: 0.043346, Val Loss: 0.019474
# Epoch 13/2000, Train Loss: 0.040983, Val Loss: 0.019447
# Epoch 14/2000, Train Loss: 0.038794, Val Loss: 0.018428
# Epoch 15/2000, Train Loss: 0.037085, Val Loss: 0.017521
# Epoch 16/2000, Train Loss: 0.035381, Val Loss: 0.016780
# Epoch 17/2000, Train Loss: 0.033572, Val Loss: 0.015957
# Epoch 18/2000, Train Loss: 0.031753, Val Loss: 0.015041
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.3, 'early_stopping_patience': 10, 'hidden_size': 100, 'learning_rate': 0.0001, 'num_epochs': 2000, 'num_layers': 2, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.416401, Val Loss: 0.210126
# Epoch 2/2000, Train Loss: 0.361787, Val Loss: 0.169397
# Epoch 3/2000, Train Loss: 0.307661, Val Loss: 0.126630
# Epoch 4/2000, Train Loss: 0.247418, Val Loss: 0.078679
# Epoch 5/2000, Train Loss: 0.175917, Val Loss: 0.029836
# Epoch 6/2000, Train Loss: 0.104895, Val Loss: 0.019095
# Epoch 7/2000, Train Loss: 0.069094, Val Loss: 0.039132
# Epoch 8/2000, Train Loss: 0.054009, Val Loss: 0.025142
# Epoch 9/2000, Train Loss: 0.054797, Val Loss: 0.022771
# Epoch 10/2000, Train Loss: 0.054147, Val Loss: 0.024015
# Epoch 11/2000, Train Loss: 0.051691, Val Loss: 0.024201
# Epoch 12/2000, Train Loss: 0.050029, Val Loss: 0.023376
# Epoch 13/2000, Train Loss: 0.048716, Val Loss: 0.022819
# Epoch 14/2000, Train Loss: 0.047207, Val Loss: 0.022059
# Epoch 15/2000, Train Loss: 0.045718, Val Loss: 0.021364
# Epoch 16/2000, Train Loss: 0.044246, Val Loss: 0.020760
# Early stopping
#
# Training with parameters: {'batch_size': 32, 'dropout': 0.3, 'early_stopping_patience': 10, 'hidden_size': 100, 'learning_rate': 0.0001, 'num_epochs': 2000, 'num_layers': 3, 'optimizer_name': 'Adam'}
# Epoch 1/2000, Train Loss: 0.422353, Val Loss: 0.214671
# Epoch 2/2000, Train Loss: 0.367435, Val Loss: 0.171557
# Epoch 3/2000, Train Loss: 0.307998, Val Loss: 0.121127
# Epoch 4/2000, Train Loss: 0.234134, Val Loss: 0.058755
# Epoch 5/2000, Train Loss: 0.143855, Val Loss: 0.014751
# Epoch 6/2000, Train Loss: 0.086003, Val Loss: 0.047590
# Epoch 7/2000, Train Loss: 0.055892, Val Loss: 0.025267
# Epoch 8/2000, Train Loss: 0.058565, Val Loss: 0.022976
# Epoch 9/2000, Train Loss: 0.057760, Val Loss: 0.025767
# Epoch 10/2000, Train Loss: 0.054935, Val Loss: 0.025054
# Epoch 11/2000, Train Loss: 0.053057, Val Loss: 0.023166
# Epoch 12/2000, Train Loss: 0.050877, Val Loss: 0.022293
# Epoch 13/2000, Train Loss: 0.048453, Val Loss: 0.021824
# Epoch 14/2000, Train Loss: 0.047062, Val Loss: 0.020644
# Epoch 15/2000, Train Loss: 0.043350, Val Loss: 0.019018
# Early stopping
#
# Best parameters: {'batch_size': 32, 'dropout': 0.3, 'early_stopping_patience': 10, 'hidden_size': 100, 'learning_rate': 0.001, 'num_epochs': 2000, 'num_layers': 2, 'optimizer_name': 'Adam'}
# Best Validation Loss: 0.001603544185248514

# %%
# Plot training and validation loss curves for the best model
plot_losses(best_train_losses, best_val_losses)
# Out:
# Best Validation Loss: 0.0015819234734711547

# %%
# Save the optimized model
torch.save(best_model.state_dict(), 'lstm_best_model.pth')

# %%
# Prepare test dataset and dataloader
sequence_length = 60
test_dataset = StockDataset(test_scaled, sequence_length)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)
#actual_dataset = StockDataset(df_actual, sequence_length)
#actual_loader = DataLoader(actual_dataset, batch_size=1, shuffle=False)

# Load the best model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
best_model.load_state_dict(torch.load('lstm_best_model.pth'))
best_model.to(device)
best_model.eval()

# Evaluate the model on the test set
predictions = []
actuals = []

with torch.no_grad():
    for x_test, y_test in test_loader:
        x_test = x_test.to(device)
        y_test = y_test.to(device)

        output = best_model(x_test)
        predictions.append(output.item())
        actuals.append(y_test.item())

# %%
# Convert lists to numpy arrays and reshape
predictions = np.array(predictions).reshape(-1, 1)
actuals = np.array(actuals).reshape(-1, 1)

# Inverse transform to get actual prices
predictions_inv = scaler.inverse_transform(predictions)
actuals_inv = scaler.inverse_transform(actuals)

# Compute RMSE
mse = mean_squared_error(actuals_inv, predictions_inv)
rmse = np.sqrt(mse)
print(f'\nTest MSE: {mse}')
print(f'\nTest RMSE: {rmse}')
# Out:
# Test MSE: 21.00919926340875
#
# Test RMSE: 4.583579306983654

# %%
# Prepare dates for plotting
test_dates = df_test.index[sequence_length:]

# Create a DataFrame for comparison
result_df = pd.DataFrame({'Date': test_dates,
                          'Actual': actuals_inv.flatten(),
                          'Predicted': predictions_inv.flatten()})

# Plot actual vs predicted prices
plt.figure(figsize=(14, 7))
plt.plot(result_df['Date'], result_df['Actual'], label='Actual Price')
plt.plot(result_df['Date'], result_df['Predicted'], label='Predicted Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Actual vs Predicted Adj Close Price')
plt.legend()
plt.show()

# Display the comparison table
print("\nComparison of Actual and Predicted Prices:")
print(result_df)
# Out:
# Comparison of Actual and Predicted Prices:
#          Date      Actual   Predicted
# 0  2023-10-04  136.270005  130.828494
# 1  2023-10-05  135.990007  131.677873
# 2  2023-10-06  138.729996  132.409272
# 3  2023-10-09  139.500002  133.474337
# 4  2023-10-10  139.199998  134.586030
# 5  2023-10-11  141.699998  135.389939
# 6  2023-10-12  140.289992  136.380106
# 7  2023-10-13  138.580002  136.918468
# 8  2023-10-16  140.490004  136.789625
# 9  2023-10-17  140.990007  136.804057
# 10 2023-10-18  139.279997  136.982108
# 11 2023-10-19  138.979994  136.843681
# 12 2023-10-20  136.740004  136.545889
# 13 2023-10-23  137.899992  135.793845
# 14 2023-10-24  140.119994  135.272090
# 15 2023-10-25  126.670000  135.429492
# 16 2023-10-26  123.440004  133.106887
# 17 2023-10-27  123.400002  129.654951
# 18 2023-10-30  125.750001  126.517646
# 19 2023-10-31  125.300003  124.713086
# 20 2023-11-01  127.569999  123.827266
# 21 2023-11-02  128.580001  123.983178
# 22 2023-11-03  130.369994  124.747181
# 23 2023-11-06  131.449996  125.939972
# 24 2023-11-07  132.399992  127.245387
# 25 2023-11-08  133.259994  128.476796
# 26 2023-11-09  131.690001  129.554098
# 27 2023-11-10  134.059996  129.995817
# 28 2023-11-13  133.640000  130.536740
# 29 2023-11-14  135.429993  130.915761
# 30 2023-11-15  136.380006  131.506112
# 31 2023-11-16  138.699995  132.243881
# 32 2023-11-17  136.940003  133.346311
# 33 2023-11-20  137.919997  133.984192
# 34 2023-11-21  138.619996  134.467965
# 35 2023-11-22  140.020006  134.911692
# 36 2023-11-24  138.220001  135.523550
# 37 2023-11-27  138.050002  135.694310
# 38 2023-11-28  138.619996  135.604018
# 39 2023-11-29  136.399994  135.542525

# %%
def predict_and_visualize(model, train_dataset, val_dataset, test_dataset, scaler, df_train, df_val, df_test, sequence_length):
    model.eval()
    predictions_train, actuals_train = [], []
    predictions_val, actuals_val = [], []
    predictions_test, actuals_test = [], []
    
    # Helper function to generate predictions
    def generate_predictions(dataset, loader):
        predictions, actuals = [], []
        with torch.no_grad():
            for x_batch, y_batch in loader:
                x_batch = x_batch.to(device)
                y_batch = y_batch.to(device)
                outputs = model(x_batch)
                predictions.append(outputs.item())
                actuals.append(y_batch.item())
        return predictions, actuals

    # Generate predictions for training dataset
    train_loader = DataLoader(train_dataset, batch_size=1, shuffle=False)
    predictions_train, actuals_train = generate_predictions(train_dataset, train_loader)

    # Generate predictions for validation dataset
    val_loader = DataLoader(val_dataset, batch_size=1, shuffle=False)
    predictions_val, actuals_val = generate_predictions(val_dataset, val_loader)

    # Generate predictions for test dataset
    test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)
    predictions_test, actuals_test = generate_predictions(test_dataset, test_loader)

    # Inverse transform the predictions and actuals
    predictions_train_inv = scaler.inverse_transform(np.array(predictions_train).reshape(-1, 1))
    actuals_train_inv = scaler.inverse_transform(np.array(actuals_train).reshape(-1, 1))

    predictions_val_inv = scaler.inverse_transform(np.array(predictions_val).reshape(-1, 1))
    actuals_val_inv = scaler.inverse_transform(np.array(actuals_val).reshape(-1, 1))

    predictions_test_inv = scaler.inverse_transform(np.array(predictions_test).reshape(-1, 1))
    actuals_test_inv = scaler.inverse_transform(np.array(actuals_test).reshape(-1, 1))

    # Combine results into a DataFrame for visualization
    train_dates = df_train.index[sequence_length:]
    val_dates = df_val.index[sequence_length:]
    test_dates = df_test.index[sequence_length:]

    combined_df = pd.DataFrame({
        'Date': np.concatenate([train_dates, val_dates, test_dates]),
        'Actual': np.concatenate([actuals_train_inv.flatten(), actuals_val_inv.flatten(), actuals_test_inv.flatten()]),
        'Train Predictions': np.concatenate([predictions_train_inv.flatten(), [None] * (len(val_dates) + len(test_dates))]),
        'Validation Predictions': np.concatenate([[None] * len(train_dates), predictions_val_inv.flatten(), [None] * len(test_dates)]),
        'Test Predictions': np.concatenate([[None] * (len(train_dates) + len(val_dates)), predictions_test_inv.flatten()]),
    })

    # Plot the results
    plt.figure(figsize=(14, 7))
    plt.plot(combined_df['Date'], combined_df['Actual'], label='Actual Prices', linewidth=2)
    plt.plot(combined_df['Date'], combined_df['Train Predictions'], label='Train Predictions', linestyle='dotted')
    plt.plot(combined_df['Date'], combined_df['Validation Predictions'], label='Validation Predictions', linestyle='dashed')
    plt.plot(combined_df['Date'], combined_df['Test Predictions'], label='Test Predictions', linestyle='dashdot')
    plt.title('Actual vs Predicted Prices (Train, Validation, Test)')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.legend()
    plt.show()

    return combined_df

# Predict and visualize
combined_results = predict_and_visualize(
    best_model,
    train_dataset,
    val_dataset,
    test_dataset,
    scaler,
    df_train,
    df_val,
    df_test,
    sequence_length
)

# Display the combined DataFrame
print("\nCombined Results (First 10 Rows):")
print(combined_results.head(10))
# Out:
# Combined Results (First 10 Rows):
#         Date      Actual Train Predictions Validation Predictions  \
# 0 2021-03-31  103.431504        103.502636                   None
# 1 2021-04-01  106.887496        103.750879                   None
# 2 2021-04-05  111.277495        104.605928                   None
# 3 2021-04-06  111.237504        106.370275                   None
# 4 2021-04-07  112.484000        108.216688                   None
# 5 2021-04-08  113.272003        109.923962                   None
# 6 2021-04-09  114.293998        111.345054                   None
# 7 2021-04-12  112.739503        112.524274                   None
# 8 2021-04-13  113.363503        113.066539                   None
# 9 2021-04-14  112.741997         113.31975                   None
#
#   Test Predictions
# 0             None
# 1             None
# 2             None
# 3             None
# 4             None
# 5             None
# 6             None
# 7             None
# 8             None
# 9             None

# %%
def generate_predictions(model, dataset, scaler, device, sequence_length):
    """
    Generate predictions for a given dataset using the trained model.
    """
    loader = DataLoader(dataset, batch_size=1, shuffle=False)
    predictions, actuals = [], []
    model.eval()

    with torch.no_grad():
        for x_batch, y_batch in loader:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)
            outputs = model(x_batch)
            predictions.append(outputs.item())
            actuals.append(y_batch.item())

    # Inverse transform predictions and actuals to original scale
    predictions_inv = scaler.inverse_transform(np.array(predictions).reshape(-1, 1))
    actuals_inv = scaler.inverse_transform(np.array(actuals).reshape(-1, 1))

    return predictions_inv, actuals_inv

# %%
# Step 1: Generate predictions for training, validation, and test datasets
predictions_train, actuals_train = generate_predictions(
    model=best_model,
    dataset=train_dataset,
    scaler=scaler,
    device=device,
    sequence_length=sequence_length
)

predictions_val, actuals_val = generate_predictions(
    model=best_model,
    dataset=val_dataset,
    scaler=scaler,
    device=device,
    sequence_length=sequence_length
)

predictions_test, actuals_test = generate_predictions(
    model=best_model,
    dataset=test_dataset,
    scaler=scaler,
    device=device,
    sequence_length=sequence_length
)

# Step 2: Visualize predictions and actual data
combined_results = visualize_predictions_with_actual(
    df_train=df_train,
    df_val=df_val,
    df_test=df_test,
    predictions_train=predictions_train,
    actuals_train=actuals_train,
    predictions_val=predictions_val,
    actuals_val=actuals_val,
    predictions_test=predictions_test,
    actuals_test=actuals_test,
    sequence_length=sequence_length
)

# Step 3: Save the combined results to a CSV file
combined_results.to_csv('combined_results_with_actual.csv', index=False)
print("Combined results saved to 'combined_results_with_actual.csv'")
# Out:
# Combined results saved to 'combined_results_with_actual.csv'
